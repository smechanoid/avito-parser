# %%
# import re
from tqdm.notebook import tqdm
import pandas as pd

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
# !ls data
# Out:
# avito_2022-08-26_17-29_raw.xlsx  avito_2022-08-29_13-17.xlsx
# avito_2022-08-26_17-29.xlsx	 geckodriver.log
# avito_2022-08-29_13-16_raw.xlsx

# %%
# fname = 'avito_2022-08-26_17-29.xlsx'
fname = 'avito_2022-08-29_13-17.xlsx'

df = pd.read_excel('data/'+fname)
print(len(df))
df.sample(5)
# Out:
# 3898
#                       adr                                 title  priceM  \
# 3850      ул. Гоголя, 20Б         1-к. квартира, 30 м², 4/4 эт.    5.50
# 3702  Античный пр-т, 64к2        1-к. квартира, 55 м², 3/10 эт.    9.50
# 574     ул. Токарева, 18Г       1-к. квартира, 40,9 м², 7/8 эт.    7.57
# 490       пр-т Победы, 39       2-к. квартира, 43,7 м², 4/5 эт.    6.20
# 1156     Парковая ул., 11  1-к. апартаменты, 41,6 м², 10/11 эт.   14.56
#
#       nrooms  floor  nfloors  area  is_studio  is_apartment  is_part  \
# 3850       1      4        4 30.00      False         False    False
# 3702       1      3       10 55.00      False         False    False
# 574        1      7        8 40.90      False         False    False
# 490        2      4        5 43.70      False         False    False
# 1156       1      0       11 41.60      False          True    False
#
#       is_auction  is_openspace  is_SNT  is_fiolent  is_last_floor  is_roof  \
# 3850       False         False   False       False           True    False
# 3702       False         False   False       False          False    False
# 574        False         False   False       False          False    False
# 490        False         False   False       False          False    False
# 1156       False         False   False       False          False    False
#
#                                                                                                                                                                                                                                                                     description  \
# 3850      Продам уютную однокомнатную квартиру в центре города на 4 этаже в доме из инкерманского камня. \nОбщая площадь — 30 кв. М. \nКомната 18 кв. М. \nКухня 5.2, \nвысота потолков 2.7м. \nОкна и балкон застеклены Пвх, на полу линолеум. Ванна, и кухня в кафеле. Есть н
# 3702        Просторная однокомнатная квартира с автономным отоплением в новом спальном районе. \n\nРайон обладает развитой инфраструктурой здесь есть все необходимые условия для комфортной жизни и отдыха: \n- несколько, средних общеобразовательных школ и детских дошкольн
# 574   Квартира в готовом доме! Можно забирать ключи и начинать ремонт! \n\nДоступна Ипотека. \n\nКвартира без отделки. \n\nКрупнейший в Севастополе семейный микрорайон «Доброгород»! \n\nПобедитель всероссийской премии «Топ ЖК 2021» в номинации «Лучший жилой комплекс». \n
# 490            Продаётся уютная квартира с хорошим ремонтом. Окна выходят на сквер с соснами. Рядом школа и детский сад. Тихий район. В квартире очень тепло зимой и не жарко летом. Хорошие соседи. При продаже остаётся кондиционер, газовая колонка и кухонная мебель. Прода
# 1156           Продажа супер видового апартамента в комплексе «акваделюкс». Шикарный вид на море и закат (на фото). В комплексе есть все необходимое для комфортной жизни: банно-бассейный комплекс, Спа, тренажёрный зал, пляж, открытый бассейн, рестораны, большая территори
#
#          price    avito_id
# 3850   5500000  2408665220
# 3702   9500000  2412857765
# 574    7566500  2505249803
# 490    6200000  2554937301
# 1156  14560000  2343514935

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3898 entries, 0 to 3897
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   adr            3898 non-null   object
#  1   title          3897 non-null   object
#  2   priceM         3898 non-null   float64
#  3   nrooms         3898 non-null   int64
#  4   floor          3898 non-null   int64
#  5   nfloors        3898 non-null   int64
#  6   area           3898 non-null   float64
#  7   is_studio      3898 non-null   bool
#  8   is_apartment   3898 non-null   bool
#  9   is_part        3898 non-null   bool
#  10  is_auction     3898 non-null   bool
#  11  is_openspace   3898 non-null   bool
#  12  is_SNT         3898 non-null   bool
#  13  is_fiolent     3898 non-null   bool
#  14  is_last_floor  3898 non-null   bool
#  15  is_roof        3898 non-null   bool
#  16  description    3898 non-null   object
#  17  price          3898 non-null   int64
#  18  avito_id       3898 non-null   int64
# dtypes: bool(9), float64(2), int64(5), object(3)
# memory usage: 338.9+ KB

# %%
# list(df.columns)

# %%
# df[ df['adr'].str.match('.*еверн.*') ][['adr','title','description','priceM']]
# df[ df['description'].str.lower().str.match('.*северн.*') ][['adr','title','description','priceM']]
# df[ df['description'].str.lower().str.match('.*мансард.*') ][['adr','title','description','priceM']]
# df[ df['description'].str.lower().str.match('.*черда.*') ][['adr','title','description','priceM']]

# %%
df_ = df.query(
    '~(is_studio|is_apartment|is_part|is_auction|is_openspace|is_SNT|is_fiolent|is_roof)'
    '&(nrooms==2)')

df_[['priceM']].describe().T
# Out:
#         count  mean  std  min  25%  50%   75%   max
# priceM 995.00  8.88 3.28 2.80 6.70 8.18 10.50 36.00

# %%
cols = ['adr', 'priceM', 'nrooms', 'floor', 'nfloors', 'area', 'description', 'avito_id',]
df_[cols].sort_values(by=['priceM'])
# Out:
#                                        adr  priceM  nrooms  floor  nfloors  \
# 1782  с. Песчаное, ул. Верхний Городок, 2А    2.80       2      1        1
# 2731              с. Вилино, ул. Кирова, 2    2.90       2      2        2
# 3640              с. Вилино, ул. Кирова, 2    3.00       2      2        2
# 2202             с. Вилино, ул. Чапаева, 1    3.40       2      1        2
# 223                 Чернореченская ул., 88    3.50       2      2        2
# ...                                    ...     ...     ...    ...      ...
# 696                        ул. Сенявина, 5   24.70       2      5       13
# 3373              Коммунистическая ул., 4А   28.00       2      6        6
# 2082                  ул. Железнякова, 17А   35.00       2      2        4
# 2926             ул. Дмитрия Ульянова, 11А   36.00       2      6        7
# 3895             ул. Дмитрия Ульянова, 11А   36.00       2      6        7
#
#        area  \
# 1782  51.00
# 2731  38.30
# 3640  38.30
# 2202  45.90
# 223   47.00
# ...     ...
# 696   95.00
# 3373 127.50
# 2082 125.20
# 2926 145.00
# 3895 145.20
#
#                                                                                                                                                                                                                                                                    description  \
# 1782                                                                                                                                                                                                         Фото сделаю, когда домой вернусь, примерно в среду, срочно, торг.
# 2731     Двухкомнатная квартира 38,3 м2, на 2/2 этаже дома. Расположена в Республике Крым, Бахчисарайский район, с. Вилино, ул. Кирова, д. 2. \n\nПозвоните нам, чтобы узнать все детали! \n\nТехнические характеристики: \n— Адрес: Республике Крым, Бахчисарайский район, с.
# 3640  Продается двухкомнатная квартира 38. 3 кв м.\n\nКвартира светлая, сухая. Состояние жилое, но ремонт по своему вкусу сделать захочется. \n\nВход в квартиру с балкона галерейного типа. \n\nС Балкона открывается потрясающий панорамный вид. \n\nГаз, автономное отоплен
# 2202    Двухкомнатная квартира 45,9 м2 на 1/2 этаже дома. Расположена в Республике Крым, с. Вилино, ул. Чапаева, д. 1. \n\nПозвоните нам, чтобы узнать все детали! \n\nТехнические характеристики: \n— Адрес: Республика Крым, с. Вилино, ул. Чапаева, д. 1. \n— Год постройки
# 223   Продам Квартиру.\n\nСобственник.\n\nКвартира продаётся в активно развивающемся районе города Севастополь. \nДвухкомнатная квартира хорошей планировки! Общая площадь 47 кв/м. \nЗаезжай живи. \n\nДо остановки 5 минут регулярно ходит общественный транспорт, в шаговой
# ...                                                                                                                                                                                                                                                                        ...
# 696       Двухкомнатная квартира 95 м2, на 5/13 этаже дома с большой кухней 17 м2. Расположена в г. Севастополь, Ленинский район, ул. Сенявина, д.5. \n\nКвартира идеально подойдет для дружной семьи, либо в качестве инвестиций. \n\nПозвоните нам, чтобы узнать все детали!
# 3373    Предлагается к продаже уникальная 2 комнатная видовая квартира(127,5 кв. М.) в центре Севастополя. \n\nЗакрытая территория. Дом монолитно-каркасный с кирпичным наполнением 2006г. Постройки. \n\nКвартира состоит из Каминного зала -70 кв. М. \n\nСпальни — 16 кв. М
# 2082        Двухкомнатная квартира 125,2 м2, на 2/4 этаже дома с большой кухней-столовой 47 м2. Расположена в г. Севастополь, Ленинский район, ул. Железнякова, д. 17 А. \n\nЭта шикарная квартира — отличный вариант для постоянного проживания или для высокорентабельной ин
# 2926        Двухкомнатная квартира 145 м2 на 6/7 этаже дома с большой кухней 35м2. Расположена в г. Севастополь, Гагаринский район, ул. Дмитрия Ульянова, д.11А. Элитный дом, с подземным паркингом (у нас личный гараж — 50м) из которого лифт доставит вас до квартиры. \n\n
# 3895         Продаётся квартира с панорамным видом и качественным ремонтом для комфортного проживания. Общей площадью 145.2 м. Кв. Расположена на 6-м этаже 7-ми этажного дома ( лифт) 2012г. Постройки. \nКухня-столовая объединена с гостиной, гостевой санузел, отдельная с
#
#         avito_id
# 1782  2538746691
# 2731  2457693926
# 3640  2523243687
# 2202  2393768041
# 223   2527337533
# ...          ...
# 696   2393165688
# 3373  2309424314
# 2082  2136038439
# 2926  2328307177
# 3895  2447926345
#
# [995 rows x 8 columns]
