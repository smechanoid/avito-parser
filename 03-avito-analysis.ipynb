# %%
# import re
from tqdm.notebook import tqdm
import pandas as pd

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
# !ls

# %%
fname = 'avito_2022-08-26_17-29.xlsx'
df = pd.read_excel('data/'+fname)
print(len(df))
df.sample(5)
# Out:
# 3949
#                                          adr  \
# 934                  Фиолентовское ш., 134к5
# 3633  Севастополь, улица Павла Корчагина, 23
# 3141                        Рубежный пр., 28
# 1037                   Столетовский пр-т, 27
# 2972                          ул. Гоголя, 63
#
#                                    title  priceM  nrooms  floor  nfloors  \
# 934   апартаменты-студия, 25 м², 2/6 эт.    3.80       0      2        6
# 3633       1-к. квартира, 36 м², 2/9 эт.    6.20       1      2        9
# 3141       2-к. квартира, 63 м², 2/5 эт.    9.50       2      2        5
# 1037    1-к. квартира, 44,6 м², 6/10 эт.    7.80       1      6       10
# 2972     2-к. квартира, 42,4 м², 4/4 эт.    7.30       2      4        4
#
#       area  is_studio  is_apartment  is_part  is_auction  is_openspace  \
# 934  25.00       True          True    False       False         False
# 3633 36.00      False         False    False       False         False
# 3141 63.00      False         False    False       False         False
# 1037 44.60      False         False    False       False         False
# 2972 42.40      False         False    False       False         False
#
#       is_SNT  is_fiolent  is_last_floor  is_roof  \
# 934    False        True          False    False
# 3633   False       False          False    False
# 3141   False       False          False    False
# 1037   False       False          False    False
# 2972   False       False           True    False
#
#                                                                                                                                                                                                                                                                   description  \
# 934          Продам апартаменты в современном комплексе « Фиолент Villadge ». В аппарт-комплексе охраняемая закрытая территория, с собственной развитлй инфраструктурой, спортивная, детская площадка, магазин, рестаран, мангальная зона, собственный спуск к морю с пляжем,
# 3633  Продаётся 1-комнатная квартира неподалеку от моря в новом доме ЖК Апельсин по ул. Павла Корчагина, 23.\n\nОтлично подойдет как для жизни, так и под сдачу в аренду! \n\nКвартира расположена на 2 этаже 9 этажного дома. \n\nОбщая площадь 36 кв. М. \nКухня 8.8 кв. М.
# 3141     Уникальное предложение: 2-комнатная возле моря. \nЕсть возможность перепланировки в две отдельные студии (с минимальными вложениями). \nСм. В фото вариант перепланировки. \nВы получаете две студии по цене 2-комнатной. Спешите! \nЭто готовый бизнес с высокой до
# 1037    Однокомнатная квартира 44,6 м2, на 6/10 этаже дома с просторной кухней 12 м2. Расположена в г. Севастополь, Гагаринский район, пр-кт Столетовский, 27. \n\nПозвоните нам, чтобы узнать все детали! \n\nТехнические характеристики: \n— Адрес: г. Севастополь, Гагарин
# 2972   Двухкомнатная квартира 42,4 м2, на 4/4 этаже дома. Расположена в г. Севастополь, Ленинский район, ул. Гоголя, д. 63. \n\nПозвоните нам, чтобы узнать все детали! \n\nТехнические характеристики: \n— Адрес: г. Севастополь, Ленинский район, ул. Гоголя, д. 63. \n— Го
#
#         price    avito_id
# 934   3800000  2482995811
# 3633  6200000  2425552182
# 3141  9500000  2078905234
# 1037  7800000  2329311968
# 2972  7300000  2520725049

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3949 entries, 0 to 3948
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   adr            3949 non-null   object
#  1   title          3948 non-null   object
#  2   priceM         3949 non-null   float64
#  3   nrooms         3949 non-null   int64
#  4   floor          3949 non-null   int64
#  5   nfloors        3949 non-null   int64
#  6   area           3949 non-null   float64
#  7   is_studio      3949 non-null   bool
#  8   is_apartment   3949 non-null   bool
#  9   is_part        3949 non-null   bool
#  10  is_auction     3949 non-null   bool
#  11  is_openspace   3949 non-null   bool
#  12  is_SNT         3949 non-null   bool
#  13  is_fiolent     3949 non-null   bool
#  14  is_last_floor  3949 non-null   bool
#  15  is_roof        3949 non-null   bool
#  16  description    3949 non-null   object
#  17  price          3949 non-null   int64
#  18  avito_id       3949 non-null   int64
# dtypes: bool(9), float64(2), int64(5), object(3)
# memory usage: 343.3+ KB

# %%
# list(df.columns)

# %%
# df[ df['adr'].str.match('.*еверн.*') ][['adr','title','description','priceM']]
# df[ df['description'].str.lower().str.match('.*северн.*') ][['adr','title','description','priceM']]
# df[ df['description'].str.lower().str.match('.*мансард.*') ][['adr','title','description','priceM']]
# df[ df['description'].str.lower().str.match('.*черда.*') ][['adr','title','description','priceM']]

# %%
df_ = df.query(
    '~(is_studio|is_apartment|is_part|is_auction|is_openspace|is_SNT|is_fiolent|is_roof)'
    '&(nrooms==2)')

df_[['priceM']].describe().T
# Out:
#          count  mean  std  min  25%  50%   75%   max
# priceM 1022.00  8.86 3.33 2.80 6.60 8.18 10.30 36.00

# %%
cols = ['adr', 'priceM', 'nrooms', 'floor', 'nfloors', 'area', 'description', 'avito_id',]
df_[cols].sort_values(by=['priceM'])
# Out:
#                                        adr  priceM  nrooms  floor  nfloors  \
# 1619  с. Песчаное, ул. Верхний Городок, 2А    2.80       2      1        1
# 2404              с. Вилино, ул. Кирова, 2    2.90       2      2        2
# 3532              с. Вилино, ул. Кирова, 2    3.00       2      2        2
# 18                 Чернореченская ул., 90А    3.35       2      1        1
# 1995             с. Вилино, ул. Чапаева, 1    3.40       2      1        2
# ...                                    ...     ...     ...    ...      ...
# 44                         ул. Сенявина, 5   24.70       2      5       13
# 3191              Коммунистическая ул., 4А   28.00       2      6        6
# 2226                  ул. Железнякова, 17А   35.00       2      2        4
# 3878             ул. Дмитрия Ульянова, 11А   36.00       2      6        7
# 2540             ул. Дмитрия Ульянова, 11А   36.00       2      6        7
#
#        area  \
# 1619  51.00
# 2404  38.30
# 3532  38.30
# 18    38.00
# 1995  45.90
# ...     ...
# 44    95.00
# 3191 127.50
# 2226 125.20
# 3878 145.20
# 2540 145.00
#
#                                                                                                                                                                                                                                                                    description  \
# 1619                                                                                                                                                                                                         Фото сделаю, когда домой вернусь, примерно в среду, срочно, торг.
# 2404     Двухкомнатная квартира 38,3 м2, на 2/2 этаже дома. Расположена в Республике Крым, Бахчисарайский район, с. Вилино, ул. Кирова, д. 2. \n\nПозвоните нам, чтобы узнать все детали! \n\nТехнические характеристики: \n— Адрес: Республике Крым, Бахчисарайский район, с.
# 3532  Продается двухкомнатная квартира 38. 3 кв м.\n\nКвартира светлая, сухая. Состояние жилое, но ремонт по своему вкусу сделать захочется. \n\nВход в квартиру с балкона галерейного типа. \n\nС Балкона открывается потрясающий панорамный вид. \n\nГаз, автономное отоплен
# 18            Собственник Обменипотека Квартира в Инкермане 38кВ. М, в одноэтажном трех Квартирном доме с отдельным входом, двором, въездом, парковка, Участок 4 сотки и однокомнатная времянка с удобствами отдельно стоящая 30 кв. М (Возможно сдавать 15 -20 т. Р. Все Комм
# 1995    Двухкомнатная квартира 45,9 м2 на 1/2 этаже дома. Расположена в Республике Крым, с. Вилино, ул. Чапаева, д. 1. \n\nПозвоните нам, чтобы узнать все детали! \n\nТехнические характеристики: \n— Адрес: Республика Крым, с. Вилино, ул. Чапаева, д. 1. \n— Год постройки
# ...                                                                                                                                                                                                                                                                        ...
# 44        Двухкомнатная квартира 95 м2, на 5/13 этаже дома с большой кухней 17 м2. Расположена в г. Севастополь, Ленинский район, ул. Сенявина, д.5. \n\nКвартира идеально подойдет для дружной семьи, либо в качестве инвестиций. \n\nПозвоните нам, чтобы узнать все детали!
# 3191    Предлагается к продаже уникальная 2 комнатная видовая квартира(127,5 кв. М.) в центре Севастополя. \n\nЗакрытая территория. Дом монолитно-каркасный с кирпичным наполнением 2006г. Постройки. \n\nКвартира состоит из Каминного зала -70 кв. М. \n\nСпальни — 16 кв. М
# 2226        Двухкомнатная квартира 125,2 м2, на 2/4 этаже дома с большой кухней-столовой 47 м2. Расположена в г. Севастополь, Ленинский район, ул. Железнякова, д. 17 А. \n\nЭта шикарная квартира — отличный вариант для постоянного проживания или для высокорентабельной ин
# 3878         Продаётся квартира с панорамным видом и качественным ремонтом для комфортного проживания. Общей площадью 145.2 м. Кв. Расположена на 6-м этаже 7-ми этажного дома ( лифт) 2012г. Постройки. \nКухня-столовая объединена с гостиной, гостевой санузел, отдельная с
# 2540        Двухкомнатная квартира 145 м2 на 6/7 этаже дома с большой кухней 35м2. Расположена в г. Севастополь, Гагаринский район, ул. Дмитрия Ульянова, д.11А. Элитный дом, с подземным паркингом (у нас личный гараж — 50м) из которого лифт доставит вас до квартиры. \n\n
#
#         avito_id
# 1619  2538746691
# 2404  2457693926
# 3532  2523243687
# 18    2390401919
# 1995  2393768041
# ...          ...
# 44    2393165688
# 3191  2309424314
# 2226  2136038439
# 3878  2447926345
# 2540  2328307177
#
# [1022 rows x 8 columns]
