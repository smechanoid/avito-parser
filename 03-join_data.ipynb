# %% [markdown]
# __собираем объявления о продаже недвижимости в одну таблицу__
#
# _Evgeny S. Borisov <parser@mechanoid.su>_

# %%
# !date
# Out:
# Вт 16 июл 2024 12:56:58 MSK

# %%
from os import listdir
import re
import pandas as pd

# %%
data_root_folder = 'data/2024'
source = {
         'flat':[data_root_folder+'/raw/flat/cian',data_root_folder+'/raw/flat/avito'],
        'house':[data_root_folder+'/raw/house/cian',data_root_folder+'/raw/house/avito'],
         'land':[data_root_folder+'/raw/land/cian',data_root_folder+'/raw/land/avito'],
    }

# %% [markdown]
# ---

# %%
obj_type = 'flat'
files = [ f'{d}/{f}' for d in source[obj_type] for f in listdir(d) if f[-4:]=='.pkl' ]
display( len(files) )

cols = ['url','place','title','subtitle','price','address','description','ts',]

df_flat = pd.concat([
        pd.read_pickle(f).drop_duplicates(['url'])
        for f in files
    ]).reset_index(drop=True)[cols]

display( len(df_flat) )
display(df_flat.sample(9))
# Out:
# 44
# 41619
#                                                    url       place  \
# 36740                  https://www.avito.ru/3704908889  sevastopol
# 4905   https://sevastopol.cian.ru/sale/flat/299735839/  sevastopol
# 14744  https://sevastopol.cian.ru/sale/flat/303202732/  sevastopol
# 13846  https://sevastopol.cian.ru/sale/flat/302149033/  sevastopol
# 41046                  https://www.avito.ru/3993188484  sevastopol
# 34905                  https://www.avito.ru/3968791969  sevastopol
# 22671                  https://www.avito.ru/3146841867  sevastopol
# 29789                  https://www.avito.ru/3949247641  sevastopol
# 4451   https://sevastopol.cian.ru/sale/flat/302904121/  sevastopol
#
#                                       title subtitle     price  \
# 36740         2-к. квартира, 42 м², 1/5 эт.      NaN   6950000
# 4905     5-комн. квартира, 144 м², 2/5 этаж           19500000
# 14744   1-комн. квартира, 30,3 м², 5/5 этаж            5500000
# 13846  1-комн. квартира, 27,46 м², 5/5 этаж            6865000
# 41046      3-к. квартира, 125,8 м², 4/4 эт.      NaN  22900000
# 34905         1-к. квартира, 50 м², 5/9 эт.      NaN   8980000
# 22671       2-к. квартира, 61,5 м², 6/8 эт.      NaN  14290000
# 29789       2-к. квартира, 60,8 м², 3/9 эт.      NaN   9120000
# 4451                Студия, 20 м², 2/2 этаж            5500000
#
#                                                  address  \
# 36740                                 ул. Горпищенко, 56
# 4905   Севастополь, р-н Ленинский, улица Карантинная, 16
# 14744  Севастополь, р-н Гагаринский, мкр. Камышовая б...
# 13846  Севастополь, р-н Гагаринский, мкр. Омега, Омег...
# 41046                                   Тульская ул., 14
# 34905                                ул. Челнокова, 29к1
# 22671                                     Маячная ул., 3
# 29789      ЖК «Доброгород»\nул. Токарева, 8 этап, блок 2
# 4451   Севастополь, р-н Балаклавский, мкр. Балаклава,...
#
#                                              description  \
# 36740  Двухкомнатная квартира 42 м2, на 1\5 этаже дом...
# 4905   Просторная пятикомнатная квартира улучшенной п...
# 14744  Продается однокомнатная квартира на 5 этаже 5 ...
# 13846
# 41046  Трехкомнатная квартира 125 м2, на 4/4 эт. Трех...
# 34905  Срочно продам видовую и просторную квартиру во...
# 22671  Дом Сдан! Любой Вид Расчета! Ипотека! Материнс...
# 29789  Крупнейший в городе Севастополь семейный район...
# 4451
#
#                               ts
# 36740 2024-06-11 10:25:30.856703
# 4905  2024-06-14 12:56:14.435965
# 14744 2024-06-18 10:45:27.403294
# 13846 2024-06-18 10:45:27.403294
# 41046 2024-06-10 11:17:35.151941
# 34905 2024-06-11 10:25:30.856703
# 22671 2024-06-17 08:29:48.414678
# 29789 2024-07-08 13:29:07.581057
# 4451  2024-06-07 11:33:12.800097

# %%
from lib.cleaner import CleanerFlat

df_flat = CleanerFlat().transform(df_flat)
display( len(df_flat) )
display(df_flat.sample(9))
# Out:
# 41619
#                                                    url       place  \
# 7839         https://krym.cian.ru/sale/flat/299297687/       sudak
# 21367                  https://www.avito.ru/3965245218       sudak
# 18125                  https://www.avito.ru/3973913754       sudak
# 34246                  https://www.avito.ru/3848885940  sevastopol
# 2492   https://sevastopol.cian.ru/sale/flat/301427791/  sevastopol
# 24018                  https://www.avito.ru/2265153030  sevastopol
# 33156                  https://www.avito.ru/3903416013  sevastopol
# 28219                  https://www.avito.ru/4219319560  sevastopol
# 4669   https://sevastopol.cian.ru/sale/flat/302886640/  sevastopol
#
#                                      title subtitle    price  \
# 7839   2-комн. квартира, 48,6 м², 1/2 этаж           3000000
# 21367        2-к. квартира, 57 м², 3/6 эт.      NaN  8550000
# 18125    квартира-студия, 22,6 м², 5/9 эт.      NaN  4285000
# 34246      3-к. квартира, 54,7 м², 1/5 эт.      NaN  8125000
# 2492     2-комн. квартира, 44 м², 3/4 этаж           6000000
# 24018      2-к. квартира, 52,7 м², 5/5 эт.      NaN  6800000
# 33156     1-к. квартира, 34,8 м², 9/12 эт.      NaN  5931695
# 28219      1-к. квартира, 30,6 м², 8/9 эт.      NaN  5100000
# 4669   2-комн. квартира, 56,9 м², 1/5 этаж           6200000
#
#                                                  address  \
# 7839           Республика Крым, Керчь, улица Ванцетти, 4
# 21367                              Гвардейская улица , 3
# 18125  Комплекс апартаментов «Бирюзовый квартал»\n ул...
# 34246                          улица Маршала Блюхера, 13
# 2492        Севастополь, р-н Ленинский, улица Гоголя, 32
# 24018                     пгт. Кача, улица Авиаторов, 34
# 33156  ЖК «Александрия»\n улица Колобова, д. 2/1, сек...
# 28219                                проспект Победы, 19
# 4669   Севастополь, р-н Нахимовский, мкр. Кача, Качин...
#
#                                              description  \
# 7839               2-х комнатная квартира вблизи от моря
# 21367  Продается 2-х комнатная квартира по адресу г. ...
# 18125  Ипотека от 11,5% платеж от 26 000р. Кладовка В...
# 34246  Продам 3х комнатную квартиру в спальном районе...
# 2492   БЕЗ КОМИССИИ ДЛЯ ПОКУПАТЕЛЯ! Продается двухком...
# 24018  Квартира двухкомнатная 52,7 м2 на 5/5 этаже до...
# 33156  Открыты продажи 4 секции в ЖК «Александрия». С...
# 28219  Квартира в развитом районе. До остановки 100 м...
# 4669   В продаже двухкомнатная квартира в пгт. Кача. ...
#
#                               ts  nrooms  floor  ...  area  is_studio  \
# 7839  2024-07-08 14:06:22.627290       0      1  ...  48.6      False
# 21367 2024-06-10 11:35:05.787844       2      3  ...  57.0      False
# 18125 2024-06-07 12:05:27.509755       0      5  ...  22.6       True
# 34246 2024-06-07 11:27:07.236636       3      1  ...  54.7      False
# 2492  2024-07-16 12:28:31.306616       0      3  ...  44.0      False
# 24018 2024-06-17 08:29:48.414678       2      5  ...  52.7      False
# 33156 2024-06-07 11:27:07.236636       1      9  ...  34.8      False
# 28219 2024-07-08 13:29:07.581057       1      8  ...  30.6      False
# 4669  2024-06-07 11:33:12.800097       0      1  ...  56.9      False
#
#        is_apartment  is_part  is_auction  is_openspace  is_roof  is_SNT  \
# 7839          False    False       False         False    False   False
# 21367         False    False       False         False    False   False
# 18125         False    False       False         False    False   False
# 34246         False    False       False         False    False   False
# 2492          False    False       False         False    False   False
# 24018         False    False       False         False    False   False
# 33156         False    False       False         False    False   False
# 28219         False    False       False         False    False   False
# 4669          False    False       False         False    False   False
#
#          priceM  is_last_floor
# 7839   3.000000          False
# 21367  8.550000          False
# 18125  4.285000          False
# 34246  8.125000          False
# 2492   6.000000          False
# 24018  6.800000           True
# 33156  5.931695          False
# 28219  5.100000          False
# 4669   6.200000          False
#
# [9 rows x 21 columns]

# %% [markdown]
# ---

# %%
obj_type = 'land'
files = [ f'{d}/{f}' for d in source[obj_type] for f in listdir(d) if f[-4:]=='.pkl' ]
display( len(files) )

cols = ['url','place','title','subtitle','price','address','description','ts',]

df_land = pd.concat([
        pd.read_pickle(f).drop_duplicates(['url'])
        for f in files
    ]).reset_index(drop=True)[cols]

display( len(df_land) )
display(df_land.sample(9))
# Out:
# 55
# 37019
#                                                      url       place  \
# 4943   https://sevastopol.cian.ru/sale/suburban/30253...  sevastopol
# 32645                    https://www.avito.ru/3623164457  sevastopol
# 11950  https://sevastopol.cian.ru/sale/suburban/30279...  sevastopol
# 8126   https://sevastopol.cian.ru/sale/suburban/30235...  sevastopol
# 18257                    https://www.avito.ru/3560119327  sevastopol
# 6407   https://sevastopol.cian.ru/sale/suburban/30248...  sevastopol
# 16266                    https://www.avito.ru/4024691502       sudak
# 1473   https://sevastopol.cian.ru/sale/suburban/28417...  sevastopol
# 18958                    https://www.avito.ru/3977519731  sevastopol
#
#                                 title subtitle    price  \
# 4943   Участок, 4.6 сот., Садоводство           3000000
# 32645     Участок 6,5 сот. (СНТ, ДНП)      NaN  2000000
# 11950           Участок, 10 сот., ИЖС           3500000
# 8126                  Участок, 8 сот.           1500000
# 18257     Участок 8,5 сот. (СНТ, ДНП)      NaN  4500000
# 6407     Участок, 4 сот., Садоводство           2700000
# 16266       Участок 7 сот. (СНТ, ДНП)      NaN  1400000
# 1473           Участок, 4.5 сот., ИЖС            999000
# 18958     Участок 6,4 сот. (СНТ, ДНП)      NaN  4100000
#
#                                                  address  \
# 4943   Севастополь, р-н Гагаринский, мкр. Фиолент, На...
# 32645                         с. Гончарное, ул. Кичигина
# 11950  Севастополь, р-н Нахимовский, улица 1-я Линия, 79
# 8126   Севастополь, р-н Балаклавский, Орлиновский мун...
# 18257                                     СОТ Южный, 190
# 6407   Севастополь, р-н Гагаринский, Фрегат садоводче...
# 16266                                      с. Миндальное
# 1473      Севастополь, р-н Балаклавский, улица Яблочкова
# 18958             садоводческое товарищество Атлантика-3
#
#                                              description  \
# 4943   Прoдaется участoк 4,6 cотки в СНТ "Наука", pас...
# 32645          Продам участок в с. Гончарное 6.53 сотки.
# 11950  Продаю участок ИЖС 10 соток с прекрасным видом...
# 8126   Продам земельный участок в Байдарской долине,в...
# 18257  Земельные участки в пределах Снт, Тсн Южный пр...
# 6407   Лучшее предложение под застройку! Продам недор...
# 16266  Продаётся участок площадью 7 соток, расположен...
# 1473   Участок 4,5 сотки СТ Участок 4,5 сотки (СТ) в ...
# 18958  Продается отличный участoк — 6,4 cотки, для ст...
#
#                               ts
# 4943  2024-06-17 08:22:17.440170
# 32645 2024-06-11 10:32:52.971878
# 11950 2024-06-14 13:00:38.621423
# 8126  2024-06-19 12:23:33.870565
# 18257 2024-06-19 12:29:14.234421
# 6407  2024-06-24 12:40:23.850839
# 16266 2024-06-24 13:03:08.984518
# 1473  2024-06-07 11:37:10.690720
# 18958 2024-06-19 12:29:14.234421

# %%
from lib.cleaner import CleanerLand

df_land = CleanerLand().transform(df_land)

display( len(df_land) )
display(df_land.sample(9))
# Out:
# 37019
#                                                      url        place  \
# 8815   https://sevastopol.cian.ru/sale/suburban/30069...   sevastopol
# 33862                    https://www.avito.ru/3785308558   sevastopol
# 36097                    https://www.avito.ru/3463287821   sevastopol
# 22834                    https://www.avito.ru/3579700360        sudak
# 2038   https://sevastopol.cian.ru/sale/suburban/30154...   sevastopol
# 23480                    https://www.avito.ru/3614221301   sevastopol
# 35245                    https://www.avito.ru/2418852400   sevastopol
# 25807                    https://www.avito.ru/3869010343  bahchisaray
# 15209                    https://www.avito.ru/2944209004   sevastopol
#
#                               title subtitle     price  \
# 8815           участок, 5 сот., ижс            3650000
# 33862          участок 4 сот. (ижс)      NaN  10000000
# 36097          участок 4 сот. (ижс)      NaN   4750000
# 22834         участок 44 сот. (ижс)      NaN   4800000
# 2038   участок, 4 сот., садоводство            1850000
# 23480         участок 10 сот. (ижс)      NaN   2000000
# 35245        участок 8,2 сот. (ижс)      NaN  31500000
# 25807    участок 68 сот. (снт, днп)      NaN   1250000
# 15209          участок 5 сот. (ижс)      NaN   4100000
#
#                                                  address  \
# 8815   Севастополь, р-н Нахимовский, улица Горпищенко, 2
# 33862                    Севастопольская зона ЮБК, 53/71
# 36097                            ул. Генерала Ракова, 16
# 22834                                     с. Земляничное
# 2038     Севастополь, р-н Гагаринский, СНТ Рябинушка ТСН
# 23480                                  ул. 1-я Линия, 48
# 35245  Гагаринский муниципальный округ, наб. Андрея П...
# 25807                          с. Танковое, ул. Мичурина
# 15209                 садоводческое товарищество Швейник
#
#                                              description  \
# 8815   Продается участок в тихом месте, ровный, 20х24...
# 33862  Продаю участок Ижс в одном из самых прекрасных...
# 36097  В продаже только у нас шикарный участок Ижс пл...
# 22834  Республика Крым, Белогорский район, село Земля...
# 2038   Продам участок г. Севастополь, Гагаринский рай...
# 23480  Продам свой земельный в Любимовке участок по у...
# 35245  Продается видовой участок 8,24 сот. В Севастоп...
# 25807          Продам земельный участок в горном районе.
# 15209  Земля в Крыму. Участок в Севастополе. Продам у...
#
#                               ts  area  is_IJS  priceM   priceMU  \
# 8815  2024-06-19 12:23:33.870565   5.0    True    3.65  0.730000
# 33862 2024-06-11 10:32:52.971878   4.0    True   10.00  2.500000
# 36097 2024-06-24 12:54:03.232729   4.0    True    4.75  1.187500
# 22834 2024-06-19 12:38:53.091938  44.0    True    4.80  0.109091
# 2038  2024-06-07 11:37:10.690720   4.0   False    1.85  0.462500
# 23480 2024-07-08 13:36:06.464523  10.0    True    2.00  0.200000
# 35245 2024-06-07 11:38:45.101812   8.2    True   31.50  3.841463
# 25807 2024-06-10 11:38:42.490270  68.0   False    1.25  0.018382
# 15209 2024-06-17 08:36:13.464806   5.0    True    4.10  0.820000
#
#       area_size_category
# 8815                 4-8
# 33862                2-4
# 36097                2-4
# 22834                20+
# 2038                 2-4
# 23480               8-12
# 35245               8-12
# 25807                20+
# 15209                4-8

# %% [markdown]
# ---

# %%
obj_type = 'house'
files = [ f'{d}/{f}' for d in source[obj_type] for f in listdir(d) if f[-4:]=='.pkl' ]
display( len(files) )

cols = ['url','place','title','subtitle','price','address','description','ts',]

df_house = pd.concat([
        pd.read_pickle(f).drop_duplicates(['url'])
        for f in files
    ]).reset_index(drop=True)[cols]

display( len(df_house) )
display(df_house.sample(9))
# Out:
# 55
# 35992
#                                                      url        place  \
# 16551      https://krym.cian.ru/sale/suburban/296633337/        sudak
# 10459  https://sevastopol.cian.ru/sale/suburban/29796...   sevastopol
# 32287                    https://www.avito.ru/3323410019   sevastopol
# 29227                    https://www.avito.ru/2199954481  bahchisaray
# 17931                    https://www.avito.ru/3879547737   sevastopol
# 20996                    https://www.avito.ru/1769071173   sevastopol
# 28057                    https://www.avito.ru/4144216073   sevastopol
# 10622  https://sevastopol.cian.ru/sale/suburban/30157...   sevastopol
# 3995   https://sevastopol.cian.ru/sale/suburban/28430...   sevastopol
#
#                                     title subtitle     price  \
# 16551         Дом, 75,9 м², 7.6 сот., ИЖС           10500000
# 10459  Дом, 172 м², 6.2 сот., Садоводство            9950000
# 32287      Дом 130 м² на участке 4,2 сот.      NaN   9000000
# 29227         Дом 80 м² на участке 5 сот.      NaN   5500000
# 17931      Дом 118 м² на участке 5,7 сот.      NaN  16000000
# 20996       Дом 42 м² на участке 3,8 сот.      NaN   6500000
# 28057      Дом 208,6 м² на участке 5 сот.      NaN   9800000
# 10622        Дом, 68,5 м², 17.8 сот., ИЖС            4300000
# 3995   Дом, 148,7 м², 4 сот., Садоводство            8500000
#
#                                                  address  \
# 16551      Республика Крым, Судак, улица Чалаш Смаил, 50
# 10459  Севастополь, р-н Нахимовский, Сапун-гора СНТ, ...
# 32287           садоводческое товарищество Нахимовец, 66
# 29227                      пгт. Куйбышево, Колхозная ул.
# 17931     садоводческое товарищество Верхний Сатурн, 345
# 20996                                     ул. Котовского
# 28057                     ТСН Родник, ул. Дмитрия Зюзина
# 10622  Севастополь, р-н Нахимовский, с. Верхнесадовое...
# 3995   Севастополь, р-н Гагаринский, Скиф садовое тов...
#
#                                              description  \
# 16551  Продается дом 75,9 м2 , на участке 7,6 соток О...
# 10459  Объект 15145. Продам дом в Нахимовском районе ...
# 32287  Продам новый дом! В доме два этажа плюс цоколь...
# 29227          Возможен обмен. На квартиру в Бахчисарае.
# 17931  Дом у моря! Дом построен из ракушечника. На пе...
# 20996  Продается частный дом (Ижс). Севастополь, Лени...
# 28057  Продаётся просторный кирпичный дом с 4 комната...
# 10622  Объект 12243. Продам участок с домом, в Севаст...
# 3995   Объект 188. Продается новый дом в СТ Скиф, Юха...
#
#                               ts
# 16551 2024-06-13 11:23:40.498702
# 10459 2024-06-18 10:55:44.416781
# 32287 2024-06-19 12:36:50.932990
# 29227 2024-06-13 11:37:16.726876
# 17931 2024-07-16 12:49:11.298800
# 20996 2024-06-13 11:32:06.964835
# 28057 2024-06-24 13:01:06.410833
# 10622 2024-06-18 10:55:44.416781
# 3995  2024-06-24 12:45:57.903825

# %%
# cols = ['title','address','place','url']
# df_house[ (df_house['place']=='sevastopol') & (df_house['address'].str.match(r'.*Судак.*')) ][cols]

# %%
from lib.cleaner import CleanerHouse

df_house = CleanerHouse().transform(df_house)

display( len(df_house) )
display(df_house.sample(9))
# Out:
# 35992
#                                                      url       place  \
# 14830  https://sevastopol.cian.ru/sale/suburban/28845...  sevastopol
# 28685                    https://www.avito.ru/3631346702  sevastopol
# 4496   https://sevastopol.cian.ru/sale/suburban/30107...  sevastopol
# 13044  https://sevastopol.cian.ru/sale/suburban/29858...  sevastopol
# 13182      https://krym.cian.ru/sale/suburban/288464653/       sudak
# 8575   https://sevastopol.cian.ru/sale/suburban/27807...  sevastopol
# 1467   https://sevastopol.cian.ru/sale/suburban/30248...  sevastopol
# 16328      https://krym.cian.ru/sale/suburban/302904239/       sudak
# 24117                    https://www.avito.ru/2416447063  sevastopol
#
#                                     title                      subtitle  \
# 14830        дом, 90,7 м², 8.79 сот., ижс
# 28685     дом 115,2 м² на участке 17 сот.                           NaN
# 4496     дом 87,6 кв.м., участок 7,43сот.  Дом, 87,6 м², 7.43 сот., ИЖС
# 13044  дом, 114 м², 3.3 сот., садоводство
# 13182            дом, 120 м², 4 сот., ижс
# 8575                 дом, 94 м², 3.5 сот.
# 1467              дом, 90 м², 4 сот., ижс
# 16328    дом, 150 м², 5 сот., садоводство
# 24117         дом 83 м² на участке 5 сот.                           NaN
#
#           price                                            address  \
# 14830   8200009  Севастополь, р-н Балаклавский, с. Штурмовое, п...
# 28685  10999000                       с. Вишнёвое, Садовая ул., 26
# 4496   16500000  Севастополь, р-н Нахимовский, мкр. Горпищенко,...
# 13044  11300000  Севастополь, р-н Гагаринский, Ветеран садоводч...
# 13182  22000000      Республика Крым, Судак, улица Юнус Кандым, 10
# 8575    4500000  Севастополь, р-н Балаклавский, Солнечный СНТСН...
# 1467   12000000       Севастополь, р-н Гагаринский, улица Липранди
# 16328  18400000  Республика Крым, Судак, Ветеран садовое товари...
# 24117   6899000                  садоводческое товарищество Гранат
#
#                                              description  \
# 14830  Продается в с. Штурмовое жилой 2-х эт дом по а...
# 28685  Предлагаем Вашему вниманию уникальное предложе...
# 4496   Продаётся Дом 87,6 кв.м., на участке 7,43 сото...
# 13044  Объект 508. Продается дом 114 м² на участке 3,...
# 13182  Продам дом 120 м2, 4 номера, участок 4 сотки К...
# 8575   Не упустите возможность стать обладателем дома...
# 1467   Новый дoм на Правой Гераклее Предложение от за...
# 16328  Объект 442. В посёлке "Ветеран" в городе Судак...
# 24117  Арт. 22919846 Продам дом в мини коттеджном пос...
#
#                               ts  house_area  is_part  is_townhouse  is_SNT  \
# 14830 2024-06-07 11:42:40.789431        90.7    False         False   False
# 28685 2024-06-24 13:01:06.410833       115.2    False         False    True
# 4496  2024-06-13 11:22:19.008525         0.0    False         False   False
# 13044 2024-07-08 14:05:28.543820       114.0    False         False    True
# 13182 2024-06-07 11:44:14.693655       120.0    False         False   False
# 8575  2024-06-19 12:37:23.275933        94.0    False         False    True
# 1467  2024-06-11 10:23:05.308675        90.0    False         False   False
# 16328 2024-07-08 14:11:37.044185       150.0    False         False    True
# 24117 2024-07-08 13:43:40.723717        83.0    False         False    True
#
#        land_area     priceM land_size_category house_size_category
# 14830      79.00   8.200009                20+              70-110
# 28685      17.00  10.999000              12-20             110-180
# 4496        7.43  16.500000                4-8                 NaN
# 13044       3.00  11.300000                2-4             110-180
# 13182       4.00  22.000000                2-4             110-180
# 8575        5.00   4.500000                4-8              70-110
# 1467        4.00  12.000000                2-4              70-110
# 16328       5.00  18.400000                4-8             110-180
# 24117       5.00   6.899000                4-8              70-110

# %% [markdown]
# ---

# %% [markdown]
# ## обновляем таблицу адресов

# %%
# !pip install geopy

# %%
from lib.locator import AddressTransformer

atr = AddressTransformer()

places = { 
# поле 'place' и название города
'bahchisaray': 'Бахчисарай,',
      'sudak': 'Судак,',
  'sevastopol': 'Севастополь,',
}

def address_norm(df,atr=atr):
    df['address_orig'] =  df['address']
    df['address'] =  df['address'].apply(atr.transform)
    df['place_'] =  df['place'].map(places)
    df['address'] = df[['address','place_']].apply(lambda d: d[0] if d[1] in d[0] else d[1]+','+d[0],axis=1) 
    df['address'] = (
        df['address']
        .str.replace(', ',',')
        .str.replace(',,',',')
        .str.replace('. ','.')
        .str.replace('\n',' ')
        .str.replace('  ',' ')
        .str.lower()
    )
    return df

# %%
df_flat = address_norm(df_flat)
df_land = address_norm(df_land)
df_house = address_norm(df_house)
# Out:
# /tmp/ipykernel_47806/776805188.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['address'] = df[['address','place_']].apply(lambda d: d[0] if d[1] in d[0] else d[1]+','+d[0],axis=1)
# /tmp/ipykernel_47806/776805188.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['address'] = df[['address','place_']].apply(lambda d: d[0] if d[1] in d[0] else d[1]+','+d[0],axis=1)
# /tmp/ipykernel_47806/776805188.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['address'] = df[['address','place_']].apply(lambda d: d[0] if d[1] in d[0] else d[1]+','+d[0],axis=1)

# %%
# df_flat[['address','address_orig']]

# %%
address = pd.concat([
        df_flat[['address','address_orig']],
        df_land[['address','address_orig']],
        df_house[['address','address_orig']],
    ]).drop_duplicates(['address']).reset_index(drop=True)

display(len(address))
display(address.sample(5))
# Out:
# 10998
#                                                  address  \
# 4641   севастополь,р-н гагаринский,мкр.фиолент,гранат...
# 10748                        севастополь,радужная ул.,12
# 5434                          севастополь,изумрудная ул.
# 7198   севастополь,р-н гагаринский,мкр.фиолент,корабе...
# 3348            севастополь,р-н нахимовский,мкр.учкуевка
#
#                                             address_orig
# 4641   Севастополь, р-н Гагаринский, мкр. Фиолент, Гр...
# 10748                                   Радужная ул., 12
# 5434                                      Изумрудная ул.
# 7198   Севастополь, р-н Гагаринский, мкр. Фиолент, Ко...
# 3348         Севастополь, р-н Нахимовский, мкр. Учкуевка

# %%
from os.path import exists as path_exists
loc_file_path = 'data/location.pkl' # таблица адресов

location = pd.DataFrame([],columns=['address','latitude','longitude',])
if path_exists( loc_file_path ):
    location = pd.read_pickle(loc_file_path).drop_duplicates(['address']).reset_index(drop=True)
    
display(len(location))
display(location.sample(5))
# Out:
# 17557
#                                                  address   latitude  longitude
# 16455  судак,с.миндальное,снт солнечная долина,спасск...  44.834101  35.059036
# 5369   севастополь,р-н гагаринский,мкр.летчики,улица ...  44.595221  33.463367
# 7008   севастополь,р-н нахимовский,мкр.красная горка,...  44.590901  33.531873
# 17373  судак,республика крым,судак городской округ,с....  44.823687  34.878537
# 11455  севастополь,садоводческое товарищество строите...  44.538208  33.472934

# %% [markdown]
# ---

# %%
# def address_norm_(df):
#     df['address_orig'] =  df['address']
#     # df['address'] =  df['address'].apply(atr.transform)
#     df['address'] = (
#         df['address']
#         .str.replace(', ',',')
#         .str.replace(',,',',')
#         .str.replace('. ','.')
#         .str.replace('\n',' ')
#         .str.replace('  ',' ')
#         .str.lower()
#     )
#     return df

# %%
# location = address_norm_(location)

# %%
# location = location[['address','latitude','longitude']]

# %% [markdown]
# ---

# %%
# собираем все адреса в один список
location = location.merge(
        address[['address']].drop_duplicates(),
        how='outer',
        on='address',
    ).drop_duplicates(['address']).reset_index(drop=True)

display(len(location))
display(location.sample(5))
# Out:
# 17934
#                                                  address   latitude  longitude
# 2109   севастополь,гагаринский район ,казачья бухта,р...  44.570202  33.405992
# 3556            севастополь,переулок генерала мельника,1   44.58244  33.557744
# 16224                севастополь,улица надежды краевой,5  44.631346  33.542572
# 3657   севастополь,пос.городского типа кача,ул.авиато...  44.791636  33.540775
# 17379  судак,республика крым,судак городской округ,с....  44.938074  34.954544

# %%
display(len(location))
display(location['latitude'].isnull().sum())
# Out:
# 17934
# 377

# %%
# собираем все адреса с геопозицией
location_def = location[~location['latitude'].isna()].reset_index(drop=True)
display(len(location_def))

# собираем все адреса без геопозиции
location_undef = location[location['latitude'].isna()][['address']].reset_index(drop=True)
display(len(location_undef))
# Out:
# 17557
# 377

# %%
display(location_undef)
# Out:
#                                    address
# 0            бахчисарай,бельбекская ул.,46
# 1                 бахчисарай,заводская ул.
# 2         бахчисарай,квартал седьмая балка
# 3                         бахчисарай,керчь
# 4    бахчисарай,коттеджный пос.светлый мир
# ..                                     ...
# 372  судак,с.солнечная долина,ул.эким-кара
# 373      судак,ст меганом,чебрецовая ул.,4
# 374                        судак,ул.ювес,5
# 375             судак,улица айвазовского,6
# 376                судак,улица бирюзова,2а
#
# [377 rows x 1 columns]

# %%
from tqdm.auto import tqdm
tqdm.pandas()

# %%
# from lib.locator import GeocoderSimpleOSM
from lib.locator import GeocoderYandex
from yandex_keys import keys

atr = AddressTransformer()
locator = GeocoderYandex(keys[0])
# locator = GeocoderSimpleOSM()

if len(location_undef)>0:
    # определяем координаты по строке адреса
    location_undef = location_undef.join( 
            location_undef['address'].progress_apply(locator.transform).apply(pd.Series) 
        ).dropna()     
    display(f'LocationUpdater: {len(location_undef)} new addresses found')
    location = pd.concat([location_def,location_undef]).reset_index(drop=True) 
    assert len(location)>0
    # location.to_pickle(loc_file_path)
# Out:
#   0%|          | 0/377 [00:00<?, ?it/s]
# 'LocationUpdater: 377 new addresses found'

# %%
display( len(location) )
display( location.sample(3) )
# Out:
# 17934
#                                                 address   latitude  longitude
# 2235  севастополь,жилищно-строительное товарищество ...  44.567319  33.483391
# 5711  севастополь,р-н гагаринский,мкр.стрелецкая бух...  44.598706  33.493173
# 4264  севастополь,р-н балаклавский,гавань садовое то...  44.582844  33.597099

# %%
assert len(location)>0
location.to_pickle(loc_file_path)

# %% [markdown]
# ## дополняем данные геометкой

# %%
display( len(df_flat) )
df_flat  = df_flat.merge(location,on='address').reset_index(drop=True) 
display( len(df_flat) )
display( df_flat.sample(3) )
# Out:
# 41619
# 41619
#                                    url       place  \
# 18400  https://www.avito.ru/4202385609       sudak
# 24402  https://www.avito.ru/3999455586  sevastopol
# 30333  https://www.avito.ru/4090956819  sevastopol
#
#                                       title subtitle    price  \
# 18400       2-к. квартира, 43,4 м², 2/3 эт.      NaN  4600000
# 24402  апартаменты-студия, 57,2 м², 4/7 эт.      NaN  9040760
# 30333         2-к. квартира, 45 м², 5/5 эт.      NaN  7950000
#
#                                                  address  \
# 18400       судак,село краснокаменка,крымская улица ,15а
# 24402  севастополь,комплекс апартаментов «акватория» ...
# 30333                   севастополь,улица вакуленчука,25
#
#                                              description  \
# 18400  Продается уютная квартира в живописной Краснок...
# 24402  Акционное Предложение. На Этапе Сдачи. Новый К...
# 30333  Продаётся 2-х комнатная квартира на 5 м этаже ...
#
#                               ts  nrooms  floor  ...  is_auction  \
# 18400 2024-06-13 11:33:20.210428       2      2  ...       False
# 24402 2024-07-16 12:34:38.165543       0      4  ...       False
# 30333 2024-06-14 13:06:45.993553       2      5  ...       False
#
#        is_openspace  is_roof  is_SNT   priceM  is_last_floor  \
# 18400         False    False   False  4.60000          False
# 24402         False    False   False  9.04076          False
# 30333         False    False   False  7.95000           True
#
#                                             address_orig        place_  \
# 18400           село Краснокаменка, Крымская улица , 15А        Судак,
# 24402  Комплекс апартаментов «Акватория»\n улица Пляж...  Севастополь,
# 30333                              улица Вакуленчука, 25  Севастополь,
#
#         latitude  longitude
# 18400  44.923391  35.074918
# 24402  44.597666   33.44135
# 30333  44.592519  33.488313
#
# [3 rows x 25 columns]

# %%
display( len(df_land) )
df_land  = df_land.merge(location,on='address').reset_index(drop=True) 
display( len(df_land) )
display( df_land.sample(3) )
# Out:
# 37019
# 37019
#                                                      url       place  \
# 10531  https://sevastopol.cian.ru/sale/suburban/30272...  sevastopol
# 5652   https://sevastopol.cian.ru/sale/suburban/25740...  sevastopol
# 17114                    https://www.avito.ru/4069141030  sevastopol
#
#                                    title                       subtitle  \
# 10531       участок, 4 сот., садоводство
# 5652   купить участок в севастополе. про  Участок, 10 сот., Садоводство
# 17114               участок 8 сот. (ижс)                            NaN
#
#          price                                            address  \
# 10531  4500000  севастополь,р-н балаклавский,берег садоводческ...
# 5652   3500000  севастополь,р-н нахимовский,лукулл садовое тов...
# 17114  3100000                              севастополь,с.полюшко
#
#                                              description  \
# 10531  Продаётся участок 4 сотки в самом востребованн...
# 5652   Продаётся видовой земельный участок 10 соток в...
# 17114  Продается. Участок 8 соток Ижс в районе Орловк...
#
#                               ts  area  is_IJS  priceM  priceMU  \
# 10531 2024-06-18 10:50:11.786732   4.0   False     4.5   1.1250
# 5652  2024-06-24 12:40:23.850839   0.0   False     3.5      inf
# 17114 2024-06-10 11:25:16.532576   8.0    True     3.1   0.3875
#
#       area_size_category                                       address_orig  \
# 10531                2-4  Севастополь, р-н Балаклавский, Берег садоводче...
# 5652                 NaN  Севастополь, р-н Нахимовский, Лукулл садовое т...
# 17114                4-8                                         с. Полюшко
#
#              place_   latitude  longitude
# 10531  Севастополь,  44.505219  33.492284
# 5652   Севастополь,  44.836568  33.556648
# 17114  Севастополь,  44.734471  33.579007

# %%
display( len(df_house) )
df_house = df_house.merge(location,on='address').reset_index(drop=True) 
display( len(df_house) )
display( df_house.sample(3) )
# Out:
# 35992
# 35992
#                                                      url       place  \
# 26558                    https://www.avito.ru/3886841407  sevastopol
# 13416  https://sevastopol.cian.ru/sale/suburban/27657...  sevastopol
# 31356                    https://www.avito.ru/4050005884       sudak
#
#                                     title subtitle     price  \
# 26558      дом 107 м² на участке 4,1 сот.      NaN   7777777
# 13416  дом, 55 м², 3.53 сот., садоводство            3500000
# 31356       дом 618 м² на участке 12 сот.      NaN  25000000
#
#                                                  address  \
# 26558  севастополь,садоводческое некоммерческое товар...
# 13416  севастополь,р-н балаклавский,балаклава г.,благ...
# 31356                              судак,ореховый б-р,15
#
#                                              description  \
# 26558  Продаю cвoй дом на участке 4.11, а по факту 4....
# 13416  Дом 55 м2 на участке 3,7 сотки Жилой дом 55 м2...
# 31356  Продается шикарный, большой дом. Дом 3 этажный...
#
#                               ts  house_area  is_part  is_townhouse  is_SNT  \
# 26558 2024-06-11 10:41:08.345000       107.0    False         False    True
# 13416 2024-06-14 13:06:13.997742        55.0    False         False    True
# 31356 2024-07-16 12:51:56.145878       618.0    False         False   False
#
#        land_area     priceM land_size_category house_size_category  \
# 26558        4.1   7.777777                4-8              70-110
# 13416       53.0   3.500000                20+               50-70
# 31356       12.0  25.000000               8-12                300+
#
#                                             address_orig        place_  \
# 26558  садоводческое некоммерческое товарищество Клеры-3  Севастополь,
# 13416  Севастополь, р-н Балаклавский, Балаклава г., Б...  Севастополь,
# 31356                                   Ореховый б-р, 15        Судак,
#
#         latitude  longitude
# 26558  44.554506     33.469
# 13416  44.504242  33.621219
# 31356   44.84981  34.989237

# %%
def address_filter(df):
    #           46.319437, 33.911048
    #
    # 45.402617, 32.455625 |  45.545301, 36.684702
    #
    #          44.320887, 33.917013

    df['latitude'] = pd.to_numeric( df['latitude'], errors='coerce' )
    df['longitude'] = pd.to_numeric( df['longitude'], errors='coerce' )

    df = df.query('(32.4<longitude<36.7) & (44.3<latitude<46.4)') 

    df.loc[ df['url']=='https://avito.ru/2322251740', ['latitude','longitude']] = None

    df.loc[ df['address']=='Севастополь,Чёрное море', ['latitude','longitude'] ] = None
    df.loc[ df['address'].str.lower().str.match('чёрное море'), ['latitude','longitude'] ] = None 

    df.loc[ df['address']=='квартал Старый Город', 'place'] = 'turkie'
    df.loc[ df['address'].str.lower().str.match('анталья'), 'place' ] = 'turkie' 

    df.loc[ df['address'].str.lower().str.match(r'.*бахчисарай.*'), 'place' ] = 'bahchisaray'
    df.loc[ df['address'].str.lower().str.match(r'.*севастополь,.*'), 'place' ] = 'sevastopol'

    df.loc[ df['address'].str.lower().str.match(r'.*мысовское.*'), 'place' ] = 'kerch'
    df.loc[ df['address'].str.lower().str.match(r'.*алушта.*'), 'place' ] = 'alushta'
    df.loc[ df['address'].str.lower().str.match(r'.*гурзуф.*'), 'place' ] = 'gurzuf'

    df.loc[ df['address'].str.lower().str.match(r'.*с.лучистое.*'), 'place' ] = 'alushta'
    df.loc[ df['address'].str.lower().str.match(r'.*снт солнечная долина.*'), 'place' ] = 'sudak'
    df.loc[ df['address'].str.lower().str.match(r'.*пгт.новоозёрное.*'), 'place' ] = 'evpatoria'

    df.loc[ df['address'].str.lower().str.match(r'.*с.мирное.*'), 'place' ] = 'simferopol'
    df.loc[ df['address'].str.lower().str.match(r'.*тсн аэрофлот.*'), 'place' ] = 'simferopol'

    df.loc[ df['address'].str.lower().str.match(r'.*семисот.*'), 'place' ] = 'kerch'

    df.loc[ df['address'].str.lower().str.match(r'.*ялта.*') , 'place' ] = 'yalta'
    df.loc[ df['address'].str.lower().str.match(r'.*феодосия.*') , 'place' ] = 'feodosia'
    df.loc[ df['address'].str.lower().str.match(r'.*окуневка.*') , 'place' ] = 'tarkhankut'
    df.loc[ df['address'].str.lower().str.match(r'.*заветное.*') , 'place' ] = 'kerch'
    df.loc[ df['address'].str.lower().str.match(r'.*евпатория.*') , 'place' ] = 'evpatoria'
    df.loc[ df['address'].str.lower().str.match(r'.*симферопольский район.*'), 'place' ] = 'simferopol'

    df = df.dropna(subset=['latitude','longitude'])
    
    return df

# %%
display(len(df_flat))
df_flat = address_filter(df_flat)
display(len(df_flat))

display(len(df_land))
df_land = address_filter(df_land)
display(len(df_land))

display(len(df_house))
df_house = address_filter(df_house)
display(len(df_house))
# Out:
# 41619
# 41160
# 37019
# 37001
# 35992
# 35991

# %%
assert len(df_flat)>0
df_flat.to_pickle(f'{data_root_folder}/df_flat.pkl')

assert len(df_land)>0
df_land.to_pickle(f'{data_root_folder}/df_land.pkl')

assert len(df_house)>0
df_house.to_pickle(f'{data_root_folder}/df_house.pkl')

# %%
# !date
# Out:
# Вт 16 июл 2024 12:59:13 MSK
