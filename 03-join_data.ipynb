_apartment  is_part  is_auction  is_openspace  is_roof  is_SNT  \
# 5117          False    False       False         False    False   False
# 2871          False    False       False         False    False   False
# 19481         False    False       False         False    False   False
# 26552          True    False       False         False    False   False
# 23161          True    False       False         False    False   False
# 13145         False    False       False         False    False   False
# 18671         False    False       False         False    False   False
# 1430           True    False       False         False    False   False
# 7854          False    False       False         False    False   False
#
#         priceM  is_last_floor
# 5117   26.7536          False
# 2871    4.6000          False
# 19481   6.7000          False
# 26552   7.5000          False
# 23161   4.9000          False
# 13145   5.8000           True
# 18671   8.4000          False
# 1430    4.5000          False
# 7854    8.9900           True
#
# [9 rows x 21 columns]

# %% [markdown]
# ---

# %%
obj_type = 'land'
files = [ f'{d}/{f}' for d in source[obj_type] for f in listdir(d) if f[-4:]=='.pkl' ]
display( len(files) )

cols = ['url','place','title','subtitle','price','address','description','ts',]

df_land = pd.concat([
        pd.read_pickle(f).drop_duplicates(['url'])
        for f in files
    ]).reset_index(drop=True)[cols]

display( len(df_land) )
display(df_land.sample(9))
# Out:
# 50
# 34591
#                                                      url        place  \
# 24044                    https://www.avito.ru/2476342385   sevastopol
# 20176                    https://www.avito.ru/4274515717  bahchisaray
# 15237                    https://www.avito.ru/4102353854   sevastopol
# 27742                    https://www.avito.ru/2315601392  bahchisaray
# 30973                    https://www.avito.ru/3795949698   sevastopol
# 10166  https://sevastopol.cian.ru/sale/suburban/30120...   sevastopol
# 22542                     https://www.avito.ru/588056794  bahchisaray
# 21005                    https://www.avito.ru/4513812185   sevastopol
# 21677                    https://www.avito.ru/2375997769   sevastopol
#
#                               title subtitle     price  \
# 24044   Участок 9,3 сот. (СНТ, ДНП)      NaN   2000000
# 20176      Участок 30 га (СНТ, ДНП)      NaN  30000000
# 15237          Участок 8 сот. (ИЖС)      NaN   5200000
# 27742     Участок 1,5 га (СНТ, ДНП)      NaN    600000
# 30973         Участок 10 сот. (ИЖС)      NaN   5400000
# 10166  Участок, 4 сот., Садоводство            3300000
# 22542     Участок 1 сот. (СНТ, ДНП)      NaN    800000
# 21005         Участок 10 сот. (ИЖС)      NaN   4600000
# 21677        Участок 5,1 сот. (ИЖС)      NaN   2900000
#
#                                                  address  \
# 24044                    пос. Кача, ул. Авиаторов, 1Г/17
# 20176                                        с. Холмовка
# 15237                                         с. Полюшко
# 27742                                    с. Белокаменное
# 30973                                       Редутная ул.
# 10166  Севастополь, р-н Гагаринский, Икар-2 садоводче...
# 22542                                        с. Долинное
# 21005                               Крепостное ш., 23к18
# 21677                                         ТСН Родник
#
#                                              description  \
# 24044  Собственник! Продается классный участок в Каче...
# 20176  Продам видовые, земельные участки в респ. Крым...
# 15237  В продаже два смежных участка по 4 сотки=8сото...
# 27742  Сельхоззначения участок 1,5 гектара. С понарам...
# 30973  Учаcток 10 сoток (Ижс) в г. Севастополь, Редут...
# 10166  Продам участок площадью 4 сотки в Гагаринском ...
# 22542  Участок находится между с. Фурмановка и с. Кра...
# 21005  Объект №381. Доброго времени суток, предложени...
# 21677  Продам Земельный Участок в черте города! СТ Ро...
#
#                               ts
# 24044 2024-06-14 13:13:27.377070
# 20176 2024-06-07 12:09:12.165236
# 15237 2024-06-17 08:36:13.464806
# 27742 2024-06-24 13:05:30.092315
# 30973 2024-06-11 10:32:52.971878
# 10166 2024-06-18 10:50:11.786732
# 22542 2024-06-17 08:47:28.297455
# 21005 2024-07-08 13:36:06.464523
# 21677 2024-07-08 13:36:06.464523

# %%
from lib.cleaner import CleanerLand

df_land = CleanerLand().transform(df_land)

display( len(df_land) )
display(df_land.sample(9))
# Out:
#
# %%
from os.path import exists as path_exists
loc_file_path = 'data/location.pkl' # таблица адресов

location = pd.DataFrame([],columns=['address','latitude','longitude',])
if path_exists( loc_file_path ):
    location = pd.read_pickle(loc_file_path).drop_duplicates(['address']).reset_index(drop=True)
    
display(len(location))
display(location.sample(5))
# Out:
# 16695
#                                                  address   latitude  longitude
# 13472                         севастополь,ул.декабристов  44.596864  33.497898
# 7646   севастополь,район балаклавский,инкерман,улица ...  44.615962  33.603073
# 13671                  севастополь,ул.николая ехлакова,2  44.602583  33.578855
# 13584                           севастополь,ул.ленина,41  44.603256  33.526824
# 9097   севастополь,район нахимовский,улица горпищенко...  44.579776  33.579007

# %% [markdown]
# ---

# %%
# def address_norm_(df):
#     df['address_orig'] =  df['address']
#     # df['address'] =  df['address'].apply(atr.transform)
#     df['address'] = (
#         df['address']
#         .str.replace(', ',',')
#         .str.replace(',,',',')
#         .str.replace('. ','.')
#         .str.replace('\n',' ')
#         .str.replace('  ',' ')
#         .str.lower()
#     )
#     return df

# %%
# location = address_norm_(location)

# %%
# location = location[['address','latitude','longitude']]

# %% [markdown]
# ---

# %%
# собираем все адреса в один список
location = location.merge(
        address[['address']].drop_duplicates(),
        how='outer',
        on='address',
    ).drop_duplicates(['address']).reset_index(drop=True)

display(len(location))
display(location.sample(5))
# Out:
# 17557
#                                                  address   latitude  longitude
# 13313    севастополь,ст энергетик-2,ул.летчика кирсанова  44.574357   33.59347
# 13951                          севастополь,узловая улица  44.593822   33.60381
# 13820                  севастополь,тсн ст морзаводец,256  44.544626  33.569602
# 2773   севастополь,ленинский район ,жилой комплекс до...  44.579474  33.505983
# 2926                     севастополь,митридатская ул.,12  44.560685  33.464805

# %%
display(len(location))
display(location['latitude'].isnull().sum())
# Out:
# 17557
# 862

# %%
# собираем все адреса с геопозицией
location_def = location[~location['latitude'].isna()].reset_index(drop=True)
display(len(location_def))

# собираем все адреса без геопозиции
location_undef = location[location['latitude'].isna()][['address']].reset_index(drop=True)
display(len(location_undef))
# Out:
# 16695
# 862

# %%
display(location_undef)
# Out:
#                                        address
# 0                           бахчисарай,35н-806
# 1                 бахчисарай,гурзуфская ул.,83
# 2                  бахчисарай,загородная ул.,1
# 3                      бахчисарай,новая ул.,15
# 4    бахчисарай,пгт.куйбышево,колхозная ул.,12
# ..                                         ...
# 857                     судак,ул.якова кушнира
# 858                    судак,улица бирюзова,22
# 859                      судак,улица ленина,34
# 860                       судак,улица чехова,1
# 861                  судак,южнобережная ул.,76
#
# [862 rows x 1 columns]

# %%
from tqdm.auto import tqdm
tqdm.pandas()

# %%
# from lib.locator import GeocoderSimpleOSM
from lib.locator import GeocoderYandex
from yandex_keys import keys

atr = AddressTransformer()
locator = GeocoderYandex(keys[0])
# locator = GeocoderSimpleOSM()

if len(location_undef)>0:
    # определяем координаты по строке адреса
    location_undef = location_undef.join( 
            location_undef['address'].progress_apply(locator.transform).apply(pd.Series) 
        ).dropna()     
    display(f'LocationUpdater: {len(location_undef)} new addresses found')
    location = pd.concat([location_def,location_undef]).reset_index(drop=True) 
    assert len(location)>0
    # location.to_pickle(loc_file_path)
# Out:
#   0%|          | 0/862 [00:00<?, ?it/s]
# 'LocationUpdater: 862 new addresses found'

# %%
display( len(location) )
display( location.sample(3) )
# Out:
# 17557
#                                                  address   latitude  longitude
# 14561           севастополь,улица военных строителей,5к3  44.566786   33.40689
# 1992   севастополь,гагаринский район ,казачья бухта,р...  44.565713  33.409603
# 14931              севастополь,улица дмитрия ульянова,20  44.605734  33.493066

# %%
assert len(location)>0
location.to_pickle(loc_file_path)

# %% [markdown]
# ## дополняем данные геометкой

# %%
display( len(df_flat) )
df_flat  = df_flat.merge(location,on='address').reset_index(drop=True) 
display( len(df_flat) )
display( df_flat.sample(3) )
# Out:
# 38661
# 38661
#                                                    url       place  \
# 4740   https://sevastopol.cian.ru/sale/flat/303095429/  sevastopol
# 19361                  https://www.avito.ru/3955755114       sudak
# 29381                  https://www.avito.ru/2329220416  sevastopol
#
#                                      title subtitle     price  \
# 4740   2-комн. квартира, 48,5 м², 2/5 этаж            6500000
# 19361   2-к. апартаменты, 55,6 м², 3/8 эт.      NaN  14720750
# 29381      1-к. квартира, 46,5 м², 3/6 эт.      NaN   9000000
#
#                                                  address  \
# 4740   севастополь,р-н ленинский,мкр.острякова,улица ...
# 19361  судак,апарт-отель «атлас араrt ноtеl & sра» ул...
# 29381                севастополь,улица астана кесаева,14
#
#                                              description  \
# 4740   Продам двухкомнатную брежневку на 2м этаже пят...
# 19361  В апарт-комплексе уже сдана и введена в эксплу...
# 29381  Однокомнатная квартира 46,5 м2 на 3/6 этаже до...
#
#                               ts  nrooms  floor  ...  is_auction  \
# 4740  2024-06-14 12:56:14.435965       0      2  ...       False
# 19361 2024-06-10 11:35:05.787844       2      3  ...       False
# 29381 2024-06-14 13:06:45.993553       1      3  ...       False
#
#        is_openspace  is_roof  is_SNT    priceM  is_last_floor  \
# 4740          False    False   False   6.50000          False
# 19361         False    False   False  14.72075          False
# 29381         False    False   False   9.00000          False
#
#                                             address_orig        place_  \
# 4740   Севастополь, р-н Ленинский, мкр. Острякова, ул...  Севастополь,
# 19361  Апарт-отель «Атлас Apart Hotel & Spa»\n улица ...        Судак,
# 29381                           улица Астана Кесаева, 14  Севастополь,
#
#         latitude  longitude
# 4740   44.569335  33.527588
# 19361  34.025651  -6.839395
# 29381  44.588173   33.45557
#
# [3 rows x 25 columns]

# %%
display( len(df_land) )
df_land  = df_land.merge(location,on='address').reset_index(drop=True) 
display( len(df_land) )
display( df_land.sample(3) )
# Out:
# 34591
# 34591
#                                                      url       place  \
# 22265                    https://www.avito.ru/4031932861  sevastopol
# 7980   https://sevastopol.cian.ru/sale/suburban/29661...  sevastopol
# 3072       https://krym.cian.ru/sale/suburban/278610899/       sudak
#
#                                  title subtitle     price  \
# 22265           участок 8,7 сот. (ижс)      NaN  10000000
# 7980            участок, 7.8 сот., ижс            7000000
# 3072   участок, 10.4 сот., садоводство            4500000
#
#                                                  address  \
# 22265           севастополь,с.ушаково,ул.котляревского,6
# 7980            севастополь,р-н балаклавский,союз тсн,6а
# 3072   судак,республика крым,судак городской округ,с....
#
#                                              description  \
# 22265  Участок 8,7 соток (Ижс) в г. Севастополь, Лени...
# 7980   Участок 8 соток (СТ) в г. Севастополь, Балакла...
# 3072   Продается земельный участок в 300 метрах от пл...
#
#                               ts  area  is_IJS  priceM   priceMU  \
# 22265 2024-07-08 13:36:06.464523   8.7    True    10.0  1.149425
# 7980  2024-06-19 12:23:33.870565   8.0    True     7.0  0.875000
# 3072  2024-07-08 14:07:49.322937   4.0   False     4.5  1.125000
#
#       area_size_category                                       address_orig  \
# 22265               8-12                   с. Ушаково, ул. Котляревского, 6
# 7980                 4-8        Севастополь, р-н Балаклавский, Союз ТСН, 6А
# 3072                 2-4  Республика Крым, Судак городской округ, с. При...
#
#              place_   latitude  longitude
# 22265  Севастополь,  44.542693  33.546228
# 7980   Севастополь,  44.509784  33.521336
# 3072         Судак,  44.859963  35.135078

# %%
display( len(df_house) )
df_house = df_house.merge(location,on='address').reset_index(drop=True) 
display( len(df_house) )
display( df_house.sample(3) )
# Out:
# 32965
# 32965
#                                                      url       place  \
# 11018  https://sevastopol.cian.ru/sale/suburban/28856...  sevastopol
# 6917   https://sevastopol.cian.ru/sale/suburban/29826...  sevastopol
# 4897   https://sevastopol.cian.ru/sale/suburban/29022...  sevastopol
#
#                                       title                  subtitle  \
# 11018                    хозяин продает дом  Дом, 110 м², 6 сот., ИЖС
# 6917   дом, 169,2 м², 2.9 сот., садоводство
# 4897                    дом, 210 м², 5 сот.
#
#           price                                            address  \
# 11018  10300000       севастополь,р-н балаклавский,родник тсн,1б/6
# 6917    6200000  севастополь,р-н ленинский,тополек садовое това...
# 4897   34500000  севастополь,р-н гагаринский,рыбак-5 садовое то...
#
#                                              description  \
# 11018  Продам одноэтажный дом новой постройки. В доме...
# 6917   Объект 1437. K продaжe 1/2 дома на участкe 3 с...
# 4897   Дом 210 м² на участке 5 соток Дом 210 м² на уч...
#
#                               ts  house_area  is_part  is_townhouse  is_SNT  \
# 11018 2024-07-08 14:05:28.543820         0.0    False         False    True
# 6917  2024-06-10 11:23:47.056251       169.2     True         False    True
# 4897  2024-06-13 11:22:19.008525       210.0    False         False    True
#
#        land_area  priceM land_size_category house_size_category  \
# 11018        0.0    10.3                NaN                 NaN
# 6917         9.0     6.2               8-12             110-180
# 4897         5.0    34.5                4-8             180-300
#
#                                             address_orig        place_  \
# 11018    Севастополь, р-н Балаклавский, Родник ТСН, 1Б/6  Севастополь,
# 6917   Севастополь, р-н Ленинский, Тополек садовое то...  Севастополь,
# 4897   Севастополь, р-н Гагаринский, Рыбак-5 садовое ...  Севастополь,
#
#         latitude  longitude
# 11018  44.542712  33.556864
# 6917   44.561391  33.533723
# 4897   44.574575  33.454734

# %%
def address_filter(df):
    #           46.319437, 33.911048
    #
    # 45.402617, 32.455625 |  45.545301, 36.684702
    #
    #          44.320887, 33.917013

    df['latitude'] = pd.to_numeric( df['latitude'], errors='coerce' )
    df['longitude'] = pd.to_numeric( df['longitude'], errors='coerce' )

    df = df.query('(32.4<longitude<36.7) & (44.3<latitude<46.4)') 

    df.loc[ df['url']=='https://avito.ru/2322251740', ['latitude','longitude']] = None

    df.loc[ df['address']=='Севастополь,Чёрное море', ['latitude','longitude'] ] = None
    df.loc[ df['address'].str.lower().str.match('чёрное море'), ['latitude','longitude'] ] = None 

    df.loc[ df['address']=='квартал Старый Город', 'place'] = 'turkie'
    df.loc[ df['address'].str.lower().str.match('анталья'), 'place' ] = 'turkie' 

    df.loc[ df['address'].str.lower().str.match(r'.*бахчисарай.*'), 'place' ] = 'bahchisaray'
    df.loc[ df['address'].str.lower().str.match(r'.*севастополь,.*'), 'place' ] = 'sevastopol'

    df.loc[ df['address'].str.lower().str.match(r'.*мысовское.*'), 'place' ] = 'kerch'
    df.loc[ df['address'].str.lower().str.match(r'.*алушта.*'), 'place' ] = 'alushta'
    df.loc[ df['address'].str.lower().str.match(r'.*гурзуф.*'), 'place' ] = 'gurzuf'

    df.loc[ df['address'].str.lower().str.match(r'.*с.лучистое.*'), 'place' ] = 'alushta'
    df.loc[ df['address'].str.lower().str.match(r'.*снт солнечная долина.*'), 'place' ] = 'sudak'
    df.loc[ df['address'].str.lower().str.match(r'.*пгт.новоозёрное.*'), 'place' ] = 'evpatoria'

    df.loc[ df['address'].str.lower().str.match(r'.*с.мирное.*'), 'place' ] = 'simferopol'
    df.loc[ df['address'].str.lower().str.match(r'.*тсн аэрофлот.*'), 'place' ] = 'simferopol'

    df.loc[ df['address'].str.lower().str.match(r'.*семисот.*'), 'place' ] = 'kerch'

    df.loc[ df['address'].str.lower().str.match(r'.*ялта.*') , 'place' ] = 'yalta'
    df.loc[ df['address'].str.lower().str.match(r'.*феодосия.*') , 'place' ] = 'feodosia'
    df.loc[ df['address'].str.lower().str.match(r'.*окуневка.*') , 'place' ] = 'tarkhankut'
    df.loc[ df['address'].str.lower().str.match(r'.*заветное.*') , 'place' ] = 'kerch'
    df.loc[ df['address'].str.lower().str.match(r'.*евпатория.*') , 'place' ] = 'evpatoria'
    df.loc[ df['address'].str.lower().str.match(r'.*симферопольский район.*'), 'place' ] = 'simferopol'

    df = df.dropna(subset=['latitude','longitude'])
    
    return df

# %%
display(len(df_flat))
df_flat = address_filter(df_flat)
display(len(df_flat))

display(len(df_land))
df_land = address_filter(df_land)
display(len(df_land))

display(len(df_house))
df_house = address_filter(df_house)
display(len(df_house))
# Out:
# 38661
# 38247
# 34591
# 34576
# 32965
# 32964

# %%
assert len(df_flat)>0
df_flat.to_pickle(f'{data_root_folder}/df_flat.pkl')

assert len(df_land)>0
df_land.to_pickle(f'{data_root_folder}/df_land.pkl')

assert len(df_house)>0
df_house.to_pickle(f'{data_root_folder}/df_house.pkl')

# %%
# !date
# Out:
# Пн 08 июл 2024 14:29:38 MSK
