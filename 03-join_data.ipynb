# %% [markdown]
# __собираем объявления о продаже недвижимости в одну таблицу__
#
# _Evgeny S. Borisov <parser@mechanoid.su>_

# %%
# !date
# Out:
# Вт 24 сен 2024 11:08:26 MSK

# %%
from os import listdir
import re
import pandas as pd

# %%
data_root_folder = 'data/2024'
source = {
         'flat':[data_root_folder+'/raw/flat/cian',data_root_folder+'/raw/flat/avito'],
        'house':[data_root_folder+'/raw/house/cian',data_root_folder+'/raw/house/avito'],
         'land':[data_root_folder+'/raw/land/cian',data_root_folder+'/raw/land/avito'],
    }

# %% [markdown]
# ---

# %%
obj_type = 'flat'
files = [ f'{d}/{f}' for d in source[obj_type] for f in listdir(d) if f[-4:]=='.pkl' ]
display( len(files) )

cols = ['url','place','title','subtitle','price','address','description','ts',]

df_flat = pd.concat([
        pd.read_pickle(f).drop_duplicates(['url'])
        for f in files
    ]).reset_index(drop=True)[cols]

display( len(df_flat) )
display(df_flat.sample(9))
# Out:
# 84
# 76539
#                                                    url       place  \
# 8452   https://sevastopol.cian.ru/sale/flat/302327246/  sevastopol
# 23143  https://sevastopol.cian.ru/sale/flat/298638496/  sevastopol
# 55347                  https://www.avito.ru/4135076440  sevastopol
# 62764                  https://www.avito.ru/3901327387  sevastopol
# 754    https://sevastopol.cian.ru/sale/flat/304382064/  sevastopol
# 73816                  https://www.avito.ru/3470844437  sevastopol
# 68079                  https://www.avito.ru/3049509336  sevastopol
# 72986                  https://www.avito.ru/4259228678  sevastopol
# 52849                  https://www.avito.ru/4172697130  sevastopol
#
#                                        title  \
# 8452       1-комн. квартира, 32 м², 3/5 этаж
# 23143    2-комн. квартира, 63,8 м², 1/9 этаж
# 55347        1-к. квартира, 40,8 м², 3/9 эт.
# 62764     Апартаменты-студия, 24 м², 1/4 эт.
# 754    1-комн. квартира, 44,4 м², 10/10 этаж
# 73816      Квартира-студия, 23,5 м², 1/2 эт.
# 68079          2-к. квартира, 55 м², 6/9 эт.
# 72986     1-к. апартаменты, 34,8 м², 2/5 эт.
# 52849        1-к. квартира, 29,6 м², 2/5 эт.
#
#                                   subtitle     price  \
# 8452                                         6250000
# 23143  Секция 2 • Сдача корпуса 4 кв. 2024   9000000
# 55347                                  NaN   5800000
# 62764                                  NaN   4200000
# 754                                   Сдан  17973120
# 73816                                  NaN   3950000
# 68079                                  NaN   7100000
# 72986                                  NaN   9990000
# 52849                                  NaN   5380000
#
#                                                  address  \
# 8452   Севастополь, р-н Гагаринский, мкр. 5-й, улица ...
# 23143  Севастополь, р-н Гагаринский, улица Братьев Ма...
# 55347                       пр-т Генерала Острякова, 154
# 62764             коттеджный пос. Вилларис дель Мар, 105
# 754     Севастополь, р-н Гагаринский, улица Парковая, 15
# 73816                 Севастополь, Предместная улица, 44
# 68079                        пр-т Генерала Острякова, 98
# 72986       Апарт-комплекс «GARDEN»\nул. Лётчиков, д. 10
# 52849                        пр-т Генерала Острякова, 42
#
#                                              description  \
# 8452   Продается 1-к квартира в Гагаринском районе От...
# 23143  Продаётся 2-комнатная квартира 28, площадь 63,...
# 55347  Просторная светлая квартира с квадратной комна...
# 62764  Продам апартаменты у самого берега моря. Свой ...
# 754
# 73816  В продаже квартира-студия с отличным ремонтом ...
# 68079  Представляем вашему вниманию двухкомнатную ква...
# 72986  Апарт-комплекс Garden — отличное решение для ж...
# 52849  Однокомнатная квартира на втором этаже, в сере...
#
#                               ts
# 8452  2024-06-11 10:13:23.305322
# 23143 2024-06-18 10:45:27.403294
# 55347 2024-07-30 16:15:15.853171
# 62764 2024-06-14 13:06:45.993553
# 754   2024-07-22 10:58:46.776952
# 73816 2024-06-10 11:17:35.151941
# 68079 2024-06-11 10:25:30.856703
# 72986 2024-09-24 10:43:34.789590
# 52849 2024-09-16 13:14:53.953042

# %%
display( len(df_flat) )
df_flat = df_flat[ df_flat['price'].str.match(r'\d+') ].reset_index(drop=True)
display( len(df_flat) )
# Out:
# 76539
# 76538

# %%
from lib.cleaner import CleanerFlat

df_flat = CleanerFlat().transform(df_flat)
display( len(df_flat) )
display(df_flat.sample(9))
# Out:
# 76538
#                                                    url       place  \
# 18532  https://sevastopol.cian.ru/sale/flat/282199843/  sevastopol
# 57261                  https://www.avito.ru/4025346105  sevastopol
# 29398                  https://www.avito.ru/3385086703  sevastopol
# 61576                  https://www.avito.ru/3912660562  sevastopol
# 53959                  https://www.avito.ru/4216742409  sevastopol
# 43253                  https://www.avito.ru/2398787287  sevastopol
# 52963                  https://www.avito.ru/3551019150  sevastopol
# 56776                  https://www.avito.ru/3832232174  sevastopol
# 16967  https://sevastopol.cian.ru/sale/flat/299737040/  sevastopol
#
#                                       title subtitle     price  \
# 18532  2-комн. квартира, 59,1 м², 2/11 этаж           11820000
# 57261       2-к. квартира, 45,2 м², 4/5 эт.      NaN   7950000
# 29398       2-к. квартира, 44,5 м², 5/5 эт.      NaN   7400000
# 61576      1-к. квартира, 41,9 м², 9/16 эт.      NaN   6720000
# 53959      3-к. квартира, 106,5 м², 5/6 эт.      NaN  15500000
# 43253       2-к. квартира, 59,6 м², 1/3 эт.      NaN  12100000
# 52963       1-к. квартира, 29,2 м², 2/5 эт.      NaN   5128000
# 56776    1-к. апартаменты, 31,8 м², 4/4 эт.      NaN   6480000
# 16967   3-комн. квартира, 105 м², 7/11 этаж           19600000
#
#                                                  address  \
# 18532    Севастополь, р-н Гагаринский, улица Парковая, 7
# 57261                    проспект Генерала Острякова, 68
# 29398                       улица Героев Подводников, 10
# 61576                   улица Александра Маринеско, 1Б/3
# 53959                    проспект Героев Сталинграда, 51
# 43253                         Большая Морская улица , 26
# 52963                 проспект Октябрьской Революции, 67
# 56776                            улица Челюскинцев, 49/4
# 16967  Севастополь, р-н Ленинский, улица Генерала Кре...
#
#                                              description  \
# 18532
# 57261  Двухкомнатная квартира с индивидуальным отопле...
# 29398  Двухкомнатная квартира 44.5 м2, на 5/5 этаже д...
# 61576  Продаю 1-к квартиру 41,9 м2 с качественной пре...
# 53959  Трехкомнатная квартира 106.5 м2, на 5/ 6 этаже...
# 43253  Квартира в центре, рядом Комсомольский парк, ш...
# 52963  Предлагается к продаже однокомнатная квартира ...
# 56776  В Продаже Весь Апарт Комплекс! От 24.8 до 42,2...
# 16967  Трехкомнатная квартира 105 м2 (с учетом балкон...
#
#                               ts  nrooms  floor  ...   area  is_studio  \
# 18532 2024-06-10 11:06:41.395615       0      2  ...   59.1      False
# 57261 2024-07-30 16:15:15.853171       2      4  ...   45.2      False
# 29398 2024-08-26 14:48:05.820089       2      5  ...   44.5      False
# 61576 2024-08-20 09:44:31.092411       1      9  ...   41.9      False
# 53959 2024-09-16 13:14:53.953042       3      5  ...  106.5      False
# 43253 2024-06-17 08:29:48.414678       2      1  ...   59.6      False
# 52963 2024-09-16 13:14:53.953042       1      2  ...   29.2      False
# 56776 2024-07-30 16:15:15.853171       1      4  ...   31.8      False
# 16967 2024-07-08 13:17:33.822433       0      7  ...  105.0      False
#
#        is_apartment  is_part  is_auction  is_openspace  is_roof  is_SNT  \
# 18532         False    False       False         False    False   False
# 57261         False    False       False         False    False   False
# 29398         False    False       False         False    False   False
# 61576         False    False       False         False    False   False
# 53959         False    False       False         False    False   False
# 43253         False    False       False         False    False   False
# 52963         False    False       False         False    False   False
# 56776          True    False       False         False    False   False
# 16967         False    False       False         False    False   False
#
#        priceM  is_last_floor
# 18532  11.820          False
# 57261   7.950          False
# 29398   7.400           True
# 61576   6.720          False
# 53959  15.500          False
# 43253  12.100          False
# 52963   5.128          False
# 56776   6.480           True
# 16967  19.600          False
#
# [9 rows x 21 columns]

# %% [markdown]
# ---

# %%
obj_type = 'land'
files = [ f'{d}/{f}' for d in source[obj_type] for f in listdir(d) if f[-4:]=='.pkl' ]
display( len(files) )

cols = ['url','place','title','subtitle','price','address','description','ts',]

df_land = pd.concat([
        pd.read_pickle(f).drop_duplicates(['url'])
        for f in files
    ]).reset_index(drop=True)[cols]

display( len(df_land) )
display(df_land.sample(9))
# Out:
# 105
# 64567
#                                                      url        place  \
# 53282                    https://www.avito.ru/2328013337  bahchisaray
# 39118                    https://www.avito.ru/2539419190   sevastopol
# 3352       https://krym.cian.ru/sale/suburban/301708674/        sudak
# 8047   https://sevastopol.cian.ru/sale/suburban/30068...   sevastopol
# 31594                    https://www.avito.ru/4067916058  bahchisaray
# 40811                    https://www.avito.ru/3944807390   sevastopol
# 20699  https://sevastopol.cian.ru/sale/suburban/30288...   sevastopol
# 55370                    https://www.avito.ru/2866500668        sudak
# 46985                    https://www.avito.ru/4069126154   sevastopol
#
#                                 title subtitle    price  \
# 53282     Участок 100 сот. (СНТ, ДНП)      NaN  1200000
# 39118     Участок 8,9 сот. (СНТ, ДНП)      NaN  6450000
# 3352     Участок, 6 сот., Садоводство           3000000
# 8047   Участок, 5.2 сот., Садоводство           3200000
# 31594      Участок 12 сот. (СНТ, ДНП)      NaN  1000000
# 40811     Участок 4,1 сот. (СНТ, ДНП)      NaN  4100000
# 20699            Участок, 4 сот., ИЖС           2450000
# 55370           Участок 12 сот. (ИЖС)      NaN  6200000
# 46985     Участок 4,5 сот. (СНТ, ДНП)      NaN  3500000
#
#                                                  address  \
# 53282                                        с. Холмовка
# 39118            СНТ Сапун-гора, ул. Лейтенанта Миронова
# 3352   Республика Крым, Судак, Ветеран садовое товари...
# 8047   Севастополь, р-н Нахимовский, Сапун-гора СНТ, ...
# 31594  садоводческий потребительский кооператив Энтуз...
# 40811          садоводческое товарищество Дергачи-4, 120
# 20699    Севастополь, р-н Нахимовский, с. Полюшко, 3А/27
# 55370                                          с. Дачное
# 46985   садоводческое товарищество Динамо, Мобильная ул.
#
#                                              description  \
# 53282  Продаётся земля сельскохозяйственного назначен...
# 39118  Объект №229. Арт. 30249025. Продам участок в Н...
# 3352   Продается участок 610 кв.м. в г. Судак, ст Вет...
# 8047   Арт. 63129073 Хороший, ровный земельный участо...
# 31594  Продается участок в Спк «Энтузиаст» 12 соток. ...
# 40811  Продам земельный участок со всеми городскими к...
# 20699  Пpoдaетcя учacтoк в городе Севастoполe (село П...
# 55370  Продам участок 12 соток в селе Дачном. На учас...
# 46985  Продам земельный участок в г. Севастополь райо...
#
#                               ts
# 53282 2024-07-08 13:48:33.488742
# 39118 2024-09-09 12:53:24.129387
# 3352  2024-09-09 12:58:08.228374
# 8047  2024-06-17 08:22:17.440170
# 31594 2024-09-09 13:06:18.507053
# 40811 2024-07-08 13:36:06.464523
# 20699 2024-06-10 11:18:48.884876
# 55370 2024-06-07 12:06:21.568118
# 46985 2024-07-22 11:12:26.881258

# %%
display( len(df_land) )
df_land = df_land[ df_land['price'].str.match(r'\d+') ].reset_index(drop=True)
display( len(df_land) )
# Out:
# 64567
# 64566

# %%
from lib.cleaner import CleanerLand

df_land = CleanerLand().transform(df_land)

display( len(df_land) )
display(df_land.sample(9))
# Out:
# 64566
#                                                      url        place  \
# 23536                    https://www.avito.ru/3089107047   sevastopol
# 5030   https://sevastopol.cian.ru/sale/suburban/27842...   sevastopol
# 22319                    https://www.avito.ru/3211766525  bahchisaray
# 53150                    https://www.avito.ru/1779652100  bahchisaray
# 63990                    https://www.avito.ru/3462922224   sevastopol
# 31889                    https://www.avito.ru/3860949670  bahchisaray
# 3360       https://krym.cian.ru/sale/suburban/301647220/        sudak
# 43175                    https://www.avito.ru/3844839316   sevastopol
# 17225  https://sevastopol.cian.ru/sale/suburban/30272...   sevastopol
#
#                              title                      subtitle    price  \
# 23536  участок 4,2 сот. (снт, днп)                           NaN  3200000
# 5030         участок, 13 сот., ижс                                3000000
# 22319        участок 10 сот. (ижс)                           NaN  3480000
# 53150   участок 50 сот. (снт, днп)                           NaN  1000000
# 63990        участок 15 сот. (ижс)                           NaN  4500000
# 31889  участок 8,4 сот. (снт, днп)                           NaN   600000
# 3360        участок, 6.3 сот., ижс                                5500000
# 43175         участок 7 сот. (ижс)                           NaN  8500000
# 17225               участок у моря  Участок, 4 сот., Садоводство  3750000
#
#                                                  address  \
# 23536                          СТ Технолог, Алмазная ул.
# 5030          Севастополь, р-н Балаклавский, с. Терновка
# 22319                                         с. Каштаны
# 53150              Республика Крым, Бахчисарайский район
# 63990                      с. Тыловое, Земляной пер., 2А
# 31889  садоводческий потребительский кооператив Энтуз...
# 3360             Республика Крым, Судак, шоссе Восточное
# 43175                                      мкр-н Фиолент
# 17225  Севастополь, р-н Балаклавский, Электрон-2 садо...
#
#                                              description  \
# 23536  Объект №99. Продам участок в супер видовом мес...
# 5030   Объект 11475. Продается участок ИЖС, 13 соток ...
# 22319  Как Не Потерять Деньги. Все ОБ Этом Молчат… Но...
# 53150  Участок — пай Лкх — находится в в красивейшем ...
# 63990  Видовой участок с прудомв одном из самых прекр...
# 31889  Продается земельный участок на территории Спк ...
# 3360   Объект 126. Продается участок в г.Судак, Восто...
# 43175  Представляем к продаже эксклюзивный земельный ...
# 17225  Объект 1212. Продается участок в самом красиво...
#
#                               ts  area  is_IJS  priceM   priceMU  \
# 23536 2024-06-17 08:36:13.464806   4.2   False    3.20  0.761905
# 5030  2024-08-12 11:10:58.029975  13.0    True    3.00  0.230769
# 22319 2024-08-20 10:02:49.280771  10.0    True    3.48  0.348000
# 53150 2024-07-08 13:48:33.488742  50.0   False    1.00  0.020000
# 63990 2024-06-24 12:54:03.232729  15.0    True    4.50  0.300000
# 31889 2024-06-11 10:49:42.413688   8.4   False    0.60  0.071429
# 3360  2024-09-09 12:58:08.228374   3.0    True    5.50  1.833333
# 43175 2024-06-14 13:13:27.377070   7.0    True    8.50  1.214286
# 17225 2024-07-30 16:15:42.641826   0.0   False    3.75       inf
#
#       area_size_category
# 23536                4-8
# 5030               12-20
# 22319               8-12
# 53150                20+
# 63990              12-20
# 31889               8-12
# 3360                 2-4
# 43175                4-8
# 17225                NaN

# %% [markdown]
# ---

# %%
obj_type = 'house'
files = [ f'{d}/{f}' for d in source[obj_type] for f in listdir(d) if f[-4:]=='.pkl' ]
display( len(files) )

cols = ['url','place','title','subtitle','price','address','description','ts',]

df_house = pd.concat([
        pd.read_pickle(f).drop_duplicates(['url'])
        for f in files
    ]).reset_index(drop=True)[cols]

display( len(df_house) )
display(df_house.sample(9))
# Out:
# 105
# 57854
#                                                      url        place  \
# 37948                    https://www.avito.ru/2541279031   sevastopol
# 26112                    https://www.avito.ru/3464905462   sevastopol
# 29951                    https://www.avito.ru/3658798575  bahchisaray
# 10752  https://sevastopol.cian.ru/sale/suburban/27409...   sevastopol
# 41296                    https://www.avito.ru/4085905168   sevastopol
# 57808                    https://www.avito.ru/4040724980   sevastopol
# 53726                    https://www.avito.ru/1746130034   sevastopol
# 28475                    https://www.avito.ru/3862089675   sevastopol
# 19121  https://sevastopol.cian.ru/sale/suburban/27496...   sevastopol
#
#                                 title subtitle     price  \
# 37948    Дом 236 м² на участке 8 сот.      NaN  15500000
# 26112   Дом 81 м² на участке 4,1 сот.      NaN   5900000
# 29951   Дом 130 м² на участке 16 сот.      NaN  11700000
# 10752            Дом, 245 м², 12 сот.           51000000
# 41296    Дом 147 м² на участке 4 сот.      NaN  12500000
# 57808  Дом 300 м² на участке 6,8 сот.      NaN  19600000
# 53726    Дом 140 м² на участке 7 сот.      NaN  20500000
# 28475     Дом 87 м² на участке 5 сот.      NaN   8200000
# 19121      Дом, 140 м², 2.5 сот., ИЖС            8000000
#
#                                                  address  \
# 37948                          ул. Василия Колодкина, 63
# 26112             садоводческое товарищество Таврия, 143
# 29951                         с. Шевченково, Садовая ул.
# 10752  Севастополь, р-н Гагаринский, Рыбак - 1 садово...
# 41296                              ул. Лётчика Алексеева
# 57808                                  пер. Токарева, 9А
# 53726  пгт. Кача, садоводческое товарищество Маяк-Кач...
# 28475                           с. Флотское, Ягодная ул.
# 19121   Севастополь, р-н Ленинский, улица Крошицкого, 49
#
#                                              description  \
# 37948  Севастополь. Красная Горка. Лучше писать Смс. ...
# 26112  Представляем Вам уникальное предложение — прев...
# 29951  Продаётся уютный тёплый дом в с. Шевченково Ба...
# 10752  Предлагается к продаже современный 2х.-этажный...
# 41296  Продам экологически чистый деревянный жилой до...
# 57808  Продается недостроенный дом площадью 300 кв. М...
# 53726  Пол дома у моря, 250 метров. Возможность выкуп...
# 28475  Продаётся дом под Балаклавой в селе Флотское! ...
# 19121  Объект 152. Продам современный таунхаус 140 кв...
#
#                               ts
# 37948 2024-06-11 10:41:08.345000
# 26112 2024-06-17 08:43:09.491886
# 29951 2024-06-11 10:50:38.246567
# 10752 2024-06-19 12:37:23.275933
# 41296 2024-08-20 09:57:45.024714
# 57808 2024-07-30 16:29:45.104005
# 53726 2024-09-03 13:44:56.372016
# 28475 2024-08-12 11:27:30.996664
# 19121 2024-06-07 11:42:40.789431

# %%
display( len(df_house) )
df_house = df_house[ df_house['price'].str.match(r'\d+') ].reset_index(drop=True)
display( len(df_house) )
# Out:
# 57854
# 57853

# %%
# cols = ['title','address','place','url']
# df_house[ (df_house['place']=='sevastopol') & (df_house['address'].str.match(r'.*Судак.*')) ][cols]

# %%
from lib.cleaner import CleanerHouse

df_house = CleanerHouse().transform(df_house)

display( len(df_house) )
display(df_house.sample(9))
# Out:
# 57853
#                                                      url       place  \
# 24170                    https://www.avito.ru/4136663259  sevastopol
# 29066                    https://www.avito.ru/3844970288  sevastopol
# 10368  https://sevastopol.cian.ru/sale/suburban/29878...  sevastopol
# 1606   https://sevastopol.cian.ru/sale/suburban/28901...  sevastopol
# 9837   https://sevastopol.cian.ru/sale/suburban/30033...  sevastopol
# 15640  https://sevastopol.cian.ru/sale/suburban/30228...  sevastopol
# 56942                    https://www.avito.ru/4043718771  sevastopol
# 46775                    https://www.avito.ru/3585613802  sevastopol
# 32593                    https://www.avito.ru/3633056142  sevastopol
#
#                                        title subtitle     price  \
# 24170            дом 83 м² на участке 1 сот.      NaN  11400000
# 29066         дом 120 м² на участке 4,1 сот.      NaN  10300000
# 10368                   дом, 56 м², 4.2 сот.            6500000
# 1606     дом, 100 м², 5.46 сот., садоводство           10500000
# 9837       дом, 30 м², 5.5 сот., садоводство            3500000
# 15640  дом, 104,8 м², 4.62 сот., садоводство            8900000
# 56942           дом 132 м² на участке 6 сот.      NaN  26300000
# 46775           дом 113 м² на участке 4 сот.      NaN   8600000
# 32593      таунхаус 110 м² на участке 2 сот.      NaN  10000000
#
#                                                  address  \
# 24170                                      СТ Омега-2, 3
# 29066               садоводческое товарищество Скиф, 316
# 10368  Севастополь, р-н Нахимовский, с. Орловка, улиц...
# 1606   Севастополь, р-н Балаклавский, Водолаз садовое...
# 9837   Севастополь, р-н Нахимовский, Дружба садоводче...
# 15640  Севастополь, р-н Нахимовский, Качинский муници...
# 56942                          с. Ушаково, Фрегатный пр.
# 46775                                         с. Орловка
# 32593                                Камышовое ш., 68В/2
#
#                                              description  \
# 24170  Продаётcя уютный, утeплeнный дом c техникой и ...
# 29066  Внимание! Для дpужной семьи предлагается качес...
# 10368  Дом 56,4 м² на участке 4,2 сотки Дом 56,4 м² н...
# 1606   Предлагаю вашему вниманию новый дом в СТ "Водо...
# 9837   Продам жилую дачу в СНТ Дружба( Доковая балка)...
# 15640  Продается дом для жизни и бизнеса в самой прив...
# 56942  Продается новый Дом 132 кв. М. На участке 6 со...
# 46775  В экологически чистом уголке Севастополя, на в...
# 32593  Срочная продажа таунхауса до 15 июля! Продам д...
#
#                               ts  house_area  is_part  is_townhouse  is_SNT  \
# 24170 2024-08-26 15:01:44.774514        83.0    False         False    True
# 29066 2024-08-12 11:27:30.996664       120.0    False         False    True
# 10368 2024-09-03 13:56:00.998366        56.0    False         False   False
# 1606  2024-06-17 08:27:31.304082       100.0    False         False    True
# 9837  2024-07-30 16:24:07.325013        30.0    False         False    True
# 15640 2024-07-08 14:05:28.543820       104.8    False         False    True
# 56942 2024-07-30 16:29:45.104005       132.0    False         False   False
# 46775 2024-06-14 13:20:44.492111       113.0    False         False   False
# 32593 2024-07-08 13:43:40.723717       110.0    False          True   False
#
#        land_area  priceM land_size_category house_size_category
# 24170        1.0    11.4                 <1              70-110
# 29066        4.1    10.3                4-8             110-180
# 10368        2.0     6.5                1-2               50-70
# 1606        46.0    10.5                20+              70-110
# 9837         5.0     3.5                4-8                 <30
# 15640       62.0     8.9                20+              70-110
# 56942        6.0    26.3                4-8             110-180
# 46775        4.0     8.6                2-4             110-180
# 32593        2.0    10.0                1-2              70-110

# %% [markdown]
# ## обновляем таблицу адресов

# %%
# !pip install geopy

# %%
# df_flat['address'].str.strip().drop_duplicates().sort_values().to_csv('tmp/flat_address.txt',index=False,header=False)
# df_land['address'].str.strip().drop_duplicates().sort_values().to_csv('tmp/land_address.txt',index=False,header=False)
# df_house['address'].str.strip().drop_duplicates().sort_values().to_csv('tmp/house_address.txt',index=False,header=False)

# %%
from lib.locator import AddressTransformer

atr = AddressTransformer()

places = { 
# поле 'place' и название города
'bahchisaray': 'Бахчисарай,',
      'sudak': 'Судак,',
  'sevastopol': 'Севастополь,',
}

def address_norm(df,atr=atr):
    df['address_orig'] =  df['address']
    df['address'] =  df['address'].apply(atr.transform)
    df['place_'] =  df['place'].map(places)
    df['address'] = df[['address','place_']].apply(lambda d: d[0] if d[1] in d[0] else d[1]+','+d[0],axis=1) 
    df['address'] = (
        df['address']
        .str.replace(', ',',')
        .str.replace(',,',',')
        .str.replace('. ','.')
        .str.replace('\n',' ')
        .str.replace('  ',' ')
        .str.lower()
    )
    return df

# %%
df_flat = address_norm(df_flat)
df_land = address_norm(df_land)
df_house = address_norm(df_house)
# Out:
# /tmp/ipykernel_823828/776805188.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['address'] = df[['address','place_']].apply(lambda d: d[0] if d[1] in d[0] else d[1]+','+d[0],axis=1)
# /tmp/ipykernel_823828/776805188.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['address'] = df[['address','place_']].apply(lambda d: d[0] if d[1] in d[0] else d[1]+','+d[0],axis=1)
# /tmp/ipykernel_823828/776805188.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['address'] = df[['address','place_']].apply(lambda d: d[0] if d[1] in d[0] else d[1]+','+d[0],axis=1)

# %%
# df_flat[['address','address_orig']]

# %%
address = pd.concat([
        df_flat[['address','address_orig']],
        df_land[['address','address_orig']],
        df_house[['address','address_orig']],
    ]).drop_duplicates(['address']).reset_index(drop=True)

display(len(address))
display(address.sample(5))
# Out:
# 13830
#                                                  address  \
# 791    севастополь,р-н гагаринский,мкр.стрелецкая бух...
# 3043                       судак,набережная улица ,75 к3
# 1673               севастополь,лабораторное шоссе ,33 к2
# 11118                       бахчисарай,ул.николая спаи,9
# 2738          севастополь,проспект героев сталинграда,28
#
#                                             address_orig
# 791    Севастополь, р-н Гагаринский, мкр. Стрелецкая ...
# 3043                            Набережная улица , 75 к3
# 1673                          Лабораторное шоссе , 33 к2
# 11118                                ул. Николая Спаи, 9
# 2738                     проспект Героев Сталинграда, 28

# %%
from os.path import exists as path_exists
loc_file_path = 'data/location.pkl' # таблица адресов

location = pd.DataFrame([],columns=['address','latitude','longitude',])
if path_exists( loc_file_path ):
    location = pd.read_pickle(loc_file_path).drop_duplicates(['address']).reset_index(drop=True)
    
display(len(location))
display(location.sample(5))
# Out:
# 20180
#                                                  address   latitude  longitude
# 435                  бахчисарай,с.красный мак,лесная ул.  44.635612  33.776816
# 815                        бахчисарай,таврическая ул.,30  44.741201  33.857952
# 7430      севастополь,р-н гагаринский,улица казачья,1а/1  44.563999   33.42306
# 14068  севастополь,садовое товарищество гавань,ул.сер...  44.582857  33.592814
# 19256  судак,республика крым,судак городской округ,с....  44.869412  35.061767

# %% [markdown]
# ---

# %%
# def address_norm_(df):
#     df['address_orig'] =  df['address']
#     # df['address'] =  df['address'].apply(atr.transform)
#     df['address'] = (
#         df['address']
#         .str.replace(', ',',')
#         .str.replace(',,',',')
#         .str.replace('. ','.')
#         .str.replace('\n',' ')
#         .str.replace('  ',' ')
#         .str.lower()
#     )
#     return df

# %%
# location = address_norm_(location)

# %%
# location = location[['address','latitude','longitude']]

# %% [markdown]
# ---

# %%
# собираем все адреса в один список
location = location.merge(
        address[['address']].drop_duplicates(),
        how='outer',
        on='address',
    ).drop_duplicates(['address']).reset_index(drop=True)

display(len(location))
display(location.sample(5))
# Out:
# 20278
#                                                address   latitude  longitude
# 13986  севастополь,садоводческое товарищество чайка,42  44.635535    33.5175
# 16262              севастополь,ул.адмирала макарова,20  44.615449  33.549857
# 11465                севастополь,с.вилино,ул.достлук,6  44.845586  33.664248
# 2224             севастополь,большая морская улица ,34  44.605624  33.521821
# 18073                     севастополь,улица косарева,5  44.577882  33.463421

# %%
display(len(location))
display(location['latitude'].isnull().sum())
# Out:
# 20278
# 98

# %%
# собираем все адреса с геопозицией
location_def = location[~location['latitude'].isna()].reset_index(drop=True)
display(len(location_def))

# собираем все адреса без геопозиции
location_undef = location[location['latitude'].isna()][['address']].reset_index(drop=True)
display(len(location_undef))
# Out:
# 20180
# 98

# %%
display(location_undef)
# Out:
#                                         address
# 0      бахчисарай,пгт.куйбышево,ул.старателей,5
# 1        бахчисарай,с.верхоречье,садовая ул.,5з
# 2        бахчисарай,с.долинное,фонтанная ул.,12
# 3   бахчисарай,с.железнодорожное,каштановая ул.
# 4             бахчисарай,симферопольская ул.,15
# ..                                          ...
# 93                     севастополь,янтарная ул.
# 94                              судак,новая ул.
# 95                      судак,ул.ковропрядов,24
# 96                  судак,улица гора фирейная,8
# 97                        судак,улица ленина,61
#
# [98 rows x 1 columns]

# %%
from tqdm.auto import tqdm
tqdm.pandas()

# %%
# from lib.locator import GeocoderSimpleOSM
from lib.locator import GeocoderYandex
from yandex_keys import keys

atr = AddressTransformer()
locator = GeocoderYandex(keys[0])
# locator = GeocoderSimpleOSM()

if len(location_undef)>0:
    # определяем координаты по строке адреса
    location_undef = location_undef.join( 
            location_undef['address'].progress_apply(locator.transform).apply(pd.Series) 
        ).dropna()     
    display(f'LocationUpdater: {len(location_undef)} new addresses found')
    location = pd.concat([location_def,location_undef]).reset_index(drop=True) 
    assert len(location)>0
    # location.to_pickle(loc_file_path)
# Out:
#   0%|          | 0/98 [00:00<?, ?it/s]
# 'LocationUpdater: 98 new addresses found'

# %%
display( len(location) )
display( location.sample(3) )
# Out:
# 20278
#                                                  address   latitude  longitude
# 18495                    севастополь,улица симонок,66/68  44.634708  33.527705
# 6392   севастополь,р-н гагаринский,мкр.летчики,проспе...   44.59214  33.460457
# 9327   севастополь,р-н нахимовский,улица горпищенко,1...  44.584064  33.576393

# %%
assert len(location)>0
location.to_pickle(loc_file_path)

# %% [markdown]
# ## дополняем данные геометкой

# %%
display( len(df_flat) )
df_flat  = df_flat.merge(location,on='address').reset_index(drop=True) 
display( len(df_flat) )
display( df_flat.sample(3) )
# Out:
# 76538
# 76538
#                                                    url       place  \
# 1335   https://sevastopol.cian.ru/sale/flat/282199800/  sevastopol
# 38587                  https://www.avito.ru/3609575005  sevastopol
# 41025                  https://www.avito.ru/3128469497  sevastopol
#
#                                         title subtitle     price  \
# 1335   3-комн. квартира, 161,5 м², 10/11 этаж           56525000
# 38587          1-к. квартира, 36 м², 4/10 эт.      NaN   7400000
# 41025         1-к. квартира, 40,8 м², 1/5 эт.      NaN   9000000
#
#                                                address  \
# 1335      севастополь,р-н гагаринский,улица парковая,7
# 38587                      севастополь,улица репина,19
# 41025  севастополь,балаклава,физкультурный переулок ,5
#
#                                              description  \
# 1335
# 38587  Удачное приобретение! Очень светлая, тёплая кв...
# 41025  Продаётся однокомнатная квартира в центре Бала...
#
#                               ts  nrooms  floor  ...  is_auction  \
# 1335  2024-06-19 12:14:54.696204       0      0  ...       False
# 38587 2024-06-24 12:47:24.649620       1      4  ...       False
# 41025 2024-08-12 11:14:17.523749       1      1  ...       False
#
#        is_openspace  is_roof  is_SNT  priceM  is_last_floor  \
# 1335          False    False   False  56.525          False
# 38587         False    False   False   7.400          False
# 41025         False    False   False   9.000          False
#
#                                           address_orig        place_  \
# 1335   Севастополь, р-н Гагаринский, улица Парковая, 7  Севастополь,
# 38587                                 улица Репина, 19  Севастополь,
# 41025            Балаклава, Физкультурный перeулок , 5  Севастополь,
#
#         latitude  longitude
# 1335   44.607941   33.46228
# 38587  44.593854  33.492275
# 41025  44.515164  33.599498
#
# [3 rows x 25 columns]

# %%
display( len(df_land) )
df_land  = df_land.merge(location,on='address').reset_index(drop=True) 
display( len(df_land) )
display( df_land.sample(3) )
# Out:
# 64566
# 64566
#                                                      url        place  \
# 52071                     https://www.avito.ru/541358570  bahchisaray
# 17406  https://sevastopol.cian.ru/sale/suburban/29506...   sevastopol
# 47085                    https://www.avito.ru/4099274217   sevastopol
#
#                              title subtitle    price  \
# 52071       участок 6,6 сот. (ижс)      NaN  2200000
# 17406       участок, 7.3 сот., ижс           3900000
# 47085  участок 4,5 сот. (снт, днп)      NaN  4500000
#
#                                                  address  \
# 52071                           бахчисарай,пгт.куйбышево
# 17406  севастополь,р-н нахимовский,мкр.кача,качинский...
# 47085               севастополь,территория тсн рыбак-7,6
#
#                                              description  \
# 52071  Пгт Куйбышево, район нового поселка. Одно из к...
# 17406  Предлагается к продаже земельный участок ИЖС 7...
# 47085  Продается земельный участок 91:02:005003:2085 ...
#
#                               ts  area  is_IJS  priceM   priceMU  \
# 52071 2024-06-24 13:05:30.092315   6.6    True     2.2  0.333333
# 17406 2024-07-30 16:15:42.641826   3.0    True     3.9  1.300000
# 47085 2024-07-22 11:12:26.881258   4.5   False     4.5  1.000000
#
#       area_size_category                                       address_orig  \
# 52071                4-8                                     пгт. Куйбышево
# 17406                2-4  Севастополь, р-н Нахимовский, мкр. Кача, Качин...
# 47085                4-8                          территория ТСН Рыбак-7, 6
#
#              place_   latitude  longitude
# 52071   Бахчисарай,  44.629281  33.865229
# 17406  Севастополь,  44.773517  33.551555
# 47085  Севастополь,  44.568269  33.437316

# %%
display( len(df_house) )
df_house = df_house.merge(location,on='address').reset_index(drop=True) 
display( len(df_house) )
display( df_house.sample(3) )
# Out:
# 57853
# 57853
#                                    url        place  \
# 23139  https://www.avito.ru/4130716390   sevastopol
# 49295  https://www.avito.ru/3764521426  bahchisaray
# 44347  https://www.avito.ru/4089781733   sevastopol
#
#                                   title subtitle     price  \
# 23139     дом 24,9 м² на участке 8 сот.      NaN   3800000
# 49295  дом 49,6 м² на участке 18,4 сот.      NaN   4600000
# 44347  дом 168,4 м² на участке 4,6 сот.      NaN  17500000
#
#                                                  address  \
# 23139        севастополь,садовое товарищество тополёк,10
# 49295                             бахчисарай,с.путиловка
# 44347  севастополь,садоводческое товарищество степной...
#
#                                              description  \
# 23139  Продам дом площадью 24.9 кв. М. На участке 8,0...
# 49295  Продается дом 49,6 кв. М., расположенный на уч...
# 44347  Собственник. Не агентство! Дом 168.4 м² на уча...
#
#                               ts  house_area  is_part  is_townhouse  is_SNT  \
# 23139 2024-08-26 15:01:44.774514        24.9    False         False    True
# 49295 2024-06-17 08:48:16.158492        49.6    False         False   False
# 44347 2024-08-06 11:17:09.275527       168.4    False         False    True
#
#        land_area  priceM land_size_category house_size_category  \
# 23139        8.0     3.8                4-8                 <30
# 49295       18.4     4.6              12-20               30-50
# 44347        4.6    17.5                4-8             110-180
#
#                                             address_orig        place_  \
# 23139                   садовое товарищество Тополёк, 10  Севастополь,
# 49295                                       с. Путиловка   Бахчисарай,
# 44347  садоводческое товарищество Степной Фазан, Друж...  Севастополь,
#
#         latitude  longitude
# 23139  44.557287   33.53649
# 49295  44.568911   33.89075
# 44347   44.57139  33.575782

# %%
# def address_filter(df):
#     #           46.319437, 33.911048
#     #
#     # 45.402617, 32.455625 |  45.545301, 36.684702
#     #
#     #          44.320887, 33.917013

#     df['latitude'] = pd.to_numeric( df['latitude'], errors='coerce' )
#     df['longitude'] = pd.to_numeric( df['longitude'], errors='coerce' )

#     df = df.query('(32.4<longitude<36.7) & (44.3<latitude<46.4)') 

#     df.loc[ df['url']=='https://avito.ru/2322251740', ['latitude','longitude']] = None

#     df.loc[ df['address']=='Севастополь,Чёрное море', ['latitude','longitude'] ] = None
#     df.loc[ df['address'].str.lower().str.match('чёрное море'), ['latitude','longitude'] ] = None 

#     df.loc[ df['address']=='квартал Старый Город', 'place'] = 'turkie'
#     df.loc[ df['address'].str.lower().str.match('анталья'), 'place' ] = 'turkie' 

#     df.loc[ df['address'].str.lower().str.match(r'.*бахчисарай.*'), 'place' ] = 'bahchisaray'
#     df.loc[ df['address'].str.lower().str.match(r'.*севастополь,.*'), 'place' ] = 'sevastopol'

#     df.loc[ df['address'].str.lower().str.match(r'.*мысовское.*'), 'place' ] = 'kerch'
#     df.loc[ df['address'].str.lower().str.match(r'.*алушта.*'), 'place' ] = 'alushta'
#     df.loc[ df['address'].str.lower().str.match(r'.*гурзуф.*'), 'place' ] = 'gurzuf'

#     df.loc[ df['address'].str.lower().str.match(r'.*с.лучистое.*'), 'place' ] = 'alushta'
#     df.loc[ df['address'].str.lower().str.match(r'.*снт солнечная долина.*'), 'place' ] = 'sudak'
#     df.loc[ df['address'].str.lower().str.match(r'.*пгт.новоозёрное.*'), 'place' ] = 'evpatoria'

#     df.loc[ df['address'].str.lower().str.match(r'.*с.мирное.*'), 'place' ] = 'simferopol'
#     df.loc[ df['address'].str.lower().str.match(r'.*тсн аэрофлот.*'), 'place' ] = 'simferopol'

#     df.loc[ df['address'].str.lower().str.match(r'.*семисот.*'), 'place' ] = 'kerch'

#     df.loc[ df['address'].str.lower().str.match(r'.*ялта.*') , 'place' ] = 'yalta'
#     df.loc[ df['address'].str.lower().str.match(r'.*феодосия.*') , 'place' ] = 'feodosia'
#     df.loc[ df['address'].str.lower().str.match(r'.*окуневка.*') , 'place' ] = 'tarkhankut'
#     df.loc[ df['address'].str.lower().str.match(r'.*заветное.*') , 'place' ] = 'kerch'
#     df.loc[ df['address'].str.lower().str.match(r'.*евпатория.*') , 'place' ] = 'evpatoria'
#     df.loc[ df['address'].str.lower().str.match(r'.*симферопольский район.*'), 'place' ] = 'simferopol'

#     df.loc[df['address'].str.match(r'.*белогорск.*'),'place'] = 'belogorsk'
#     df.loc[df['address'].str.match(r'.*кировский.*'),'place'] = 'kirovsky'
#     df.loc[df['address'].str.match(r'.*сакский район.*'),'place'] = 'saki'
#     df.loc[df['address'].str.match(r'.*керчь.*'),'place'] = 'kerch'
#     df.loc[df['address'].str.match(r'.*белогорский.*'),'place'] = 'belogorsk'
#     df.loc[df['address'].str.match(r'.*кировский.*'),'place'] = 'kirovski'

#     df.loc[df['address'].str.match(r'.*кореиз.*'),'place'] = 'ubk'
#     df.loc[df['address'].str.match(r'.*малый маяк.*'),'place'] = 'ubk'
#     df.loc[df['address'].str.match(r'.*светлый мир.*'),'place'] = 'simferopol'
#     df.loc[df['address'].str.match(r'.*доброе.*'),'place'] = 'simferopol'
#     df.loc[df['address'].str.match(r'.*родниково.*'),'place'] = 'simferopol'
#     df.loc[df['address'].str.match(r'.*уютное.*'),'place'] = 'evpatoria'
#     df.loc[df['address'].str.match(r'.*коктебель.*'),'place'] = 'koktebel'
#     df.loc[df['address'].str.match(r'.*новосельское.*'),'place'] = 'tarhankut'

#     df = df.dropna(subset=['latitude','longitude'])
    
#     return df

# %%
# display(len(df_flat))
# df_flat = address_filter(df_flat)
# display(len(df_flat))

# display(len(df_land))
# df_land = address_filter(df_land)
# display(len(df_land))

# display(len(df_house))
# df_house = address_filter(df_house)
# display(len(df_house))

# %%
assert len(df_flat)>0
df_flat.to_pickle(f'{data_root_folder}/df_flat.pkl')

assert len(df_land)>0
df_land.to_pickle(f'{data_root_folder}/df_land.pkl')

assert len(df_house)>0
df_house.to_pickle(f'{data_root_folder}/df_house.pkl')

# %%
# !date
# Out:
# Вт 24 сен 2024 11:17:54 MSK
