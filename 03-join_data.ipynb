# %% [markdown]
# __собираем объявления о продаже недвижимости в одну таблицу__
#
# _Evgeny S. Borisov <parser@mechanoid.su>_

# %%
# !date
# Out:
# Пн 09 сен 2024 13:08:00 MSK

# %%
from os import listdir
import re
import pandas as pd

# %%
data_root_folder = 'data/2024'
source = {
         'flat':[data_root_folder+'/raw/flat/cian',data_root_folder+'/raw/flat/avito'],
        'house':[data_root_folder+'/raw/house/cian',data_root_folder+'/raw/house/avito'],
         'land':[data_root_folder+'/raw/land/cian',data_root_folder+'/raw/land/avito'],
    }

# %% [markdown]
# ---

# %%
obj_type = 'flat'
files = [ f'{d}/{f}' for d in source[obj_type] for f in listdir(d) if f[-4:]=='.pkl' ]
display( len(files) )

cols = ['url','place','title','subtitle','price','address','description','ts',]

df_flat = pd.concat([
        pd.read_pickle(f).drop_duplicates(['url'])
        for f in files
    ]).reset_index(drop=True)[cols]

display( len(df_flat) )
display(df_flat.sample(9))
# Out:
# 76
# 71167
#                                                    url       place  \
# 9622   https://sevastopol.cian.ru/sale/flat/303459086/  sevastopol
# 64486                  https://www.avito.ru/3900987456  sevastopol
# 42403                  https://www.avito.ru/3945424103  sevastopol
# 68155                  https://www.avito.ru/3637583483  sevastopol
# 48482                  https://www.avito.ru/3032875097  sevastopol
# 60361                  https://www.avito.ru/3959928329  sevastopol
# 48509                  https://www.avito.ru/3625372317  sevastopol
# 13637        https://krym.cian.ru/sale/flat/299848840/       sudak
# 61017                  https://www.avito.ru/3834705759  sevastopol
#
#                                       title                  subtitle  \
# 9622    3-комн. квартира, 148 м², 8/16 этаж
# 64486       2-к. квартира, 57,2 м², 3/9 эт.                       NaN
# 42403       2-к. квартира, 57,5 м², 6/6 эт.                       NaN
# 68155         2-к. квартира, 50 м², 5/5 эт.                       NaN
# 48482         4-к. квартира, 93 м², 3/4 эт.                       NaN
# 60361         3-к. квартира, 51 м², 2/3 эт.                       NaN
# 48509     Квартира-студия, 33,1 м², 3/9 эт.                       NaN
# 13637  3-комн. квартира, 62,06 м², 7/8 этаж  Сдача корпуса 1 кв. 2027
# 61017       3-к. квартира, 75,2 м², 9/9 эт.                       NaN
#
#           price                                            address  \
# 9622   29900000  Севастополь, р-н Ленинский, улица 6-я Бастионн...
# 64486  10500000                                 Античный пр-т, 5/4
# 42403   8150000                                   Античный пр-т, 9
# 68155   7790000                                ул. Хрусталёва, 125
# 48482  12300000                                    Готский пр., 16
# 60361   5300000                                      с. Дальнее, 2
# 48509   5924900      ЖК «Доброгород»\nул. Токарева, 8 этап, блок 4
# 13637  11199451              Республика Крым, Судак, Долина Роз ЖК
# 61017  11100000  ЖК «Porto Franco»\nул. Западный берег Камышово...
#
#                                              description  \
# 9622   Арт. 52732410 Продаем трехкомнатную квартиру р...
# 64486  Продается двухкомнатную квартира у моря в ново...
# 42403  В продаже очень интересная двухкомнатная видов...
# 68155  Квартира с узаконенным Агв( автономное отоплен...
# 48482  Четырехкомнатная квартира 93 м2, 3/4 эт. Четыр...
# 60361  Трёхкомнатная квартира 51 м2, на 2/3 этаже дом...
# 48509  Сдача объекта — I кв. 2027 г. Доступна ипотека...
# 13637  Продаётся 3-комнатная квартира в строящемся до...
# 61017  Продаётся 3-комнатная квартира №80, площадь 75...
#
#                               ts
# 9622  2024-07-30 16:07:58.352115
# 64486 2024-06-11 10:25:30.856703
# 42403 2024-06-17 08:29:48.414678
# 68155 2024-06-10 11:17:35.151941
# 48482 2024-06-19 12:22:29.452737
# 60361 2024-06-14 13:06:45.993553
# 48509 2024-06-19 12:22:29.452737
# 13637 2024-08-06 11:15:49.423503
# 61017 2024-06-07 11:27:07.236636

# %%
from lib.cleaner import CleanerFlat

df_flat = CleanerFlat().transform(df_flat)
display( len(df_flat) )
display(df_flat.sample(9))
# Out:
# 71167
#                                                    url       place  \
# 26740                  https://www.avito.ru/4129284724  sevastopol
# 57972                  https://www.avito.ru/4008819690  sevastopol
# 54786                  https://www.avito.ru/3322935398  sevastopol
# 29213                  https://www.avito.ru/3806632067  sevastopol
# 25746        https://krym.cian.ru/sale/flat/300740613/       sudak
# 41159                  https://www.avito.ru/3756674252  sevastopol
# 43260                  https://www.avito.ru/3834625534  sevastopol
# 4618   https://sevastopol.cian.ru/sale/flat/280688563/  sevastopol
# 70867                  https://www.avito.ru/3762163767       sudak
#
#                                        title subtitle     price  \
# 26740  апартаменты-студия, 36,2 м², 2/10 эт.      NaN  11900000
# 57972        2-к. квартира, 58,9 м², 8/9 эт.      NaN  10700000
# 54786       1-к. апартаменты, 25 м², 4/6 эт.      NaN   7600000
# 29213        2-к. квартира, 44,3 м², 3/5 эт.      NaN   8000000
# 25746    апартаменты-студия, 45 м², 2/8 этаж           14000000
# 41159          2-к. квартира, 43 м², 2/3 эт.      NaN   8100000
# 43260        2-к. квартира, 63,2 м², 7/9 эт.      NaN   9150000
# 4618     1-комн. квартира, 34,4 м², 1/9 этаж            6600000
# 70867          1-к. квартира, 36 м², 8/8 эт.      NaN   6000000
#
#                                                  address  \
# 26740                                 Парковая улица , 7
# 57972                     улица Генерала Мельника, 11А/1
# 54786                       Фиолентовское шоссе , 134 к4
# 29213                                  улица Ерошенко, 8
# 25746       Республика Крым, Судак, улица Набережная, 75
# 41159                           улица Надежды Краевой, 1
# 43260  ЖК «Porto Franco»\n улица Западный берег Камыш...
# 4618   Севастополь, р-н Ленинский, мкр. Острякова, пр...
# 70867                              Серный перeулок , 12А
#
#                                              description  \
# 26740  Продаются апартаменты в лучшем Курортном компл...
# 57972  Двуxкомнaтная квaртиpa 58.9 м2, на 8-м этаже 9...
# 54786  Предлагаю к продаже квартиру у моря 25 кв. М. ...
# 29213  Продается отличная 2-к квартира, в лучшем райо...
# 25746  Объект 254. К продаже предлагаются роскошные а...
# 41159  Собственник! Северная сторона Севастополя, нап...
# 43260  Продаётся 2-комнатная квартира №46, площадь 63...
# 4618   В продаже уютная однокомнатная квартира в Лени...
# 70867  Продается квартира в Жк Мадера 4 корпус, новос...
#
#                               ts  nrooms  floor  ...  area  is_studio  \
# 26740 2024-08-26 14:48:05.820089       0      2  ...  36.2       True
# 57972 2024-08-20 09:44:31.092411       2      8  ...  58.9      False
# 54786 2024-07-08 13:29:07.581057       1      4  ...  25.0      False
# 29213 2024-09-09 12:47:04.646000       2      3  ...  44.3      False
# 25746 2024-06-13 11:23:14.304133       0      2  ...  45.0       True
# 41159 2024-06-17 08:29:48.414678       2      2  ...  43.0      False
# 43260 2024-07-22 11:05:31.760224       2      7  ...  63.2      False
# 4618  2024-06-07 11:33:12.800097       0      1  ...  34.4      False
# 70867 2024-07-22 11:21:20.039093       1      8  ...  36.0      False
#
#        is_apartment  is_part  is_auction  is_openspace  is_roof  is_SNT  \
# 26740          True    False       False         False    False   False
# 57972         False    False       False         False    False   False
# 54786          True    False       False         False    False   False
# 29213         False    False       False         False    False   False
# 25746          True    False       False         False    False   False
# 41159         False    False       False         False    False   False
# 43260         False    False       False         False    False   False
# 4618          False    False       False         False    False   False
# 70867         False    False       False         False    False   False
#
#        priceM  is_last_floor
# 26740   11.90          False
# 57972   10.70          False
# 54786    7.60          False
# 29213    8.00          False
# 25746   14.00          False
# 41159    8.10          False
# 43260    9.15          False
# 4618     6.60          False
# 70867    6.00           True
#
# [9 rows x 21 columns]

# %% [markdown]
# ---

# %%
obj_type = 'land'
files = [ f'{d}/{f}' for d in source[obj_type] for f in listdir(d) if f[-4:]=='.pkl' ]
display( len(files) )

cols = ['url','place','title','subtitle','price','address','description','ts',]

df_land = pd.concat([
        pd.read_pickle(f).drop_duplicates(['url'])
        for f in files
    ]).reset_index(drop=True)[cols]

display( len(df_land) )
display(df_land.sample(9))
# Out:
# 95
# 61389
#                                                      url       place  \
# 43795                    https://www.avito.ru/4207694064  sevastopol
# 543    https://sevastopol.cian.ru/sale/suburban/30279...  sevastopol
# 46647                    https://www.avito.ru/4261881397  sevastopol
# 2891   https://sevastopol.cian.ru/sale/suburban/29863...  sevastopol
# 35798                    https://www.avito.ru/3657569784       sudak
# 57449                    https://www.avito.ru/3752269158  sevastopol
# 22915                    https://www.avito.ru/4090029225  sevastopol
# 24743                    https://www.avito.ru/3784415295  sevastopol
# 40706                    https://www.avito.ru/1188893265  sevastopol
#
#                              title subtitle    price  \
# 43795  Участок 6,1 сот. (СНТ, ДНП)      NaN  3500000
# 543              Участок, 3.2 сот.           1700000
# 46647         Участок 4 сот. (ИЖС)      NaN  2150000
# 2891          Участок, 4 сот., ИЖС           4350000
# 35798         Участок 7 сот. (ИЖС)      NaN  2900000
# 57449  Участок 4,4 сот. (СНТ, ДНП)      NaN  6000000
# 22915   Участок 12 сот. (СНТ, ДНП)      NaN  3700000
# 24743    Участок 6 сот. (СНТ, ДНП)      NaN  2800000
# 40706         Участок 8 сот. (ИЖС)      NaN  6500000
#
#                                                  address  \
# 43795                               СНТ Сапун-гора, 1501
# 543    Севастополь, р-н Нахимовский, мкр. Любимовка, ...
# 46647                                         с. Полюшко
# 2891      Севастополь, р-н Ленинский, улица Остен-Сакена
# 35798                                с. Солнечная Долина
# 57449               садоводческое товарищество Энтузиаст
# 22915  Балаклава, садоводческое товарищество Благодат...
# 24743                       садовое товарищество Водолаз
# 40706                      с. Черноречье, ул. Ешиль-Мале
#
#                                              description  \
# 43795  Продаётся участок 6,11. Сот. Снт «Сапун-гора»....
# 543    Продаю замечательный участок площадью 4 сотки ...
# 46647  Продам участок Ижз, 4 сотки, прямоугольный, ви...
# 2891   Продается участок ИЖС 4 сотки в центральном ра...
# 35798  Земельный участок 7 соток. Ровный, правильной ...
# 57449  Участок в очень удобном месте. От участка до о...
# 22915  Объект №1148. Продается видовой участок 12 сот...
# 24743  Продам участок 6 сот. В Севастополе. Участок к...
# 40706  Продам Земельный участок под Ижс. Готов рассмо...
#
#                               ts
# 43795 2024-07-22 11:12:26.881258
# 543   2024-06-11 10:17:41.455159
# 46647 2024-07-30 16:22:13.854597
# 2891  2024-06-07 11:37:10.690720
# 35798 2024-06-19 12:38:53.091938
# 57449 2024-06-11 10:32:52.971878
# 22915 2024-06-17 08:36:13.464806
# 24743 2024-06-10 11:25:16.532576
# 40706 2024-06-14 13:13:27.377070

# %%
from lib.cleaner import CleanerLand

df_land = CleanerLand().transform(df_land)

display( len(df_land) )
display(df_land.sample(9))
# Out:
# 61389
#                                                      url        place  \
# 52235                    https://www.avito.ru/4025775527        sudak
# 39489                    https://www.avito.ru/3958197111  bahchisaray
# 8795   https://sevastopol.cian.ru/sale/suburban/30222...   sevastopol
# 23878                    https://www.avito.ru/2834046433        sudak
# 17764  https://sevastopol.cian.ru/sale/suburban/30235...   sevastopol
# 34897                    https://www.avito.ru/3533562323   sevastopol
# 21136                    https://www.avito.ru/2740353071  bahchisaray
# 13758  https://sevastopol.cian.ru/sale/suburban/30337...   sevastopol
# 14979  https://sevastopol.cian.ru/sale/suburban/29999...   sevastopol
#
#                            title subtitle    price  \
# 52235  участок 6 сот. (снт, днп)      NaN  1600000
# 39489       участок 6 сот. (ижс)      NaN  2000000
# 8795        участок, 5 сот., ижс           1950000
# 23878  участок 6 сот. (снт, днп)      NaN  1100000
# 17764            участок, 8 сот.           1500000
# 34897     участок 8,6 сот. (ижс)      NaN  3500000
# 21136    участок 2 га (снт, днп)      NaN   800000
# 13758          участок, 4.5 сот.           3500000
# 14979      участок, 10 сот., ижс           2597000
#
#                                                  address  \
# 52235                                      с. Миндальное
# 39489                        Республика Крым, Бахчисарай
# 8795   Севастополь, р-н Нахимовский, улица Федоровска...
# 23878                с. Миндальное, СНТ Солнечная Долина
# 17764  Севастополь, р-н Балаклавский, Орлиновский мун...
# 34897                          с. Фруктовое, Сумская ул.
# 21136                                        пос. Сирень
# 13758  Севастополь, р-н Гагаринский, мкр. Фиолент, Св...
# 14979          Севастополь, р-н Балаклавский, с. Озерное
#
#                                              description  \
# 52235  Объект №147. Продам участок в с. Миндальное, 6...
# 39489  Продам участок, Ижс в Бахчисарае 9мкр. Район а...
# 8795   Объект 2922. Предлагаю Вам к покупке отличный ...
# 23878  Продам видовой участок с видом на мыс Меганом ...
# 17764  Продам земельный участок в Байдарской долине,в...
# 34897  Арт. 58655582. Продается земельный участок Ижс...
# 21136  Собственник. Продам участок сельскохозяйственн...
# 13758  Объект 17980. Продам участок в р-не Горбатого ...
# 14979  Арт. 61903554 - 10 соток ИЖС в Озерном -Первая...
#
#                               ts   area  is_IJS  priceM   priceMU  \
# 52235 2024-06-07 12:06:21.568118    6.0   False   1.600  0.266667
# 39489 2024-06-10 11:38:42.490270    6.0    True   2.000  0.333333
# 8795  2024-09-03 13:49:29.818498    5.0    True   1.950  0.390000
# 23878 2024-06-24 13:03:08.984518    6.0   False   1.100  0.183333
# 17764 2024-06-14 13:00:38.621423    8.0   False   1.500  0.187500
# 34897 2024-08-06 11:09:38.953015    8.6    True   3.500  0.406977
# 21136 2024-08-20 10:02:49.280771  200.0   False   0.800  0.004000
# 13758 2024-06-18 10:50:11.786732    5.0   False   3.500  0.700000
# 14979 2024-08-06 11:07:20.938325   10.0    True   2.597  0.259700
#
#       area_size_category
# 52235                4-8
# 39489                4-8
# 8795                 4-8
# 23878                4-8
# 17764                4-8
# 34897               8-12
# 21136                20+
# 13758                4-8
# 14979               8-12

# %% [markdown]
# ---

# %%
obj_type = 'house'
files = [ f'{d}/{f}' for d in source[obj_type] for f in listdir(d) if f[-4:]=='.pkl' ]
display( len(files) )

cols = ['url','place','title','subtitle','price','address','description','ts',]

df_house = pd.concat([
        pd.read_pickle(f).drop_duplicates(['url'])
        for f in files
    ]).reset_index(drop=True)[cols]

display( len(df_house) )
display(df_house.sample(9))
# Out:
# 95
# 55200
#                                                      url       place  \
# 15388  https://sevastopol.cian.ru/sale/suburban/29596...  sevastopol
# 39773                    https://www.avito.ru/3961893191  sevastopol
# 45560                    https://www.avito.ru/2576239186  sevastopol
# 54105                    https://www.avito.ru/3318853253  sevastopol
# 17041  https://sevastopol.cian.ru/sale/suburban/29719...  sevastopol
# 13544  https://sevastopol.cian.ru/sale/suburban/29800...  sevastopol
# 52268                    https://www.avito.ru/2857497539  sevastopol
# 27012                    https://www.avito.ru/3322882353  sevastopol
# 24832                    https://www.avito.ru/3374303670  sevastopol
#
#                                     title subtitle     price  \
# 15388  Дом, 127 м², 3.9 сот., Садоводство            8000000
# 39773      Дом 140 м² на участке 5,1 сот.      NaN   9500000
# 45560      Дача 92 м² на участке 4,5 сот.      NaN   5000000
# 54105    Дом 197,7 м² на участке 2,2 сот.      NaN  20400000
# 17041     Дом, 51 м², 6 сот., Садоводство            4500000
# 13544         Дом, 94,9 м², 6.3 сот., ИЖС            6500000
# 52268      Дача 50 м² на участке 4,5 сот.      NaN   6000000
# 27012        Дом 500 м² на участке 7 сот.      NaN  35000000
# 24832         Дом 80 м² на участке 4 сот.      NaN   7600000
#
#                                                  address  \
# 15388  Севастополь, р-н Нахимовский, Чайка-1 садовое ...
# 39773            садоводческое товарищество Гераклея, 95
# 45560                      Севастополь, СТ Солнечный, 41
# 54105                                    ул. Авдеева, 32
# 17041         Севастополь, р-н Ленинский, Восход ТСН, 97
# 13544  Севастополь, р-н Нахимовский, Сапун-гора СНТ, ...
# 52268  Гагаринский муниципальный округ, мкр-н Казачья...
# 27012                                        ул. Громова
# 24832                                      ТСН Союз, 268
#
#                                              description  \
# 15388  Объект 1267. Продам новый просторный современн...
# 39773  Объект №677. Продается дом 139,3 м² на участке...
# 45560  Дача район ул. Отрадная с одной стороны и по о...
# 54105  Предлагаю в продажу отличный дом в центральной...
# 17041  Продается дом 53,1 м2 в СТ Восход (Максимова д...
# 13544  Арт. 59072439 Прoдaётся дoм в CHТ Сапун-горa с...
# 52268  Продаётся дача с пропиской в снт Скалистый. На...
# 27012  Продаётся гостевой дом -500кв. М. + участок 7 ...
# 24832  Дом, для круглогодичного проживания. С ремонто...
#
#                               ts
# 15388 2024-07-08 14:05:28.543820
# 39773 2024-08-20 09:57:45.024714
# 45560 2024-06-19 12:36:50.932990
# 54105 2024-07-30 16:29:45.104005
# 17041 2024-06-14 13:06:13.997742
# 13544 2024-06-18 10:55:44.416781
# 52268 2024-06-07 11:52:05.094685
# 27012 2024-06-13 11:32:06.964835
# 24832 2024-06-17 08:43:09.491886

# %%
# cols = ['title','address','place','url']
# df_house[ (df_house['place']=='sevastopol') & (df_house['address'].str.match(r'.*Судак.*')) ][cols]

# %%
from lib.cleaner import CleanerHouse

df_house = CleanerHouse().transform(df_house)

display( len(df_house) )
display(df_house.sample(9))
# Out:
# 55200
#                                                      url       place  \
# 3276       https://krym.cian.ru/sale/suburban/273811410/       sudak
# 36495                    https://www.avito.ru/3675121717  sevastopol
# 31895                    https://www.avito.ru/4109518410  sevastopol
# 49623                    https://www.avito.ru/3917220215  sevastopol
# 36853                    https://www.avito.ru/2939720419  sevastopol
# 10692  https://sevastopol.cian.ru/sale/suburban/29291...  sevastopol
# 52143                    https://www.avito.ru/3848002528  sevastopol
# 13115  https://sevastopol.cian.ru/sale/suburban/30112...  sevastopol
# 17609  https://sevastopol.cian.ru/sale/suburban/30228...  sevastopol
#
#                                  title subtitle     price  \
# 3276         дом, 73,2 м², 8 сот., ижс            5200000
# 36495      дом 55 м² на участке 1 сот.      NaN   3650000
# 31895    дом 61,4 м² на участке 4 сот.      NaN   5950000
# 49623    дом 25 м² на участке 4,3 сот.      NaN   3600000
# 36853      дом 80 м² на участке 4 сот.      NaN   3550000
# 10692  дом, 60 м², 5 сот., садоводство            3500000
# 52143     дом 150 м² на участке 4 сот.      NaN  11000000
# 13115          коттедж, 100 м², 4 сот.            6290000
# 17609       дом, 100 м², 5.4 сот., днп            9300000
#
#                                                  address  \
# 3276   Республика Крым, Феодосия городской округ, Щеб...
# 36495                                    Фёдоровская ул.
# 31895                        ТСН СТ Фиолент, Пятая линия
# 49623                  садоводческое товарищество Динамо
# 36853                             район Северная Сторона
# 10692  Севастополь, р-н Балаклавский, Медик-88 садово...
# 52143                                        Севастополь
# 13115  Севастополь, р-н Нахимовский, с. Осипенко, ули...
# 17609  Севастополь, р-н Гагаринский, мкр. Фиолент, Ча...
#
#                                              description  \
# 3276   Продам дом 73,2м2 на 8 сот земли пгт. Щебетовк...
# 36495  Предлагается к продаже дача на берегу моря в с...
# 31895  Арт. 71633325. Продажа двухэтажного дома рядом...
# 49623  Арт. 62946436. Предлагается к покупке дом на з...
# 36853  Предлагаем к продаже отличный дом 80 м кв на С...
# 10692  Объект 1425. В СНТ Медик 88 продаётся двухэтаж...
# 52143  Арт. 51082024 Двухэтажный дом в СТ Лукоморье! ...
# 13115  Дом 100 м² на участке 4 сотки, одноэтажный. Ра...
# 17609  Продается уютный дом из ракушки в живописном м...
#
#                               ts  house_area  is_part  is_townhouse  is_SNT  \
# 3276  2024-07-22 11:19:38.978616        73.2    False         False   False
# 36495 2024-06-11 10:41:08.345000        55.0    False         False   False
# 31895 2024-09-09 13:01:38.475470        61.4    False         False    True
# 49623 2024-07-22 11:20:00.587621        25.0    False         False    True
# 36853 2024-06-11 10:41:08.345000        80.0    False         False   False
# 10692 2024-06-19 12:37:23.275933        60.0    False         False    True
# 52143 2024-06-07 11:52:05.094685       150.0    False         False   False
# 13115 2024-06-18 10:55:44.416781       100.0    False         False   False
# 17609 2024-06-14 13:06:13.997742       100.0    False         False    True
#
#        land_area  priceM land_size_category house_size_category
# 3276         8.0    5.20                4-8              70-110
# 36495        1.0    3.65                 <1               50-70
# 31895        4.0    5.95                2-4               50-70
# 49623        4.3    3.60                4-8                 <30
# 36853        4.0    3.55                2-4              70-110
# 10692        5.0    3.50                4-8               50-70
# 52143        4.0   11.00                2-4             110-180
# 13115        4.0    6.29                2-4              70-110
# 17609        4.0    9.30                2-4              70-110

# %% [markdown]
# ## обновляем таблицу адресов

# %%
# !pip install geopy

# %%
# df_flat['address'].str.strip().drop_duplicates().sort_values().to_csv('tmp/flat_address.txt',index=False,header=False)
# df_land['address'].str.strip().drop_duplicates().sort_values().to_csv('tmp/land_address.txt',index=False,header=False)
# df_house['address'].str.strip().drop_duplicates().sort_values().to_csv('tmp/house_address.txt',index=False,header=False)

# %%
from lib.locator import AddressTransformer

atr = AddressTransformer()

places = { 
# поле 'place' и название города
'bahchisaray': 'Бахчисарай,',
      'sudak': 'Судак,',
  'sevastopol': 'Севастополь,',
}

def address_norm(df,atr=atr):
    df['address_orig'] =  df['address']
    df['address'] =  df['address'].apply(atr.transform)
    df['place_'] =  df['place'].map(places)
    df['address'] = df[['address','place_']].apply(lambda d: d[0] if d[1] in d[0] else d[1]+','+d[0],axis=1) 
    df['address'] = (
        df['address']
        .str.replace(', ',',')
        .str.replace(',,',',')
        .str.replace('. ','.')
        .str.replace('\n',' ')
        .str.replace('  ',' ')
        .str.lower()
    )
    return df

# %%
df_flat = address_norm(df_flat)
df_land = address_norm(df_land)
df_house = address_norm(df_house)
# Out:
# /tmp/ipykernel_2329482/776805188.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['address'] = df[['address','place_']].apply(lambda d: d[0] if d[1] in d[0] else d[1]+','+d[0],axis=1)
# /tmp/ipykernel_2329482/776805188.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['address'] = df[['address','place_']].apply(lambda d: d[0] if d[1] in d[0] else d[1]+','+d[0],axis=1)
# /tmp/ipykernel_2329482/776805188.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['address'] = df[['address','place_']].apply(lambda d: d[0] if d[1] in d[0] else d[1]+','+d[0],axis=1)

# %%
# df_flat[['address','address_orig']]

# %%
address = pd.concat([
        df_flat[['address','address_orig']],
        df_land[['address','address_orig']],
        df_house[['address','address_orig']],
    ]).drop_duplicates(['address']).reset_index(drop=True)

display(len(address))
display(address.sample(5))
# Out:
# 13460
#                                                 address  \
# 8246  севастополь,садоводческое некоммерческое товар...
# 4982  судак,республика крым,судак городской округ,с....
# 2476                    севастополь,улица горпищенко,82
# 7140              бахчисарай,садовые участки 3-й массив
# 5235  севастополь,р-н балаклавский,с.орлиное,улица и...
#
#                                            address_orig
# 8246  садоводческое некоммерческое товарищество Скал...
# 4982  Республика Крым, Судак городской округ, с. Сол...
# 2476                               улица Горпищенко, 82
# 7140                         садовые участки 3-й массив
# 5235  Севастополь, р-н Балаклавский, с. Орлиное, ули...

# %%
from os.path import exists as path_exists
loc_file_path = 'data/location.pkl' # таблица адресов

location = pd.DataFrame([],columns=['address','latitude','longitude',])
if path_exists( loc_file_path ):
    location = pd.read_pickle(loc_file_path).drop_duplicates(['address']).reset_index(drop=True)
    
display(len(location))
display(location.sample(5))
# Out:
# 19789
#                                                  address   latitude  longitude
# 16988              севастополь,улица генерала хрюкина,18  44.566529  33.528639
# 15214                         севастополь,тсн восход,100  44.566574  33.549956
# 9734   севастополь,район гагаринский,летчики,улица ко...  44.584668  33.464984
# 19598  севастополь,нахимовский район ,любимовка,кварт...  44.651106  33.549093
# 6864   севастополь,р-н гагаринский,мкр.фиолент,сосенк...  44.550845  33.455525

# %% [markdown]
# ---

# %%
# def address_norm_(df):
#     df['address_orig'] =  df['address']
#     # df['address'] =  df['address'].apply(atr.transform)
#     df['address'] = (
#         df['address']
#         .str.replace(', ',',')
#         .str.replace(',,',',')
#         .str.replace('. ','.')
#         .str.replace('\n',' ')
#         .str.replace('  ',' ')
#         .str.lower()
#     )
#     return df

# %%
# location = address_norm_(location)

# %%
# location = location[['address','latitude','longitude']]

# %% [markdown]
# ---

# %%
# собираем все адреса в один список
location = location.merge(
        address[['address']].drop_duplicates(),
        how='outer',
        on='address',
    ).drop_duplicates(['address']).reset_index(drop=True)

display(len(location))
display(location.sample(5))
# Out:
# 19980
#                                                  address   latitude  longitude
# 17696               севастополь,улица инженерная балка,9  44.626266  33.541512
# 3837                         севастополь,пасечная ул.,17  44.647874  33.586805
# 17396                 севастополь,улица героев бреста,35  44.586934  33.446641
# 604              бахчисарай,с.севастьяновка,ул.саурчи,28  44.819883  33.936106
# 13287  севастополь,садоводческое товарищество подорож...  44.536024  33.487909

# %%
display(len(location))
display(location['latitude'].isnull().sum())
# Out:
# 19980
# 191

# %%
# собираем все адреса с геопозицией
location_def = location[~location['latitude'].isna()].reset_index(drop=True)
display(len(location_def))

# собираем все адреса без геопозиции
location_undef = location[location['latitude'].isna()][['address']].reset_index(drop=True)
display(len(location_undef))
# Out:
# 19789
# 191

# %%
display(location_undef)
# Out:
#                                                address
# 0                              бахчисарай,пос.стальное
# 1                       бахчисарай,промышленная ул.,28
# 2    бахчисарай,республика крым,долинненское сельск...
# 3          бахчисарай,с.верхоречье,красноармейская ул.
# 4                  бахчисарай,с.викторовка,ул.мектепли
# ..                                                 ...
# 186          судак,с.солнечная долина,квартал яны-къоз
# 187              судак,с.солнечная долина,тенистая ул.
# 188                        судак,севастопольская ул.,3
# 189                   судак,ст меганом,облепиховая ул.
# 190                       судак,улица айвазовского,25а
#
# [191 rows x 1 columns]

# %%
from tqdm.auto import tqdm
tqdm.pandas()

# %%
# from lib.locator import GeocoderSimpleOSM
from lib.locator import GeocoderYandex
from yandex_keys import keys

atr = AddressTransformer()
locator = GeocoderYandex(keys[0])
# locator = GeocoderSimpleOSM()

if len(location_undef)>0:
    # определяем координаты по строке адреса
    location_undef = location_undef.join( 
            location_undef['address'].progress_apply(locator.transform).apply(pd.Series) 
        ).dropna()     
    display(f'LocationUpdater: {len(location_undef)} new addresses found')
    location = pd.concat([location_def,location_undef]).reset_index(drop=True) 
    assert len(location)>0
    # location.to_pickle(loc_file_path)
# Out:
#   0%|          | 0/191 [00:00<?, ?it/s]
# 'LocationUpdater: 191 new addresses found'

# %%
display( len(location) )
display( location.sample(3) )
# Out:
# 19980
#                                      address   latitude  longitude
# 3901          севастополь,пластунский пр.,41  44.587454  33.550019
# 18060  севастополь,улица разведчика колобуна  44.571692  33.538835
# 2406                  севастополь,горпищенко  44.591344  33.567123

# %%
assert len(location)>0
location.to_pickle(loc_file_path)

# %% [markdown]
# ## дополняем данные геометкой

# %%
display( len(df_flat) )
df_flat  = df_flat.merge(location,on='address').reset_index(drop=True) 
display( len(df_flat) )
display( df_flat.sample(3) )
# Out:
# 71167
# 71167
#                                                    url       place  \
# 64803                  https://www.avito.ru/3736671065  sevastopol
# 61472                  https://www.avito.ru/3950660992  sevastopol
# 9010   https://sevastopol.cian.ru/sale/flat/299737603/  sevastopol
#
#                                       title subtitle    price  \
# 64803        1-к. квартира, 40 м², 1/16 эт.      NaN  7400000
# 61472         3-к. квартира, 72 м², 1/5 эт.      NaN  8500000
# 9010   1-комн. квартира, 37,2 м², 5/10 этаж           8500000
#
#                                                  address  \
# 64803                   севастополь,улица степаняна,2ак1
# 61472                   севастополь,улица хрусталёва,163
# 9010   севастополь,р-н гагаринский,мкр.5-й,улица тара...
#
#                                              description  \
# 64803  Однокомнатная квартира м2, эт. Однокомнатная к...
# 61472  Продажа От Собственника! Просторная, светлая и...
# 9010   Продаётся просторная однокомнатная квартира по...
#
#                               ts  nrooms  floor  ...  is_auction  \
# 64803 2024-06-11 10:25:30.856703       1      1  ...       False
# 61472 2024-06-07 11:27:07.236636       3      1  ...       False
# 9010  2024-07-30 16:07:58.352115       0      5  ...       False
#
#        is_openspace  is_roof  is_SNT  priceM  is_last_floor  \
# 64803         False    False   False     7.4          False
# 61472         False    False   False     8.5          False
# 9010          False    False   False     8.5          False
#
#                                             address_orig        place_  \
# 64803                              улица Степаняна, 2Ак1  Севастополь,
# 61472                              улица Хрусталёва, 163  Севастополь,
# 9010   Севастополь, р-н Гагаринский, мкр. 5-й, улица ...  Севастополь,
#
#         latitude  longitude
# 64803  44.591684  33.468946
# 61472  44.553587  33.526402
# 9010    44.57645  33.459001
#
# [3 rows x 25 columns]

# %%
display( len(df_land) )
df_land  = df_land.merge(location,on='address').reset_index(drop=True) 
display( len(df_land) )
display( df_land.sample(3) )
# Out:
# 61389
# 61389
#                                                      url       place  \
# 10707  https://sevastopol.cian.ru/sale/suburban/29421...  sevastopol
# 45830                    https://www.avito.ru/3424530120  sevastopol
# 38400                    https://www.avito.ru/3661418505  sevastopol
#
#                              title subtitle     price  \
# 10707        участок, 15 сот., ижс            4500000
# 45830  участок 4,2 сот. (снт, днп)      NaN   4000000
# 38400        участок 10 сот. (ижс)      NaN  12000000
#
#                                                  address  \
# 10707  севастополь,р-н балаклавский,с.гончарное,улица...
# 45830  севастополь,садоводческое товарищество рыбак-6,13
# 38400                      севастополь,коралловая ул.,1а
#
#                                              description  \
# 10707  Объект 240. Продам участок 15 соток, в живопис...
# 45830  Продам участок с хорошими подъездными путями, ...
# 38400  Арт_67585555. К продаже предлагается Земельный...
#
#                               ts  area  is_IJS  priceM   priceMU  \
# 10707 2024-06-13 11:16:11.805581  15.0    True     4.5  0.300000
# 45830 2024-07-30 16:22:13.854597   4.2   False     4.0  0.952381
# 38400 2024-07-08 13:36:06.464523  10.0    True    12.0  1.200000
#
#       area_size_category                                       address_orig  \
# 10707              12-20  Севастополь, р-н Балаклавский, с. Гончарное, у...
# 45830                4-8             садоводческое товарищество Рыбак-6, 13
# 38400               8-12                                 Коралловая ул., 1А
#
#              place_   latitude  longitude
# 10707  Севастополь,  44.464415  33.693336
# 45830  Севастополь,  44.568096  33.432366
# 38400  Севастополь,  44.585598  33.475153

# %%
display( len(df_house) )
df_house = df_house.merge(location,on='address').reset_index(drop=True) 
display( len(df_house) )
display( df_house.sample(3) )
# Out:
# 55200
# 55200
#                                                      url        place  \
# 18161  https://sevastopol.cian.ru/sale/suburban/26427...   sevastopol
# 47400                    https://www.avito.ru/3433891529  bahchisaray
# 12091      https://krym.cian.ru/sale/suburban/301718119/        sudak
#
#                               title subtitle     price  \
# 18161         дом, 40 м², 6.57 сот.            4700000
# 47400  дом 42 м² на участке 10 сот.      NaN   4950000
# 12091      дом, 221 м², 6 сот., ижс           20000000
#
#                                                  address  \
# 18161  севастополь,р-н гагаринский,мкр.фиолент,клеры-...
# 47400                бахчисарай,с.синапное,запрудная ул.
# 12091                        судак,республика крым,судак
#
#                                              description  \
# 18161  Дом 40 м2 на участке 6,57 соток Дом 40 м2 на у...
# 47400  Дом со всеми удобствами, заезжай и живи, отлич...
# 12091  Продается жилой дом в городе Судак, квартал Су...
#
#                               ts  house_area  is_part  is_townhouse  is_SNT  \
# 18161 2024-06-07 11:42:40.789431        40.0    False         False    True
# 47400 2024-07-22 11:25:30.126492        42.0    False         False   False
# 12091 2024-06-17 08:28:56.608317       221.0    False         False   False
#
#        land_area  priceM land_size_category house_size_category  \
# 18161       57.0    4.70                20+               30-50
# 47400       10.0    4.95               8-12               30-50
# 12091        6.0   20.00                4-8             180-300
#
#                                             address_orig        place_  \
# 18161  Севастополь, р-н Гагаринский, мкр. Фиолент, Кл...  Севастополь,
# 47400                         с. Синапное, Запрудная ул.   Бахчисарай,
# 12091                             Республика Крым, Судак        Судак,
#
#         latitude  longitude
# 18161  44.549175   33.45522
# 47400  44.670969  34.015014
# 12091  44.850532  34.976157

# %%
# def address_filter(df):
#     #           46.319437, 33.911048
#     #
#     # 45.402617, 32.455625 |  45.545301, 36.684702
#     #
#     #          44.320887, 33.917013

#     df['latitude'] = pd.to_numeric( df['latitude'], errors='coerce' )
#     df['longitude'] = pd.to_numeric( df['longitude'], errors='coerce' )

#     df = df.query('(32.4<longitude<36.7) & (44.3<latitude<46.4)') 

#     df.loc[ df['url']=='https://avito.ru/2322251740', ['latitude','longitude']] = None

#     df.loc[ df['address']=='Севастополь,Чёрное море', ['latitude','longitude'] ] = None
#     df.loc[ df['address'].str.lower().str.match('чёрное море'), ['latitude','longitude'] ] = None 

#     df.loc[ df['address']=='квартал Старый Город', 'place'] = 'turkie'
#     df.loc[ df['address'].str.lower().str.match('анталья'), 'place' ] = 'turkie' 

#     df.loc[ df['address'].str.lower().str.match(r'.*бахчисарай.*'), 'place' ] = 'bahchisaray'
#     df.loc[ df['address'].str.lower().str.match(r'.*севастополь,.*'), 'place' ] = 'sevastopol'

#     df.loc[ df['address'].str.lower().str.match(r'.*мысовское.*'), 'place' ] = 'kerch'
#     df.loc[ df['address'].str.lower().str.match(r'.*алушта.*'), 'place' ] = 'alushta'
#     df.loc[ df['address'].str.lower().str.match(r'.*гурзуф.*'), 'place' ] = 'gurzuf'

#     df.loc[ df['address'].str.lower().str.match(r'.*с.лучистое.*'), 'place' ] = 'alushta'
#     df.loc[ df['address'].str.lower().str.match(r'.*снт солнечная долина.*'), 'place' ] = 'sudak'
#     df.loc[ df['address'].str.lower().str.match(r'.*пгт.новоозёрное.*'), 'place' ] = 'evpatoria'

#     df.loc[ df['address'].str.lower().str.match(r'.*с.мирное.*'), 'place' ] = 'simferopol'
#     df.loc[ df['address'].str.lower().str.match(r'.*тсн аэрофлот.*'), 'place' ] = 'simferopol'

#     df.loc[ df['address'].str.lower().str.match(r'.*семисот.*'), 'place' ] = 'kerch'

#     df.loc[ df['address'].str.lower().str.match(r'.*ялта.*') , 'place' ] = 'yalta'
#     df.loc[ df['address'].str.lower().str.match(r'.*феодосия.*') , 'place' ] = 'feodosia'
#     df.loc[ df['address'].str.lower().str.match(r'.*окуневка.*') , 'place' ] = 'tarkhankut'
#     df.loc[ df['address'].str.lower().str.match(r'.*заветное.*') , 'place' ] = 'kerch'
#     df.loc[ df['address'].str.lower().str.match(r'.*евпатория.*') , 'place' ] = 'evpatoria'
#     df.loc[ df['address'].str.lower().str.match(r'.*симферопольский район.*'), 'place' ] = 'simferopol'

#     df.loc[df['address'].str.match(r'.*белогорск.*'),'place'] = 'belogorsk'
#     df.loc[df['address'].str.match(r'.*кировский.*'),'place'] = 'kirovsky'
#     df.loc[df['address'].str.match(r'.*сакский район.*'),'place'] = 'saki'
#     df.loc[df['address'].str.match(r'.*керчь.*'),'place'] = 'kerch'
#     df.loc[df['address'].str.match(r'.*белогорский.*'),'place'] = 'belogorsk'
#     df.loc[df['address'].str.match(r'.*кировский.*'),'place'] = 'kirovski'

#     df.loc[df['address'].str.match(r'.*кореиз.*'),'place'] = 'ubk'
#     df.loc[df['address'].str.match(r'.*малый маяк.*'),'place'] = 'ubk'
#     df.loc[df['address'].str.match(r'.*светлый мир.*'),'place'] = 'simferopol'
#     df.loc[df['address'].str.match(r'.*доброе.*'),'place'] = 'simferopol'
#     df.loc[df['address'].str.match(r'.*родниково.*'),'place'] = 'simferopol'
#     df.loc[df['address'].str.match(r'.*уютное.*'),'place'] = 'evpatoria'
#     df.loc[df['address'].str.match(r'.*коктебель.*'),'place'] = 'koktebel'
#     df.loc[df['address'].str.match(r'.*новосельское.*'),'place'] = 'tarhankut'

#     df = df.dropna(subset=['latitude','longitude'])
    
#     return df

# %%
# display(len(df_flat))
# df_flat = address_filter(df_flat)
# display(len(df_flat))

# display(len(df_land))
# df_land = address_filter(df_land)
# display(len(df_land))

# display(len(df_house))
# df_house = address_filter(df_house)
# display(len(df_house))

# %%
assert len(df_flat)>0
df_flat.to_pickle(f'{data_root_folder}/df_flat.pkl')

assert len(df_land)>0
df_land.to_pickle(f'{data_root_folder}/df_land.pkl')

assert len(df_house)>0
df_house.to_pickle(f'{data_root_folder}/df_house.pkl')

# %%
# !date
# Out:
# Пн 09 сен 2024 13:49:25 MSK
