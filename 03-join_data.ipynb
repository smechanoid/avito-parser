# %% [markdown]
# __собираем объявления о продаже недвижимости в одну таблицу__
#
# _Evgeny S. Borisov <parser@mechanoid.su>_

# %%
# !date
# Out:
# Пн 12 авг 2024 11:36:46 MSK

# %%
from os import listdir
import re
import pandas as pd

# %%
data_root_folder = 'data/2024'
source = {
         'flat':[data_root_folder+'/raw/flat/cian',data_root_folder+'/raw/flat/avito'],
        'house':[data_root_folder+'/raw/house/cian',data_root_folder+'/raw/house/avito'],
         'land':[data_root_folder+'/raw/land/cian',data_root_folder+'/raw/land/avito'],
    }

# %% [markdown]
# ---

# %%
obj_type = 'flat'
files = [ f'{d}/{f}' for d in source[obj_type] for f in listdir(d) if f[-4:]=='.pkl' ]
display( len(files) )

cols = ['url','place','title','subtitle','price','address','description','ts',]

df_flat = pd.concat([
        pd.read_pickle(f).drop_duplicates(['url'])
        for f in files
    ]).reset_index(drop=True)[cols]

display( len(df_flat) )
display(df_flat.sample(9))
# Out:
# 60
# 55847
#                                                    url       place  \
# 19473  https://sevastopol.cian.ru/sale/flat/282199914/  sevastopol
# 5292   https://sevastopol.cian.ru/sale/flat/300552843/  sevastopol
# 18764  https://sevastopol.cian.ru/sale/flat/302626030/  sevastopol
# 41938                  https://www.avito.ru/4055895313  sevastopol
# 30858                  https://www.avito.ru/3850625763  sevastopol
# 40459                  https://www.avito.ru/3981055273  sevastopol
# 38269                  https://www.avito.ru/3225447540  sevastopol
# 34073                  https://www.avito.ru/3813713058       sudak
# 9919         https://krym.cian.ru/sale/flat/301444448/       sudak
#
#                                         title subtitle     price  \
# 19473    1-комн. квартира, 56,6 м², 4/11 этаж           12452000
# 5292      1-комн. квартира, 31,3 м², 3/9 этаж            5500000
# 18764     1-комн. квартира, 30,8 м², 6/9 этаж            5800000
# 41938           1-к. квартира, 43 м², 3/5 эт.      NaN   6250000
# 30858         1-к. квартира, 30,3 м², 5/5 эт.      NaN   5400000
# 40459         3-к. квартира, 70,1 м², 4/5 эт.      NaN   7700000
# 38269       1-к. апартаменты, 30 м², 5/10 эт.      NaN  11200000
# 34073         1-к. квартира, 34,5 м², 8/9 эт.      NaN   6734000
# 9919   3-комн. апартаменты, 89,3 м², 2/3 этаж           35700000
#
#                                                  address  \
# 19473    Севастополь, р-н Гагаринский, улица Парковая, 7
# 5292   Севастополь, р-н Гагаринский, мкр. Камышовая б...
# 18764  Севастополь, р-н Гагаринский, мкр. Летчики, ул...
# 41938                            ул. Генерала Лебедя, 10
# 30858                            ул. Маршала Блюхера, 18
# 40459                                     Казачья ул., 9
# 38269                                    Парковая ул., 7
# 34073  Комплекс апартаментов «Бирюзовый квартал»\nул....
# 9919     Республика Крым, Судак, улица Набережная, 75к11
#
#                                              description  \
# 19473
# 5292   Объект 38. Продается с ремонтом, мебелью и тех...
# 18764  БЕЗ КОМИССИИ ДЛЯ ПОКУПАТЕЛЯ!!! Продается однок...
# 41938  Продам в г. Севастополе ул. Генерала Лебедя,10...
# 30858  Объект №1566. Продаётся уютная 1-комнатная ква...
# 40459  K Пpодaже Предлагаeтcя Прoстoрhaя Kbaртирa В Л...
# 38269  Продаются элитные апартаменты в лучшем 5-ти зв...
# 34073  Ремонт В Подарок до 15.08.24г. Скидка 100 000 ...
# 9919   Первая линия моря, круглогодичный спа комплекс...
#
#                               ts
# 19473 2024-06-24 12:36:04.449533
# 5292  2024-06-07 11:33:12.800097
# 18764 2024-06-18 10:45:27.403294
# 41938 2024-07-08 13:29:07.581057
# 30858 2024-07-22 11:05:31.760224
# 40459 2024-07-30 16:15:15.853171
# 38269 2024-08-06 11:02:57.284493
# 34073 2024-07-30 16:30:58.800714
# 9919  2024-07-22 11:12:52.007628

# %%
from lib.cleaner import CleanerFlat

df_flat = CleanerFlat().transform(df_flat)
display( len(df_flat) )
display(df_flat.sample(9))
# Out:
# 55847
#                                                    url       place  \
# 6400   https://sevastopol.cian.ru/sale/flat/295065037/  sevastopol
# 30425                  https://www.avito.ru/3625364275  sevastopol
# 190          https://krym.cian.ru/sale/flat/296384951/       sudak
# 53798                  https://www.avito.ru/3755167168  sevastopol
# 9357   https://sevastopol.cian.ru/sale/flat/299737090/  sevastopol
# 46352                  https://www.avito.ru/4236136486  sevastopol
# 50264                  https://www.avito.ru/3880876291  sevastopol
# 7921   https://sevastopol.cian.ru/sale/flat/302531616/  sevastopol
# 19219  https://sevastopol.cian.ru/sale/flat/276529734/  sevastopol
#
#                                        title  \
# 6400                 студия, 33 м², 1/3 этаж
# 30425        1-к. квартира, 43,2 м², 4/9 эт.
# 190    2-комн. квартира, 117,93 м², 7/8 этаж
# 53798          3-к. квартира, 77 м², 3/3 эт.
# 9357   1-комн. апартаменты, 53 м², 2/10 этаж
# 46352       1-к. квартира, 34,1 м², 3/11 эт.
# 50264        1-к. квартира, 44,3 м², 4/5 эт.
# 7921       1-комн. квартира, 22 м², 4/5 этаж
# 19219      купить квартиру в севастополе. пр
#
#                                      subtitle     price  \
# 6400                                            3300000
# 30425                                     NaN   7084800
# 190      Секция С5 • Сдача корпуса 1 кв. 2027  20944128
# 53798                                     NaN   9950000
# 9357                                           14500000
# 46352                                     NaN   6820000
# 50264                                     NaN   7400000
# 7921                                            4200000
# 19219  1-комн. апартаменты, 46,6 м², 4/5 этаж   4500000
#
#                                                  address  \
# 6400   Севастополь, р-н Гагаринский, мкр. Стрелецкая ...
# 30425   ЖК «Доброгород»\n улица Токарева, 8 этап, блок 4
# 190                Республика Крым, Судак, Долина Роз ЖК
# 53798                                улица Челнокова, 39
# 9357     Севастополь, р-н Гагаринский, улица Парковая, 7
# 46352                          улица Тараса Шевченко, 18
# 50264                            улица Героев Бреста, 31
# 7921   Севастополь, р-н Балаклавский, село Первомайск...
# 19219  Севастополь, р-н Гагаринский, улица Адмирала Ф...
#
#                                              description  \
# 6400   Продаётся квартира-студия в Гагаринском районе...
# 30425  Сдача объекта — I кв. 2027 г. Доступна ипотека...
# 190    Продается квартира общей площадью 117,93 м2 в ...
# 53798  Объект №1432. Продам 3-комнатную квартиру в мо...
# 9357   Однокомнатные апартаменты 53 м2, на 2/10 эт. О...
# 46352  Квартира от собственника, на 3 этаже 11 этажно...
# 50264  Предлагаем Вашему вниманию однокомнатную кварт...
# 7921   Продаётся уютная однокомнатная квартира в живо...
# 19219  Срочно!Продаются видовые апартаменты в Стрелец...
#
#                               ts  nrooms  floor  ...    area  is_studio  \
# 6400  2024-06-14 12:56:14.435965       0      1  ...   33.00       True
# 30425 2024-06-17 08:29:48.414678       1      4  ...   43.20      False
# 190   2024-06-18 10:56:35.757139       0      7  ...  117.93      False
# 53798 2024-06-10 11:17:35.151941       3      3  ...   77.00      False
# 9357  2024-07-30 16:07:58.352115       0      2  ...   53.00      False
# 46352 2024-06-07 11:27:07.236636       1      3  ...   34.10      False
# 50264 2024-06-11 10:25:30.856703       1      4  ...   44.30      False
# 7921  2024-06-11 10:13:23.305322       0      4  ...   22.00      False
# 19219 2024-06-24 12:36:04.449533       0      0  ...    0.00      False
#
#        is_apartment  is_part  is_auction  is_openspace  is_roof  is_SNT  \
# 6400          False    False       False         False    False   False
# 30425         False    False       False         False    False   False
# 190           False    False       False         False    False   False
# 53798         False    False       False         False    False   False
# 9357           True    False       False         False    False   False
# 46352         False    False       False         False    False   False
# 50264         False    False       False         False    False   False
# 7921          False    False       False         False    False   False
# 19219         False    False       False         False    False   False
#
#           priceM  is_last_floor
# 6400    3.300000          False
# 30425   7.084800          False
# 190    20.944128          False
# 53798   9.950000           True
# 9357   14.500000          False
# 46352   6.820000          False
# 50264   7.400000          False
# 7921    4.200000          False
# 19219   4.500000           True
#
# [9 rows x 21 columns]

# %% [markdown]
# ---

# %%
obj_type = 'land'
files = [ f'{d}/{f}' for d in source[obj_type] for f in listdir(d) if f[-4:]=='.pkl' ]
display( len(files) )

cols = ['url','place','title','subtitle','price','address','description','ts',]

df_land = pd.concat([
        pd.read_pickle(f).drop_duplicates(['url'])
        for f in files
    ]).reset_index(drop=True)[cols]

display( len(df_land) )
display(df_land.sample(9))
# Out:
# 75
# 50163
#                                                      url        place  \
# 31927                    https://www.avito.ru/2800811623   sevastopol
# 6771   https://sevastopol.cian.ru/sale/suburban/30256...   sevastopol
# 19684                    https://www.avito.ru/3937499205   sevastopol
# 10762  https://sevastopol.cian.ru/sale/suburban/30257...   sevastopol
# 45885                    https://www.avito.ru/3503970097   sevastopol
# 15541  https://sevastopol.cian.ru/sale/suburban/30419...   sevastopol
# 42746                    https://www.avito.ru/3890295706        sudak
# 24232                    https://www.avito.ru/3664350929  bahchisaray
# 33720                    https://www.avito.ru/3503160306  bahchisaray
#
#                                 title subtitle    price  \
# 31927       Участок 5 сот. (СНТ, ДНП)      NaN  2050000
# 6771   Участок, 5.3 сот., Садоводство           4200000
# 19684     Участок 4,5 сот. (СНТ, ДНП)      NaN  2500000
# 10762  Участок, 6.2 сот., Садоводство           3500000
# 45885            Участок 9 сот. (ИЖС)      NaN  1100000
# 15541           Участок, 10 сот., ИЖС           2450000
# 42746          Участок 5,8 сот. (ИЖС)      NaN  3500000
# 24232          Участок 8,1 сот. (ИЖС)      NaN  3500000
# 33720         Участок 3 га (СНТ, ДНП)      NaN  9999000
#
#                                                  address  \
# 31927               садоводческое товарищество Лукулл, 9
# 6771   Севастополь, р-н Балаклавский, шоссе Монастырс...
# 19684                 садоводческое товарищество Техника
# 10762  Севастополь, р-н Гагаринский, мкр. Фиолент, Гр...
# 45885                        с. Фронтовое, Солнечная ул.
# 15541  Севастополь, р-н Балаклавский, с. Родниковское...
# 42746                                      квартал Алчак
# 24232                                     Альминская ул.
# 33720                                       с. Новополье
#
#                                              description  \
# 31927  Цена актуальна до конца недели. Собственник. П...
# 6771   Продаю участок на первой линии в районе конечн...
# 19684  Угловой, с уклоном, квадратной формы, частично...
# 10762  Продам участок на Фиоленте, СНТ Гранат, 6,2 со...
# 45885  Продам земельный участок в Нахимовском районе ...
# 15541  Объект 16864. Южный берег Крыма (сокращенно ЮБ...
# 42746  Продается участок недалеко от Восточного шоссе...
# 24232  Продам участок, документы Российские, я собств...
# 33720  Продам уникальный земельный участок 3 га в с. ...
#
#                               ts
# 31927 2024-07-08 13:36:06.464523
# 6771  2024-06-17 08:22:17.440170
# 19684 2024-06-17 08:36:13.464806
# 10762 2024-06-19 12:23:33.870565
# 45885 2024-06-11 10:32:52.971878
# 15541 2024-07-30 16:15:42.641826
# 42746 2024-06-07 12:06:21.568118
# 24232 2024-07-30 16:34:04.489119
# 33720 2024-06-10 11:38:42.490270

# %%
from lib.cleaner import CleanerLand

df_land = CleanerLand().transform(df_land)

display( len(df_land) )
display(df_land.sample(9))
# Out:
# 50163
#                                                      url        place  \
# 21749                    https://www.avito.ru/3864743358   sevastopol
# 42806                    https://www.avito.ru/2138394932        sudak
# 44224                    https://www.avito.ru/4167067976  bahchisaray
# 44504                    https://www.avito.ru/4187510003  bahchisaray
# 3746   https://sevastopol.cian.ru/sale/suburban/29754...   sevastopol
# 31445                    https://www.avito.ru/4070075853   sevastopol
# 39400                    https://www.avito.ru/3819342594        sudak
# 27464                    https://www.avito.ru/3811899199  bahchisaray
# 20303                    https://www.avito.ru/3550706740   sevastopol
#
#                              title subtitle     price  \
# 21749         участок 8 сот. (ижс)      NaN   2850000
# 42806       участок 8,3 сот. (ижс)      NaN   1900000
# 44224   участок 35 сот. (снт, днп)      NaN   2500000
# 44504    участок 8 сот. (снт, днп)      NaN    600000
# 3746          участок, 4 сот., ижс            5700000
# 31445  участок 3,9 сот. (снт, днп)      NaN   4500000
# 39400         участок 8 сот. (ижс)      NaN   3700001
# 27464        участок 16 сот. (ижс)      NaN   3000000
# 20303         участок 7 сот. (ижс)      NaN  28500000
#
#                                                  address  \
# 21749                                         с. Угловое
# 42806                    с. Богатовка, ул. Новый квартал
# 44224                     с. Солнечноселье, Зелёный пер.
# 44504                                квартал Новый Город
# 3746   Севастополь, р-н Нахимовский, Солнышко садовод...
# 31445                ТСН Дружба, ул. Старшины Бабажанова
# 39400                 с. Солнечная Долина, ул. Матвиенко
# 27464                             с. Вилино, ул. Шалаева
# 20303                                     Древняя ул., 8
#
#                                              description  \
# 21749  Продается земельный участок, ровный, без уклон...
# 42806  Продается участок в селе Богатовка, ул. Новый ...
# 44224  Прекрасный видовой участок Лпх 35 соток рядом ...
# 44504  Продаются земельные участки по 8 соток, земли ...
# 3746   Участок 4 сотки (СТ) в г. Севастополь, Нахимов...
# 31445  Квадратный участок, ровный. Городская вода( кр...
# 39400  Угловой участок. Расположен на пересечении ули...
# 27464  Собственник! Важно дочитать объявление до конц...
# 20303  Предлагается к продаже земельный участок в гор...
#
#                               ts  area  is_IJS     priceM   priceMU  \
# 21749 2024-06-10 11:25:16.532576   8.0    True   2.850000  0.356250
# 42806 2024-06-07 12:06:21.568118   8.3    True   1.900000  0.228916
# 44224 2024-07-22 11:24:37.881374  35.0   False   2.500000  0.071429
# 44504 2024-07-22 11:24:37.881374   8.0   False   0.600000  0.075000
# 3746  2024-08-12 11:10:58.029975   4.0    True   5.700000  1.425000
# 31445 2024-07-08 13:36:06.464523   3.9   False   4.500000  1.153846
# 39400 2024-07-16 12:51:23.262228   8.0    True   3.700001  0.462500
# 27464 2024-06-11 10:49:42.413688  16.0    True   3.000000  0.187500
# 20303 2024-06-17 08:36:13.464806   7.0    True  28.500000  4.071429
#
#       area_size_category
# 21749                4-8
# 42806               8-12
# 44224                20+
# 44504                4-8
# 3746                 2-4
# 31445                2-4
# 39400                4-8
# 27464              12-20
# 20303                4-8

# %% [markdown]
# ---

# %%
obj_type = 'house'
files = [ f'{d}/{f}' for d in source[obj_type] for f in listdir(d) if f[-4:]=='.pkl' ]
display( len(files) )

cols = ['url','place','title','subtitle','price','address','description','ts',]

df_house = pd.concat([
        pd.read_pickle(f).drop_duplicates(['url'])
        for f in files
    ]).reset_index(drop=True)[cols]

display( len(df_house) )
display(df_house.sample(9))
# Out:
# 75
# 46014
#                                                      url        place  \
# 16356  https://sevastopol.cian.ru/sale/suburban/29714...   sevastopol
# 12795  https://sevastopol.cian.ru/sale/suburban/30259...   sevastopol
# 2105   https://sevastopol.cian.ru/sale/suburban/28548...   sevastopol
# 23106                    https://www.avito.ru/3250911497   sevastopol
# 10202  https://sevastopol.cian.ru/sale/suburban/29475...   sevastopol
# 29087                    https://www.avito.ru/3816689204  bahchisaray
# 39901                    https://www.avito.ru/2849235377  bahchisaray
# 29902                    https://www.avito.ru/3751777855   sevastopol
# 19336                    https://www.avito.ru/3285141880  bahchisaray
#
#                                     title subtitle     price  \
# 16356  Дом, 110,8 м², 4 сот., Садоводство            9980000
# 12795    Дом, 110 м², 4 сот., Садоводство           11000000
# 2105                Дом, 50,1 м², 16 сот.            5400000
# 23106        Дом 106 м² на участке 4 сот.      NaN  14000000
# 10202   Дом, 45,5 м², 4 сот., Садоводство            6400000
# 29087      Дом 44,7 м² на участке 24 сот.      NaN   5100000
# 39901       Дом 116 м² на участке 10 сот.      NaN   3700000
# 29902    Дом 190,7 м² на участке 8,8 сот.      NaN  13499000
# 19336       Дом 52,3 м² на участке 6 сот.      NaN   4950000
#
#                                                  address  \
# 16356  Севастополь, р-н Гагаринский, Торпеда садоводч...
# 12795  Севастополь, р-н Гагаринский, Янтарь садоводче...
# 2105   Севастополь, р-н Балаклавский, с. Родниковское...
# 23106                                       Камышовое ш.
# 10202  Севастополь, р-н Гагаринский, мкр. Фиолент, Ко...
# 29087                                     с. Высокое, 34
# 39901                                   ул. Висовина, 17
# 29902    садовое товарищество Гавань, ул. Волонтеров, 12
# 19336                                          Новая ул.
#
#                                              description  \
# 16356  ДОМ НА ЗЕМЕЛЬНОМ УЧАСТКЕ У ЧЕРНОГО МОРЯ! (г. С...
# 12795  Продается одноэтажный дом в СТ "Янтарь" площад...
# 2105   Продам дом в одном из самых красивых мест Крым...
# 23106  Продается дом в Гагаринском районе, в черте го...
# 10202  Дом 45,5 м² на участке 4 сотки Дом 45,5 м² на ...
# 29087  Продается одноэтажный дом 44,7 кв. М. На участ...
# 39901  Продам дом в центре города. Требует капитально...
# 29902  Арт. 63569957 Срочная Продажа! Экодом с приуса...
# 19336  Дом находится в городе Бахчисарай, недалеко от...
#
#                               ts
# 16356 2024-06-14 13:06:13.997742
# 12795 2024-06-18 10:55:44.416781
# 2105  2024-06-17 08:27:31.304082
# 23106 2024-06-13 11:32:06.964835
# 10202 2024-06-19 12:37:23.275933
# 29087 2024-06-24 13:06:17.982273
# 39901 2024-07-08 13:49:26.679246
# 29902 2024-06-10 11:33:36.811644
# 19336 2024-06-14 13:24:56.973530

# %%
# cols = ['title','address','place','url']
# df_house[ (df_house['place']=='sevastopol') & (df_house['address'].str.match(r'.*Судак.*')) ][cols]

# %%
from lib.cleaner import CleanerHouse

df_house = CleanerHouse().transform(df_house)

display( len(df_house) )
display(df_house.sample(9))
# Out:
# 46014
#                                                      url        place  \
# 19108      https://krym.cian.ru/sale/suburban/284017012/        sudak
# 40938                    https://www.avito.ru/3998350887  bahchisaray
# 29268                    https://www.avito.ru/3720063196   sevastopol
# 15510  https://sevastopol.cian.ru/sale/suburban/29669...   sevastopol
# 1488   https://sevastopol.cian.ru/sale/suburban/30268...   sevastopol
# 7541       https://krym.cian.ru/sale/suburban/295803442/        sudak
# 12817  https://sevastopol.cian.ru/sale/suburban/30141...   sevastopol
# 2168   https://sevastopol.cian.ru/sale/suburban/29855...   sevastopol
# 20435                    https://www.avito.ru/4208071690   sevastopol
#
#                                       title subtitle      price  \
# 19108            дом, 300 м², 5.5 сот., ижс            10300000
# 40938      дом 110,6 м² на участке 6,8 сот.      NaN    2700000
# 29268          дом 110 м² на участке 8 сот.      NaN   12300000
# 15510                    дом, 47 м², 4 сот.             5200000
# 1488               дом, 110 м², 4 сот., ижс             9600000
# 7541                 дом, 2 248 м², 15 сот.           130000000
# 12817      дом, 150 м², 4 сот., садоводство            11000000
# 2168   дом, 53,3 м², 3.95 сот., садоводство             6100000
# 20435         дом 25 м² на участке 5,4 сот.      NaN    4500000
#
#                                                  address  \
# 19108             Республика Крым, Судак, улица Лазурная
# 40938  садоводческий потребительский кооператив Энтуз...
# 29268                                           СТ Берег
# 15510  Севастополь, р-н Балаклавский, Технолог садово...
# 1488   Севастополь, р-н Нахимовский, улица Генерала Р...
# 7541       Республика Крым, Судак, улица Консульская, 20
# 12817  Севастополь, р-н Гагаринский, мкр. Фиолент, Лу...
# 2168      Севастополь, р-н Балаклавский, Корабел СТ, 320
# 20435          садоводческое товарищество Дергачи-4, 187
#
#                                              description  \
# 19108  Продается недостроенный дом расположенный в кв...
# 40938  Продается жилой дом в дачном кооперативе, дом ...
# 29268  Продам дом в одном из лучших СТ Северной сторо...
# 15510  Дом 50 м² на участке 4 сотки Дом 50 м² на учас...
# 1488   Объект 242. Предлагаю приобрести дом в совреме...
# 7541   Продается недостроенный многоквартирный дом на...
# 12817  Двухэтажный дом в СТ Лукоморье!!! Дом 150 м2 н...
# 2168   Уникальное предложение! Продаётся уютный, небо...
# 20435  Арт. 69557313 Этот объект можно купить в ипоте...
#
#                               ts  house_area  is_part  is_townhouse  is_SNT  \
# 19108 2024-07-16 12:55:43.335990       300.0    False         False   False
# 40938 2024-06-10 11:39:39.442400       110.6    False         False    True
# 29268 2024-06-10 11:33:36.811644       110.0    False         False    True
# 15510 2024-06-14 13:06:13.997742        47.0    False         False    True
# 1488  2024-06-17 08:27:31.304082       110.0    False         False   False
# 7541  2024-06-10 11:25:21.743717       248.0    False         False   False
# 12817 2024-06-18 10:55:44.416781       150.0    False         False    True
# 2168  2024-06-17 08:27:31.304082        53.3    False         False    True
# 20435 2024-07-16 12:49:11.298800        25.0    False         False    True
#
#        land_area  priceM land_size_category house_size_category
# 19108        5.0    10.3                4-8             180-300
# 40938        6.8     2.7                4-8             110-180
# 29268        8.0    12.3                4-8              70-110
# 15510        4.0     5.2                2-4               30-50
# 1488         4.0     9.6                2-4              70-110
# 7541        15.0   130.0              12-20             180-300
# 12817        4.0    11.0                2-4             110-180
# 2168        95.0     6.1                20+               50-70
# 20435        5.4     4.5                4-8                 <30

# %% [markdown]
# ---

# %% [markdown]
# ## обновляем таблицу адресов

# %%
# !pip install geopy

# %%
from lib.locator import AddressTransformer

atr = AddressTransformer()

places = { 
# поле 'place' и название города
'bahchisaray': 'Бахчисарай,',
      'sudak': 'Судак,',
  'sevastopol': 'Севастополь,',
}

def address_norm(df,atr=atr):
    df['address_orig'] =  df['address']
    df['address'] =  df['address'].apply(atr.transform)
    df['place_'] =  df['place'].map(places)
    df['address'] = df[['address','place_']].apply(lambda d: d[0] if d[1] in d[0] else d[1]+','+d[0],axis=1) 
    df['address'] = (
        df['address']
        .str.replace(', ',',')
        .str.replace(',,',',')
        .str.replace('. ','.')
        .str.replace('\n',' ')
        .str.replace('  ',' ')
        .str.lower()
    )
    return df

# %%
df_flat = address_norm(df_flat)
df_land = address_norm(df_land)
df_house = address_norm(df_house)
# Out:
# /tmp/ipykernel_2301970/776805188.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['address'] = df[['address','place_']].apply(lambda d: d[0] if d[1] in d[0] else d[1]+','+d[0],axis=1)
# /tmp/ipykernel_2301970/776805188.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['address'] = df[['address','place_']].apply(lambda d: d[0] if d[1] in d[0] else d[1]+','+d[0],axis=1)
# /tmp/ipykernel_2301970/776805188.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['address'] = df[['address','place_']].apply(lambda d: d[0] if d[1] in d[0] else d[1]+','+d[0],axis=1)

# %%
# df_flat[['address','address_orig']]

# %%
address = pd.concat([
        df_flat[['address','address_orig']],
        df_land[['address','address_orig']],
        df_house[['address','address_orig']],
    ]).drop_duplicates(['address']).reset_index(drop=True)

display(len(address))
display(address.sample(5))
# Out:
# 12337
#                                                 address  \
# 7204           бахчисарай,с.новоульяновка,советская ул.
# 7407                            севастополь,пл.лазарева
# 3106            севастополь,балаклава,улица аксютина,39
# 8521  севастополь,р-н нахимовский,с.вишневое,улица к...
# 5671  севастополь,садоводческое товарищество золотая...
#
#                                            address_orig
# 7204                    с. Новоульяновка, Советская ул.
# 7407                                       пл. Лазарева
# 3106                      Балаклава, улица Аксютина, 39
# 8521  Севастополь, р-н Нахимовский, с. Вишневое, ули...
# 5671       садоводческое товарищество Золотая Балка, 98

# %%
from os.path import exists as path_exists
loc_file_path = 'data/location.pkl' # таблица адресов

location = pd.DataFrame([],columns=['address','latitude','longitude',])
if path_exists( loc_file_path ):
    location = pd.read_pickle(loc_file_path).drop_duplicates(['address']).reset_index(drop=True)
    
display(len(location))
display(location.sample(5))
# Out:
# 18817
#                                                  address   latitude  longitude
# 9449       севастополь,район гагаринский,улица щитовая,8  44.603616  33.463619
# 7712   севастополь,р-н нахимовский,мкр.горпищенко,ули...  44.595214  33.558912
# 9974   севастополь,район нахимовский,кача,улица авиат...  44.774067  33.542796
# 18527  бахчисарай,садоводческое товарищество строител...  44.740253  33.894433
# 10216   севастополь,район нахимовский,улица курчатова,15  44.628614  33.570437

# %% [markdown]
# ---

# %%
# def address_norm_(df):
#     df['address_orig'] =  df['address']
#     # df['address'] =  df['address'].apply(atr.transform)
#     df['address'] = (
#         df['address']
#         .str.replace(', ',',')
#         .str.replace(',,',',')
#         .str.replace('. ','.')
#         .str.replace('\n',' ')
#         .str.replace('  ',' ')
#         .str.lower()
#     )
#     return df

# %%
# location = address_norm_(location)

# %%
# location = location[['address','latitude','longitude']]

# %% [markdown]
# ---

# %%
# собираем все адреса в один список
location = location.merge(
        address[['address']].drop_duplicates(),
        how='outer',
        on='address',
    ).drop_duplicates(['address']).reset_index(drop=True)

display(len(location))
display(location.sample(5))
# Out:
# 19065
#                                                  address   latitude  longitude
# 18397  судак,республика крым,судак городской округ,с....  44.849484  34.885068
# 5080            севастополь,р-н балаклавский,рубин ст,58  44.539467  33.584245
# 7918   севастополь,р-н нахимовский,мираж садовое това...   44.71718  33.551914
# 2670                 севастополь,кача,улица авиаторов,25  44.775936  33.545392
# 12102  севастополь,садоводческое товарищество золотая...  44.519733  33.550836

# %%
display(len(location))
display(location['latitude'].isnull().sum())
# Out:
# 19065
# 248

# %%
# собираем все адреса с геопозицией
location_def = location[~location['latitude'].isna()].reset_index(drop=True)
display(len(location_def))

# собираем все адреса без геопозиции
location_undef = location[location['latitude'].isna()][['address']].reset_index(drop=True)
display(len(location_undef))
# Out:
# 18817
# 248

# %%
display(location_undef)
# Out:
#                                        address
# 0         бахчисарай,пгт.почтовое,вишнёвая ул.
# 1        бахчисарай,с.вилино,спортивная ул.,35
# 2           бахчисарай,с.высокое,ул.строителей
# 3         бахчисарай,с.глубокий яр,ул.чешме,32
# 4       бахчисарай,с.красный мак,ул.ленина,46а
# ..                                         ...
# 243  судак,с.солнечная долина,квартал бугаз,79
# 244     судак,садовое товарищество ветеран,147
# 245                  судак,серный переулок ,12
# 246               судак,улица айвазовского,4/1
# 247                     судак,улица бирюзова,4
#
# [248 rows x 1 columns]

# %%
from tqdm.auto import tqdm
tqdm.pandas()

# %%
# from lib.locator import GeocoderSimpleOSM
from lib.locator import GeocoderYandex
from yandex_keys import keys

atr = AddressTransformer()
locator = GeocoderYandex(keys[0])
# locator = GeocoderSimpleOSM()

if len(location_undef)>0:
    # определяем координаты по строке адреса
    location_undef = location_undef.join( 
            location_undef['address'].progress_apply(locator.transform).apply(pd.Series) 
        ).dropna()     
    display(f'LocationUpdater: {len(location_undef)} new addresses found')
    location = pd.concat([location_def,location_undef]).reset_index(drop=True) 
    assert len(location)>0
    # location.to_pickle(loc_file_path)
# Out:
#   0%|          | 0/248 [00:00<?, ?it/s]
# 'LocationUpdater: 248 new addresses found'

# %%
display( len(location) )
display( location.sample(3) )
# Out:
# 19065
#                                                  address   latitude  longitude
# 10141  севастополь,район нахимовский,горпищенко,улица...  44.590586  33.566368
# 5545     севастополь,р-н балаклавский,улица каширская,1а  44.606074  33.590946
# 11119                   севастополь,с.угловое,ул.лазо,44  44.816456  33.614976

# %%
assert len(location)>0
location.to_pickle(loc_file_path)

# %% [markdown]
# ## дополняем данные геометкой

# %%
display( len(df_flat) )
df_flat  = df_flat.merge(location,on='address').reset_index(drop=True) 
display( len(df_flat) )
display( df_flat.sample(3) )
# Out:
# 55847
# 55847
#                                                    url       place  \
# 9854         https://krym.cian.ru/sale/flat/304682549/       sudak
# 52259                  https://www.avito.ru/3881037543  sevastopol
# 2803   https://sevastopol.cian.ru/sale/flat/303562878/  sevastopol
#
#                                         title subtitle    price  \
# 9854   апартаменты-студия, 31,95 м², 3/8 этаж           5751000
# 52259         3-к. квартира, 54,3 м², 3/5 эт.      NaN  8000000
# 2803      1-комн. квартира, 31,1 м², 1/5 этаж           4950000
#
#                                                  address  \
# 9854        республика крым,судак,улица айвазовского,4/1
# 52259               севастополь,улица маршала блюхера,13
# 2803   севастополь,р-н ленинский,мкр.острякова,улица ...
#
#                                              description  \
# 9854   Без комиссии для покупателя ! Продаются уютные...
# 52259  Продаю трехкомнатную квартиру в спальном район...
# 2803   Oднокoмнaтная квaртира в центральнoм рaйоне Ce...
#
#                               ts  nrooms  floor  ...  is_auction  \
# 9854  2024-07-22 11:12:52.007628       0      3  ...       False
# 52259 2024-06-13 11:17:37.489999       3      3  ...       False
# 2803  2024-07-16 12:28:31.306616       0      1  ...       False
#
#        is_openspace  is_roof  is_SNT  priceM  is_last_floor  \
# 9854          False    False   False   5.751          False
# 52259         False    False   False   8.000          False
# 2803          False    False   False   4.950          False
#
#                                             address_orig        place_  \
# 9854     Республика Крым, Судак, улица Айвазовского, 4/1        Судак,
# 52259                          улица Маршала Блюхера, 13  Севастополь,
# 2803   Севастополь, р-н Ленинский, мкр. Острякова, ул...  Севастополь,
#
#         latitude  longitude
# 9854   44.851733  34.969689
# 52259  44.583018  33.436957
# 2803    44.56981  33.518865
#
# [3 rows x 25 columns]

# %%
display( len(df_land) )
df_land  = df_land.merge(location,on='address').reset_index(drop=True) 
display( len(df_land) )
display( df_land.sample(3) )
# Out:
# 50163
# 50163
#                                                      url        place  \
# 9415   https://sevastopol.cian.ru/sale/suburban/29311...   sevastopol
# 35928                    https://www.avito.ru/2508008634  bahchisaray
# 35858                    https://www.avito.ru/1397676898  bahchisaray
#
#                             title subtitle     price  \
# 9415       участок, 7.3 сот., ижс           16300000
# 35928  участок 2,11 га (снт, днп)      NaN    700000
# 35858   участок 2,9 га (снт, днп)      NaN   1200000
#
#                                                  address  \
# 9415   севастополь,р-н гагаринский,мкр.камышовая бухт...
# 35928                        бахчисарай,с.нововасильевка
# 35858    бахчисарай,республика крым,бахчисарайский район
#
#                                              description  \
# 9415   Объект 1078. Продам участок по улице Героев Ст...
# 35928  Продам пай сельхозназначения 2,1 га. Земельный...
# 35858  Продам землю с/х 2,9га рядом с Бахчисараем. По...
#
#                               ts   area  is_IJS  priceM   priceMU  \
# 9415  2024-06-13 11:16:11.805581    3.0    True    16.3  5.433333
# 35928 2024-06-13 11:36:28.263004  211.0   False     0.7  0.003318
# 35858 2024-06-13 11:36:28.263004  290.0   False     1.2  0.004138
#
#       area_size_category                                       address_orig  \
# 9415                 2-4  Севастополь, р-н Гагаринский, мкр. Камышовая б...
# 35928                20+                                  с. Нововасильевка
# 35858                20+              Республика Крым, Бахчисарайский район
#
#              place_   latitude  longitude
# 9415   Севастополь,  44.588609  33.443721
# 35928   Бахчисарай,  44.849005  33.915112
# 35858   Бахчисарай,  44.744997  33.848035

# %%
display( len(df_house) )
df_house = df_house.merge(location,on='address').reset_index(drop=True) 
display( len(df_house) )
display( df_house.sample(3) )
# Out:
# 46014
# 46014
#                                                      url        place  \
# 21279                    https://www.avito.ru/4186188280        sudak
# 12905  https://sevastopol.cian.ru/sale/suburban/28784...   sevastopol
# 41192                    https://www.avito.ru/2115784815  bahchisaray
#
#                                 title subtitle     price  \
# 21279  дом 213 м² на участке 7,4 сот.      NaN  15650000
# 12905             дом, 150 м², 4 сот.           12000000
# 41192    дом 80 м² на участке 15 сот.      NaN   8000000
#
#                                                  address  \
# 21279                             судак,коммунальная ул.
# 12905  севастополь,р-н гагаринский,мкр.фиолент,космос...
# 41192           бахчисарай,с.кудрино,новосёловская ул.,8
#
#                                              description  \
# 21279  Объект №497. Продам замечательный двухэтажный ...
# 12905  Продам жилой дом 150 кв.м новой постройки на Ф...
# 41192  В красивом уголке Бахчисарайского района, сред...
#
#                               ts  house_area  is_part  is_townhouse  is_SNT  \
# 21279 2024-06-19 12:39:21.598723       213.0    False         False   False
# 12905 2024-06-18 10:55:44.416781       150.0    False         False    True
# 41192 2024-06-10 11:39:39.442400        80.0    False         False   False
#
#        land_area  priceM land_size_category house_size_category  \
# 21279        7.4   15.65                4-8             180-300
# 12905        4.0   12.00                2-4             110-180
# 41192       15.0    8.00              12-20              70-110
#
#                                             address_orig        place_  \
# 21279                                   Коммунальная ул.        Судак,
# 12905  Севастополь, р-н Гагаринский, мкр. Фиолент, Ко...  Севастополь,
# 41192                   с. Кудрино, Новосёловская ул., 8   Бахчисарай,
#
#         latitude  longitude
# 21279  44.851542  34.984395
# 12905  44.544613  33.455732
# 41192   44.70392  33.949562

# %%
def address_filter(df):
    #           46.319437, 33.911048
    #
    # 45.402617, 32.455625 |  45.545301, 36.684702
    #
    #          44.320887, 33.917013

    df['latitude'] = pd.to_numeric( df['latitude'], errors='coerce' )
    df['longitude'] = pd.to_numeric( df['longitude'], errors='coerce' )

    df = df.query('(32.4<longitude<36.7) & (44.3<latitude<46.4)') 

    df.loc[ df['url']=='https://avito.ru/2322251740', ['latitude','longitude']] = None

    df.loc[ df['address']=='Севастополь,Чёрное море', ['latitude','longitude'] ] = None
    df.loc[ df['address'].str.lower().str.match('чёрное море'), ['latitude','longitude'] ] = None 

    df.loc[ df['address']=='квартал Старый Город', 'place'] = 'turkie'
    df.loc[ df['address'].str.lower().str.match('анталья'), 'place' ] = 'turkie' 

    df.loc[ df['address'].str.lower().str.match(r'.*бахчисарай.*'), 'place' ] = 'bahchisaray'
    df.loc[ df['address'].str.lower().str.match(r'.*севастополь,.*'), 'place' ] = 'sevastopol'

    df.loc[ df['address'].str.lower().str.match(r'.*мысовское.*'), 'place' ] = 'kerch'
    df.loc[ df['address'].str.lower().str.match(r'.*алушта.*'), 'place' ] = 'alushta'
    df.loc[ df['address'].str.lower().str.match(r'.*гурзуф.*'), 'place' ] = 'gurzuf'

    df.loc[ df['address'].str.lower().str.match(r'.*с.лучистое.*'), 'place' ] = 'alushta'
    df.loc[ df['address'].str.lower().str.match(r'.*снт солнечная долина.*'), 'place' ] = 'sudak'
    df.loc[ df['address'].str.lower().str.match(r'.*пгт.новоозёрное.*'), 'place' ] = 'evpatoria'

    df.loc[ df['address'].str.lower().str.match(r'.*с.мирное.*'), 'place' ] = 'simferopol'
    df.loc[ df['address'].str.lower().str.match(r'.*тсн аэрофлот.*'), 'place' ] = 'simferopol'

    df.loc[ df['address'].str.lower().str.match(r'.*семисот.*'), 'place' ] = 'kerch'

    df.loc[ df['address'].str.lower().str.match(r'.*ялта.*') , 'place' ] = 'yalta'
    df.loc[ df['address'].str.lower().str.match(r'.*феодосия.*') , 'place' ] = 'feodosia'
    df.loc[ df['address'].str.lower().str.match(r'.*окуневка.*') , 'place' ] = 'tarkhankut'
    df.loc[ df['address'].str.lower().str.match(r'.*заветное.*') , 'place' ] = 'kerch'
    df.loc[ df['address'].str.lower().str.match(r'.*евпатория.*') , 'place' ] = 'evpatoria'
    df.loc[ df['address'].str.lower().str.match(r'.*симферопольский район.*'), 'place' ] = 'simferopol'

    df.loc[df['address'].str.match(r'.*белогорск.*'),'place'] = 'belogorsk'
    df.loc[df['address'].str.match(r'.*кировский.*'),'place'] = 'kirovsky'
    df.loc[df['address'].str.match(r'.*сакский район.*'),'place'] = 'saki'
    df.loc[df['address'].str.match(r'.*керчь.*'),'place'] = 'kerch'
    df.loc[df['address'].str.match(r'.*белогорский.*'),'place'] = 'belogorsk'
    df.loc[df['address'].str.match(r'.*кировский.*'),'place'] = 'kirovski'

    df.loc[df['address'].str.match(r'.*кореиз.*'),'place'] = 'ubk'
    df.loc[df['address'].str.match(r'.*малый маяк.*'),'place'] = 'ubk'
    df.loc[df['address'].str.match(r'.*светлый мир.*'),'place'] = 'simferopol'
    df.loc[df['address'].str.match(r'.*доброе.*'),'place'] = 'simferopol'
    df.loc[df['address'].str.match(r'.*родниково.*'),'place'] = 'simferopol'
    df.loc[df['address'].str.match(r'.*уютное.*'),'place'] = 'evpatoria'
    df.loc[df['address'].str.match(r'.*коктебель.*'),'place'] = 'koktebel'
    df.loc[df['address'].str.match(r'.*новосельское.*'),'place'] = 'tarhankut'

    df = df.dropna(subset=['latitude','longitude'])
    
    return df

# %%
display(len(df_flat))
df_flat = address_filter(df_flat)
display(len(df_flat))

display(len(df_land))
df_land = address_filter(df_land)
display(len(df_land))

display(len(df_house))
df_house = address_filter(df_house)
display(len(df_house))
# Out:
# 55847
# 55156
# 50163
# 50139
# 46014
# 46012

# %%
assert len(df_flat)>0
df_flat.to_pickle(f'{data_root_folder}/df_flat.pkl')

assert len(df_land)>0
df_land.to_pickle(f'{data_root_folder}/df_land.pkl')

assert len(df_house)>0
df_house.to_pickle(f'{data_root_folder}/df_house.pkl')

# %%
# !date
# Out:
# Пн 12 авг 2024 11:38:23 MSK
