# %%
from os import listdir
import re
import pandas as pd

# %%
data_root_folder = 'data'
source = {
         'flat':[data_root_folder+'/raw/flat/cian',data_root_folder+'/raw/flat/avito'],
        'house':[data_root_folder+'/raw/house/cian',data_root_folder+'/raw/house/avito'],
         'land':[data_root_folder+'/raw/land/cian',data_root_folder+'/raw/land/avito'],
    }

# %% [markdown]
# ---

# %%
obj_type = 'flat'
files = [ f'{d}/{f}' for d in source[obj_type] for f in listdir(d) if f[-4:]=='.pkl' ]
display( len(files) )

cols = ['url','place','title','subtitle','price','address','description','ts',]

df_flat = pd.concat([
        pd.read_pickle(f).drop_duplicates(['url'])
        for f in files
    ]).reset_index(drop=True)[cols]

display( len(df_flat) )
display(df_flat.sample(9))
# Out:
# 8
# 8438
#                                                   url       place  \
# 5854                  https://www.avito.ru/3625519228  sevastopol
# 2401  https://sevastopol.cian.ru/sale/flat/293886292/  sevastopol
# 5745                  https://www.avito.ru/3817580914  sevastopol
# 4757                  https://www.avito.ru/3758146779  sevastopol
# 4548                  https://www.avito.ru/3776554897  sevastopol
# 6988                  https://www.avito.ru/3711528376  sevastopol
# 5648                  https://www.avito.ru/3625274239  sevastopol
# 2247  https://sevastopol.cian.ru/sale/flat/299736859/  sevastopol
# 3531                  https://www.avito.ru/3973913754       sudak
#
#                                     title subtitle     price  \
# 5854    Квартира-студия, 30,8 м², 3/9 эт.      NaN   5390000
# 2401   2-комн. квартира, 78 м², 5/10 этаж           12300000
# 5745    1-к. квартира, 41,3 м², 10/10 эт.      NaN   7500000
# 4757      Квартира-студия, 23 м², 3/3 эт.      NaN   1990000
# 4548        2-к. квартира, 39 м², 1/2 эт.      NaN   5900000
# 6988      3-к. квартира, 69,9 м², 1/5 эт.      NaN  12800000
# 5648    Квартира-студия, 28,3 м², 6/9 эт.      NaN   4952500
# 2247  1-комн. квартира, 35,7 м², 4/4 этаж            6450000
# 3531    Квартира-студия, 22,6 м², 5/9 эт.      NaN   4285000
#
#                                                 address  \
# 5854      ЖК «Доброгород»\nул. Токарева, 8 этап, блок 3
# 2401  Севастополь, р-н Гагаринский, мкр. Камышовая б...
# 5745                          ул. Комбрига Потапова, 24
# 4757                                   ул. Ватутина, 62
# 4548                                     ул. Супруна, 8
# 6988                                ул. Вакуленчука, 26
# 5648      ЖК «Доброгород»\nул. Токарева, 8 этап, блок 3
# 2247  Севастополь, р-н Нахимовский, улица Героев Сев...
# 3531  Комплекс апартаментов «Бирюзовый квартал»\nул....
#
#                                             description  \
# 5854  Доступна ипотека! Ипотека с господдержкой, вое...
# 2401  Объект 1115. Предлагается к продаже просторная...
# 5745  Продам видовую 1-к квартиру, 41.3 м², на 10-ом...
# 4757  Продам свою студию 23 м² в предчистовой отделк...
# 4548  В центре города продам квартиру. Остальные воп...
# 6988  Предлагается к продаже отличная 3-х комнатная ...
# 5648  Доступна ипотека! Ипотека с господдержкой, вое...
# 2247  Однокомнатная квартира площадью 35.7 м2, на 4/...
# 3531  Ипотека от 11,5% платеж от 26 000р. Кладовка В...
#
#                              ts
# 5854 2024-06-07 11:27:07.236636
# 2401 2024-06-10 11:06:41.395615
# 5745 2024-06-07 11:27:07.236636
# 4757 2024-06-07 11:27:07.236636
# 4548 2024-06-07 11:27:07.236636
# 6988 2024-06-10 11:17:35.151941
# 5648 2024-06-07 11:27:07.236636
# 2247 2024-06-10 11:06:41.395615
# 3531 2024-06-07 12:05:27.509755

# %%
from lib.cleaner import CleanerFlat

df_flat = CleanerFlat().transform(df_flat)
display( len(df_flat) )
display(df_flat.sample(9))
# Out:
# 8438
#                                                   url       place  \
# 926   https://sevastopol.cian.ru/sale/flat/299736869/  sevastopol
# 7192                  https://www.avito.ru/3819224794  sevastopol
# 688   https://sevastopol.cian.ru/sale/flat/299736660/  sevastopol
# 432   https://sevastopol.cian.ru/sale/flat/301640757/  sevastopol
# 3974                  https://www.avito.ru/3613936169       sudak
# 2234  https://sevastopol.cian.ru/sale/flat/299737514/  sevastopol
# 14          https://krym.cian.ru/sale/flat/273192286/       sudak
# 4687                  https://www.avito.ru/3892421747  sevastopol
# 5766                  https://www.avito.ru/3865380814  sevastopol
#
#                                       title subtitle     price  \
# 926   5-комн. квартира, 113,6 м², 9/10 этаж           10200000
# 7192         4-к. квартира, 126 м², 1/5 эт.      NaN  15500000
# 688    1-комн. апартаменты, 41 м², 4/9 этаж           13800000
# 432    3-комн. квартира, 107,8 м², 7/8 этаж           21000000
# 3974        1-к. квартира, 50,9 м², 2/8 эт.      NaN  11298989
# 2234    2-комн. квартира, 43,2 м², 2/5 этаж            6100000
# 14        2-комн. квартира, 34 м², 1/1 этаж            5800000
# 4687         1-к. квартира, 29 м², 9/10 эт.      NaN   6525000
# 5766        2-к. квартира, 44,5 м², 2/5 эт.      NaN   7200000
#
#                                                 address  \
# 926   Севастополь, р-н Нахимовский, улица Горпищенко...
# 7192                         площадь 50-летия СССР, 4/1
# 688     Севастополь, р-н Гагаринский, улица Парковая, 7
# 432   Севастополь, р-н Гагаринский, мкр. Омега, прос...
# 3974            ЖК «Долина Роз»\nкв-л Долина роз, 1 оч.
# 2234      Севастополь, р-н Ленинский, улица Кожанова, 1
# 14        Республика Крым, Судак, улица Партизанская, 9
# 4687                           улица Горпищенко, 143 к6
# 5766                            Пролетарская улица , 38
#
#                                             description  \
# 926   Эксклюзивная пятикомнатная двухуровневая кварт...
# 7192  Объект №1559. Продаётся 4-комнатная квартира в...
# 688   Однокомнатные апартаменты 41 м2, 4/9 эт. Однок...
# 432   Объект 1071. Продается трёхкомнатная квартира ...
# 3974  Продается квартира общей площадью 50,91 м2 в к...
# 2234  Двухкомнатная квартира 43,2 м2, на 2 этаже 5-т...
# 14    Продается 2-х комнатная квартира 33.5 кв.м.,(о...
# 4687  Все документы в порядке. Я собственник, без об...
# 5766  Двухкомнатная квартира 44.5м2, на 2/5 этаже до...
#
#                              ts  nrooms  floor  ...   area  is_studio  \
# 926  2024-06-07 11:33:12.800097       0      9  ...  113.6      False
# 7192 2024-06-10 11:17:35.151941       4      1  ...  126.0      False
# 688  2024-06-07 11:33:12.800097       0      4  ...   41.0      False
# 432  2024-06-07 11:33:12.800097       0      7  ...  107.8      False
# 3974 2024-06-10 11:35:05.787844       1      2  ...   50.9      False
# 2234 2024-06-10 11:06:41.395615       0      2  ...   43.2      False
# 14   2024-06-10 11:24:43.460368       0      1  ...   34.0      False
# 4687 2024-06-07 11:27:07.236636       1      9  ...   29.0      False
# 5766 2024-06-07 11:27:07.236636       2      2  ...   44.5      False
#
#       is_apartment  is_part  is_auction  is_openspace  is_roof  is_SNT  \
# 926          False    False       False         False    False   False
# 7192         False    False       False         False    False   False
# 688           True    False       False         False    False   False
# 432          False    False       False         False    False   False
# 3974         False    False       False         False    False   False
# 2234         False    False       False         False    False   False
# 14           False    False       False         False    False   False
# 4687         False    False       False         False    False   False
# 5766         False    False       False         False    False   False
#
#          priceM  is_last_floor
# 926   10.200000          False
# 7192  15.500000          False
# 688   13.800000          False
# 432   21.000000          False
# 3974  11.298989          False
# 2234   6.100000          False
# 14     5.800000           True
# 4687   6.525000          False
# 5766   7.200000          False
#
# [9 rows x 21 columns]

# %% [markdown]
# ---

# %%
obj_type = 'land'
files = [ f'{d}/{f}' for d in source[obj_type] for f in listdir(d) if f[-4:]=='.pkl' ]
display( len(files) )

cols = ['url','place','title','subtitle','price','address','description','ts',]

df_land = pd.concat([
        pd.read_pickle(f).drop_duplicates(['url'])
        for f in files
    ]).reset_index(drop=True)[cols]

display( len(df_land) )
display(df_land.sample(9))
# Out:
# 10
# 7473
#                                                     url        place  \
# 1125  https://sevastopol.cian.ru/sale/suburban/29971...   sevastopol
# 4975                    https://www.avito.ru/3616541296  bahchisaray
# 4025                    https://www.avito.ru/3939586849   sevastopol
# 3796                    https://www.avito.ru/2319782146   sevastopol
# 2892  https://sevastopol.cian.ru/sale/suburban/30189...   sevastopol
# 3087                    https://www.avito.ru/3434124186   sevastopol
# 5973                    https://www.avito.ru/3774573576        sudak
# 4822                    https://www.avito.ru/3906884465  bahchisaray
# 3981                    https://www.avito.ru/3952942328   sevastopol
#
#                                   title subtitle     price  \
# 1125    Участок, 4.21 сот., Садоводство            3500000
# 4975              Участок 11 сот. (ИЖС)      NaN   2500000
# 4025               Участок 6 сот. (ИЖС)      NaN   9500000
# 3796               Участок 9 сот. (ИЖС)      NaN   8700000
# 2892    Участок, 3.69 сот., Садоводство            4000000
# 3087             Участок 7,5 сот. (ИЖС)      NaN  12000000
# 5973              Участок 30 сот. (ИЖС)      NaN  22000000
# 4822               Участок 9 сот. (ИЖС)      NaN   2000000
# 3981  Участок 1,2 сот. (промназначения)      NaN   1900000
#
#                                                 address  \
# 1125  Севастополь, р-н Балаклавский, Балаклава г., Б...
# 4975                                        с. Плодовое
# 4025                                   ул. Мечникова, 2
# 3796                                      Молочный пер.
# 2892  Севастополь, р-н Нахимовский, Берег садовое то...
# 3087                    Гагаринский муниципальный округ
# 5973  с. Миндальное, СНТ Солнечная Долина, Капсельск...
# 4822                      с. Тургеневка, Парниковая ул.
# 3981                        пр-т Героев Сталинграда, 54
#
#                                             description  \
# 1125  Продается участок 4,2 сотки в Балаклаве СТ Бла...
# 4975  Продам дом. С. Плодовое, Бахчисарайского район...
# 4025  Продается прекрасный участок недвижимости в ис...
# 3796  Первая Линия От Дороги! Продам земельный участ...
# 2892  Продаётся красивый видовой участок 3,69 сотки ...
# 3087  Срочная продажа. Ижс, вид на море, все коммуни...
# 5973  В продаже 5 смежных участков в перспективном м...
# 4822  Продаю участок под строительство дома в очень ...
# 3981  Объект №1808. Продам переуступку земельного уч...
#
#                              ts
# 1125 2024-06-07 11:37:10.690720
# 4975 2024-06-07 12:09:12.165236
# 4025 2024-06-10 11:25:16.532576
# 3796 2024-06-10 11:25:16.532576
# 2892 2024-06-10 11:18:48.884876
# 3087 2024-06-10 11:25:16.532576
# 5973 2024-06-07 12:06:21.568118
# 4822 2024-06-07 12:09:12.165236
# 3981 2024-06-10 11:25:16.532576

# %%
from lib.cleaner import CleanerLand

df_land = CleanerLand().transform(df_land)

display( len(df_land) )
display(df_land.sample(9))
# Out:
# 7473
#                                                     url        place  \
# 443   https://sevastopol.cian.ru/sale/suburban/30143...   sevastopol
# 6062                    https://www.avito.ru/3094678109        sudak
# 924   https://sevastopol.cian.ru/sale/suburban/29922...   sevastopol
# 6759                    https://www.avito.ru/3900905437   sevastopol
# 3550                    https://www.avito.ru/3763633602   sevastopol
# 5700                    https://www.avito.ru/3719760080  bahchisaray
# 3814                    https://www.avito.ru/3595241249   sevastopol
# 461   https://sevastopol.cian.ru/sale/suburban/29888...   sevastopol
# 4301                    https://www.avito.ru/3962598732   sevastopol
#
#                                 title subtitle     price  \
# 443             участок, 10 сот., ижс             750000
# 6062        участок 6 сот. (снт, днп)      NaN   1300000
# 924      участок, 4 сот., садоводство            2900000
# 6759      участок 6,4 сот. (снт, днп)      NaN   2950000
# 3550      участок 9,2 сот. (снт, днп)      NaN   7850000
# 5700       участок 12 сот. (снт, днп)      NaN   2000000
# 3814  участок 9 сот. (промназначения)      NaN  25000000
# 461                участок, 12.7 сот.            1075000
# 4301           участок 7,9 сот. (ижс)      NaN   4900000
#
#                                                 address  \
# 443   Севастополь, р-н Нахимовский, Айва садоводческ...
# 6062                с. Миндальное, СНТ Солнечная Долина
# 924   Севастополь, р-н Гагаринский, мкр. Фиолент, Мр...
# 6759                                         СТ Корабел
# 3550                                             СТ Риф
# 5700  садоводческое некоммерческое товарищество Садовод
# 3814                                       Катерная ул.
# 461           Севастополь, р-н Балаклавский, с. Орлиное
# 4301  пос. 1-е отделение Золотой Балки, Междурядный ...
#
#                                             description  \
# 443   Объект 19. Продается видовой участок 10 соток ...
# 6062  Продам земельный участок площадью 6 соток для ...
# 924   Объект 1547. Продам участок 4 сотки в красивом...
# 6759  Собственник. Продам участок в СТ Корабел. 6,35...
# 3550  Продам большой участок на Фиоленте по хорошей ...
# 5700  Участок ровный готов к постройке электроэнерги...
# 3814  Объект №1346. Продам земельный участок в центр...
# 461   Продаю участок 13 соток в Севастополе в Байдар...
# 4301  Лот № 74126. Продается участок 7,9 соток (Ижс)...
#
#                              ts  area  is_IJS  priceM   priceMU  \
# 443  2024-06-07 11:37:10.690720  10.0    True   0.750  0.075000
# 6062 2024-06-10 11:36:02.209722   6.0   False   1.300  0.216667
# 924  2024-06-07 11:37:10.690720   4.0   False   2.900  0.725000
# 6759 2024-06-07 11:38:45.101812   6.4   False   2.950  0.460938
# 3550 2024-06-10 11:25:16.532576   9.2   False   7.850  0.853261
# 5700 2024-06-10 11:38:42.490270  12.0   False   2.000  0.166667
# 3814 2024-06-10 11:25:16.532576   9.0   False  25.000  2.777778
# 461  2024-06-07 11:37:10.690720   7.0   False   1.075  0.153571
# 4301 2024-06-10 11:25:16.532576   7.9    True   4.900  0.620253
#
#      area_size_category
# 443                8-20
# 6062                4-8
# 924                 2-4
# 6759                4-8
# 3550               8-20
# 5700               8-20
# 3814               8-20
# 461                 4-8
# 4301                4-8

# %% [markdown]
# ---

# %%
obj_type = 'house'
files = [ f'{d}/{f}' for d in source[obj_type] for f in listdir(d) if f[-4:]=='.pkl' ]
display( len(files) )

cols = ['url','place','title','subtitle','price','address','description','ts',]

df_house = pd.concat([
        pd.read_pickle(f).drop_duplicates(['url'])
        for f in files
    ]).reset_index(drop=True)[cols]

display( len(df_house) )
display(df_house.sample(9))
# Out:
# 10
# 6858
#                                                     url        place  \
# 986   https://sevastopol.cian.ru/sale/suburban/30255...   sevastopol
# 6272                    https://www.avito.ru/4133721353   sevastopol
# 5152                    https://www.avito.ru/2337658734  bahchisaray
# 4325                    https://www.avito.ru/3274720332   sevastopol
# 250   https://sevastopol.cian.ru/sale/suburban/28435...   sevastopol
# 2400  https://sevastopol.cian.ru/sale/suburban/25990...   sevastopol
# 1274  https://sevastopol.cian.ru/sale/suburban/27351...   sevastopol
# 3843                    https://www.avito.ru/4024898670   sevastopol
# 3232                    https://www.avito.ru/3491185991  bahchisaray
#
#                                 title subtitle     price  \
# 986      Дом, 44,7 м², 4.51 сот., ИЖС            7500000
# 6272   Дом 113 м² на участке 4,2 сот.      NaN  10500000
# 5152   Дом 90,4 м² на участке 23 сот.      NaN   6000000
# 4325     Дом 161 м² на участке 4 сот.      NaN  18499999
# 250            Дом, 102 м², 6.58 сот.           14000000
# 2400               Дом, 60 м², 2 сот.            6500000
# 1274  Дом, 72 м², 4 сот., Садоводство            9500000
# 3843      Дом 63 м² на участке 6 сот.      NaN   5504500
# 3232     Дом 125 м² на участке 6 сот.      NaN   8000000
#
#                                                 address  \
# 986   Севастополь, р-н Нахимовский, улица Подольцева...
# 6272                  садовое товарищество Автомобилист
# 5152                                          с. Речное
# 4325                              ул. Второй Обороны, 6
# 250   Севастополь, р-н Ленинский, Куликово Поле садо...
# 2400  Севастополь, р-н Гагаринский, Рябинушка садово...
# 1274  Севастополь, р-н Нахимовский, Радар-С садовое ...
# 3843                               ул. Дениса Ракицкого
# 3232                             Узбекистанская ул., 34
#
#                                             description  \
# 986   Продаю дом 44,7 м² на участке ИЖС 4,5 cотки, в...
# 6272  Пpодaм дом 113 м2 в СT Автомобилист. Современн...
# 5152  Продам дом в с. Речное Бахчисарайского района....
# 4325  Объект №1220. Хотите купить дом в Севастополе?...
# 250   Дом 102 м² на участке 6,58 соток Дом 102 м² на...
# 2400
# 1274  Объект 171. Кольцо Дергачи,СТ "Радар-С" ул. Ра...
# 3843  Предлагаем приобрести Дом по цене Квартиры от ...
# 3232  Продам благоустроенный жилой дом в тихом район...
#
#                              ts
# 986  2024-06-10 11:23:47.056251
# 6272 2024-06-07 11:52:05.094685
# 5152 2024-06-10 11:39:39.442400
# 4325 2024-06-10 11:33:36.811644
# 250  2024-06-10 11:23:47.056251
# 2400 2024-06-07 11:42:40.789431
# 1274 2024-06-10 11:23:47.056251
# 3843 2024-06-10 11:33:36.811644
# 3232 2024-06-07 12:10:08.505306

# %%
# cols = ['title','address','place','url']
# df_house[ (df_house['place']=='sevastopol') & (df_house['address'].str.match(r'.*Судак.*')) ][cols]

# %%
from lib.cleaner import CleanerHouse

df_house = CleanerHouse().transform(df_house)

display( len(df_house) )
display(df_house.sample(9))
# Out:
# 6858
#                                                     url        place  \
# 5060                    https://www.avito.ru/3915262430  bahchisaray
# 4309                    https://www.avito.ru/2213152392   sevastopol
# 1954  https://sevastopol.cian.ru/sale/suburban/29140...   sevastopol
# 4169                    https://www.avito.ru/3720483526   sevastopol
# 3914                    https://www.avito.ru/3316032624   sevastopol
# 387   https://sevastopol.cian.ru/sale/suburban/29178...   sevastopol
# 952   https://sevastopol.cian.ru/sale/suburban/30170...   sevastopol
# 1273  https://sevastopol.cian.ru/sale/suburban/29625...   sevastopol
# 3468                    https://www.avito.ru/3025282996   sevastopol
#
#                                 title subtitle     price  \
# 5060    дача 50 м² на участке 24 сот.      NaN   9000000
# 4309     дом 71 м² на участке 10 сот.      NaN  10000000
# 1954          дом, 87 м², 4 сот., ижс            8600000
# 4169  дом 61,4 м² на участке 2,8 сот.      NaN   5000000
# 3914     дом 155 м² на участке 5 сот.      NaN   9300000
# 387   дом, 87 м², 8 сот., садоводство            7250000
# 952   дом, 95 м², 4 сот., садоводство            7150000
# 1273       дом, 100 м², 6.5 сот., ижс            9500000
# 3468      дом 60 м² на участке 4 сот.      NaN   9450000
#
#                                                 address  \
# 5060  садоводческое некоммерческое товарищество Садо...
# 4309                                Межгорская ул., 14А
# 1954  Севастополь, р-н Нахимовский, улица Пластунска...
# 4169                                Лазаревская ул., 25
# 3914  товарищества собственников недвижимости Карава...
# 387   Севастополь, р-н Гагаринский, мкр. Фиолент, Ча...
# 952   Севастополь, р-н Гагаринский, мкр. Фиолент, По...
# 1273  Севастополь, р-н Балаклавский, мкр. Балаклава,...
# 3468                                       СТ Рубин, 26
#
#                                             description  \
# 5060  Дача 24 сотки жилой дом, с правом прописки, пл...
# 4309  Предлагается к продаже жилой дом в поселке Чер...
# 1954  Объект 849. Продам дом в городе! Все коммуника...
# 4169  Арт. 62999395 Продам уютный дом. В доме две сп...
# 3914  Новый дом 155м2 рядом с остановкой! Фиолент с ...
# 387   Дом 87 м² на участке 8 соток Дом 87 м² на учас...
# 952   Объект 13915. Продается дом 90м на 4 сотках в ...
# 1273  Объект 815. Предлагается шикарный видовой учас...
# 3468  Продается шикарный дом для комфортного и счаст...
#
#                              ts  house_area  is_part  is_townhouse  is_SNT  \
# 5060 2024-06-10 11:39:39.442400        50.0    False         False    True
# 4309 2024-06-10 11:33:36.811644        71.0    False         False   False
# 1954 2024-06-07 11:42:40.789431        87.0    False         False   False
# 4169 2024-06-10 11:33:36.811644        61.4    False         False   False
# 3914 2024-06-10 11:33:36.811644       155.0    False         False   False
# 387  2024-06-10 11:23:47.056251        87.0    False         False    True
# 952  2024-06-10 11:23:47.056251        95.0    False         False    True
# 1273 2024-06-10 11:23:47.056251       100.0    False         False   False
# 3468 2024-06-10 11:33:36.811644        60.0    False         False    True
#
#       land_area  priceM land_size_category house_size_category
# 5060       24.0    9.00                20+               30-50
# 4309       10.0   10.00               8-20              70-150
# 1954        4.0    8.60                2-4              70-150
# 4169        2.8    5.00                2-4               50-70
# 3914        5.0    9.30                4-8             150-300
# 387         8.0    7.25                4-8              70-150
# 952         4.0    7.15                2-4              70-150
# 1273        5.0    9.50                4-8              70-150
# 3468        4.0    9.45                2-4               50-70

# %% [markdown]
# ---

# %% [markdown]
# ## обновляем таблицу адресов

# %%
# !pip install geopy

# %%
from lib.locator import AddressTransformer

atr = AddressTransformer()

places = { 
# поле 'place' и название города
'bahchisaray': 'Бахчисарай,',
      'sudak': 'Судак,',
  'sevastopol': 'Севастополь,',
}

def address_norm(df,atr=atr):
    df['address_orig'] =  df['address']
    df['address'] =  df['address'].apply(atr.transform)
    df['place_'] =  df['place'].map(places)
    df['address'] = df[['address','place_']].apply(lambda d: d[0] if d[1] in d[0] else d[1]+','+d[0],axis=1) 
    df['address'] = (
        df['address']
        .str.replace(', ',',')
        .str.replace(',,',',')
        .str.replace('. ','.')
        .str.replace('\n',' ')
        .str.replace('  ',' ')
        .str.lower()
    )
    return df

# %%
df_flat = address_norm(df_flat)
df_land = address_norm(df_land)
df_house = address_norm(df_house)
# Out:
# /tmp/ipykernel_172044/776805188.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['address'] = df[['address','place_']].apply(lambda d: d[0] if d[1] in d[0] else d[1]+','+d[0],axis=1)
# /tmp/ipykernel_172044/776805188.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['address'] = df[['address','place_']].apply(lambda d: d[0] if d[1] in d[0] else d[1]+','+d[0],axis=1)
# /tmp/ipykernel_172044/776805188.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['address'] = df[['address','place_']].apply(lambda d: d[0] if d[1] in d[0] else d[1]+','+d[0],axis=1)

# %%
# df_flat[['address','address_orig']]

# %%
address = pd.concat([
        df_flat[['address','address_orig']],
        df_land[['address','address_orig']],
        df_house[['address','address_orig']],
    ]).drop_duplicates(['address']).reset_index(drop=True)

display(len(address))
display(address.sample(5))
# Out:
# 7609
#                                                 address  \
# 2711  севастополь,р-н гагаринский,таврия садоводческ...
# 4914                   республика крым,судак,асрет кв-л
# 1796               севастополь,улица дмитрия ульянова,9
# 6117                              бахчисарай,ул.пушкина
# 2202             севастополь,р-н балаклавский,с.орлиное
#
#                                            address_orig
# 2711  Севастополь, р-н Гагаринский, Таврия садоводче...
# 4914                 Республика Крым, Судак, Асрет кв-л
# 1796                          улица Дмитрия Ульянова, 9
# 6117                                        ул. Пушкина
# 2202          Севастополь, р-н Балаклавский, с. Орлиное

# %%
from os.path import exists as path_exists
loc_file_path = 'data/location.pkl' # таблица адресов

location = pd.DataFrame([],columns=['address','latitude','longitude',])
if path_exists( loc_file_path ):
    location = pd.read_pickle(loc_file_path).drop_duplicates(['address']).reset_index(drop=True)
    
display(len(location))
display(location.sample(5))
# Out:
# 14922
#                                                  address   latitude  longitude
# 496                              бахчисарай,с.шевченково  44.863726  33.757449
# 11520  севастополь,товарищество собственников недвижи...  44.514386  33.521147
# 13440                севастополь,улица комбата гегешидзе  44.602056  33.570976
# 3846   севастополь,р-н балаклавский,гераклея садоводч...  44.511918  33.544773
# 1984   севастополь,жк «дергачёв» улица горпищенко,д.1...  44.580064  33.578172

# %% [markdown]
# ---

# %%
# def address_norm_(df):
#     df['address_orig'] =  df['address']
#     # df['address'] =  df['address'].apply(atr.transform)
#     df['address'] = (
#         df['address']
#         .str.replace(', ',',')
#         .str.replace(',,',',')
#         .str.replace('. ','.')
#         .str.replace('\n',' ')
#         .str.replace('  ',' ')
#         .str.lower()
#     )
#     return df

# %%
# location = address_norm_(location)

# %%
# location = location[['address','latitude','longitude']]

# %% [markdown]
# ---

# %%
# собираем все адреса в один список
location = location.merge(
        address[['address']].drop_duplicates(),
        how='outer',
        on='address',
    ).drop_duplicates(['address']).reset_index(drop=True)

display(len(location))
display(location.sample(5))
# Out:
# 15317
#                                                  address   latitude  longitude
# 8787             севастополь,с.некрасовка,ул.островского  44.747071  33.689114
# 206                бахчисарай,с.викторовка,ул.къысмет,22  44.789403  33.800146
# 13853                     севастополь,улица краснодонцев  44.595831  33.482178
# 7929   севастополь,район ленинский,острякова,улица хр...   44.55123  33.529115
# 10923        севастополь,садовое товарищество тополёк,73        NaN        NaN

# %%
display(len(location))
display(location['latitude'].isnull().sum())
# Out:
# 15317
# 395

# %%
# собираем все адреса с геопозицией
location_def = location[~location['latitude'].isna()].reset_index(drop=True)
display(len(location_def))

# собираем все адреса без геопозиции
location_undef = location[location['latitude'].isna()][['address']].reset_index(drop=True)
display(len(location_undef))
# Out:
# 14922
# 395

# %%
from tqdm.auto import tqdm
tqdm.pandas()

# %%
# from lib.locator import GeocoderSimpleOSM
from lib.locator import GeocoderYandex
from yandex_keys import keys

atr = AddressTransformer()
locator = GeocoderYandex(keys[0])
# locator = GeocoderSimpleOSM()

if len(location_undef)>0:
    # определяем координаты по строке адреса
    location_undef = location_undef.join( 
            location_undef['address'].progress_apply(locator.transform).apply(pd.Series) 
        ).dropna()     
    display(f'LocationUpdater: {len(location_undef)} new addresses found')
    location = pd.concat([location_def,location_undef]).reset_index(drop=True) 
    assert len(location)>0
    # location.to_pickle(loc_file_path)
# Out:
#   0%|          | 0/395 [00:00<?, ?it/s]
# 'LocationUpdater: 395 new addresses found'

# %%
display( len(location) )
display( location.sample(3) )
# Out:
# 15317
#                                                 address   latitude  longitude
# 2650                севастополь,монастырское ш.,116г/1а   44.51229  33.503612
# 9785   севастополь,садоводческое товарищество надежда-2  44.534122  33.515272
# 13337             севастополь,улица дмитрия ульянова,57  44.606439  33.494674

# %%
assert len(location)>0
location.to_pickle(loc_file_path)

# %% [markdown]
# ## дополняем данные геометкой

# %%
display( len(df_flat) )
df_flat  = df_flat.merge(location,on='address').reset_index(drop=True) 
display( len(df_flat) )
display( df_flat.sample(3) )
# Out:
# 8438
# 8438
#                                   url       place  \
# 7401  https://www.avito.ru/3830155174  sevastopol
# 7882  https://www.avito.ru/3656689930  sevastopol
# 7483  https://www.avito.ru/3894047664  sevastopol
#
#                                 title subtitle    price  \
# 7401    1-к. квартира, 43 м², 2/2 эт.      NaN  5400000
# 7882  3-к. квартира, 57,9 м², 3/3 эт.      NaN  7100000
# 7483  квартира-студия, 19 м², 1/3 эт.      NaN  1900000
#
#                                 address  \
# 7401  севастополь,мореходная улица ,137
# 7882    севастополь,брестская улица ,20
# 7483    севастополь,качинское шоссе ,6а
#
#                                             description  \
# 7401  Продаю квартиру-студию в клубном доме город Се...
# 7882  Уникальное предложение для жизни. И под сдачу ...
# 7483  Продается студия у моря в г. Севастополь! Студ...
#
#                              ts  nrooms  floor  ...  is_auction  is_openspace  \
# 7401 2024-06-10 11:17:35.151941       1      2  ...       False         False
# 7882 2024-06-10 11:17:35.151941       3      3  ...       False         False
# 7483 2024-06-10 11:17:35.151941       0      1  ...       False         False
#
#       is_roof  is_SNT  priceM  is_last_floor            address_orig  \
# 7401    False   False     5.4           True  Мореходная улица , 137
# 7882    False   False     7.1           True    Брестская улица , 20
# 7483    False   False     1.9          False    Качинское шоссе , 6А
#
#             place_   latitude  longitude
# 7401  Севастополь,  44.611438  33.563134
# 7882  Севастополь,  44.601408  33.540541
# 7483  Севастополь,  44.657659  33.548393
#
# [3 rows x 25 columns]

# %%
display( len(df_land) )
df_land  = df_land.merge(location,on='address').reset_index(drop=True) 
display( len(df_land) )
display( df_land.sample(3) )
# Out:
# 7473
# 7473
#                                   url        place  \
# 3545  https://www.avito.ru/3830162590   sevastopol
# 4970  https://www.avito.ru/3365491011  bahchisaray
# 7010  https://www.avito.ru/3850995772   sevastopol
#
#                             title subtitle     price  \
# 3545   участок 15 сот. (снт, днп)      NaN   5000000
# 4970         участок 7 сот. (ижс)      NaN   2800000
# 7010  участок 304,8 га (снт, днп)      NaN  11000000
#
#                                                 address  \
# 3545        севастополь,садоводческое товарищество уптк
# 4970                           бахчисарай,пгт.куйбышево
# 7010  севастополь,нахимовский район,верхнесадовский ...
#
#                                             description  \
# 3545  Продам участок в СТ Уптк (граничит с СТ Тополе...
# 4970  В экологически чистом месте. Двухуровневый уча...
# 7010  Севастополь, Нахимовский район пгт. Верхнесадо...
#
#                              ts     area  is_IJS  priceM   priceMU  \
# 3545 2024-06-10 11:25:16.532576     15.0   False     5.0  0.333333
# 4970 2024-06-07 12:09:12.165236      7.0    True     2.8  0.400000
# 7010 2024-06-07 11:38:45.101812  30480.0   False    11.0  0.000361
#
#      area_size_category                                       address_orig  \
# 3545               8-20                    садоводческое товарищество УПТК
# 4970                4-8                                     пгт. Куйбышево
# 7010                20+  Севастополь, Нахимовский район, Верхнесадовски...
#
#             place_   latitude  longitude
# 3545  Севастополь,  44.565842  33.536921
# 4970   Бахчисарай,  44.629281  33.865229
# 7010  Севастополь,  44.690824  33.661886

# %%
display( len(df_house) )
df_house = df_house.merge(location,on='address').reset_index(drop=True) 
display( len(df_house) )
display( df_house.sample(3) )
# Out:
# 6858
# 6858
#                                                     url       place  \
# 6047                    https://www.avito.ru/4055789666  sevastopol
# 3647                    https://www.avito.ru/3710738080  sevastopol
# 2882  https://sevastopol.cian.ru/sale/suburban/30264...  sevastopol
#
#                                title subtitle     price  \
# 6047  дом 356 м² на участке 4,2 сот.      NaN  44000000
# 3647    дом 137 м² на участке 6 сот.      NaN  11500000
# 2882     дом, 98,5 м², 2.8 сот., ижс           10000000
#
#                                                 address  \
# 6047  севастополь,гагаринский район ,мкр-н казачья б...
# 3647                            севастополь,ул.ватутина
# 2882            севастополь,р-н ленинский,улица 8 марта
#
#                                             description  \
# 6047  Продаётся шикарный дом площадью 356м2 на берег...
# 3647  Продам дом с шикарным видом в г. Севастополе Н...
# 2882  Продам дом в историческом центре Севастополя. ...
#
#                              ts  house_area  is_part  is_townhouse  is_SNT  \
# 6047 2024-06-07 11:52:05.094685       356.0    False         False   False
# 3647 2024-06-10 11:33:36.811644       137.0    False         False   False
# 2882 2024-06-07 11:42:40.789431        98.5    False         False   False
#
#       land_area  priceM land_size_category house_size_category  \
# 6047        4.2    44.0                4-8                300+
# 3647        6.0    11.5                4-8              70-150
# 2882        8.0    10.0                4-8              70-150
#
#                                            address_orig        place_  \
# 6047  Гагаринский муниципальный округ, мкр-н Казачья...  Севастополь,
# 3647                                       ул. Ватутина  Севастополь,
# 2882          Севастополь, р-н Ленинский, улица 8 Марта  Севастополь,
#
#        latitude  longitude
# 6047   44.57392  33.407815
# 3647  44.585913  33.527453
# 2882  44.608788  33.507043

# %%
assert len(df_flat)>0
df_flat.to_pickle(f'{data_root_folder}/df_flat.pkl')

assert len(df_land)>0
df_land.to_pickle(f'{data_root_folder}/df_land.pkl')

assert len(df_house)>0
df_house.to_pickle(f'{data_root_folder}/df_house.pkl')
