# %% [markdown]
# __собираем объявления о продаже недвижимости в одну таблицу__
#
# _Evgeny S. Borisov <parser@mechanoid.su>_

# %%
# !date
# Out:
# Ср 19 июн 2024 12:56:51 MSK

# %%
from os import listdir
import re
import pandas as pd

# %%
data_root_folder = 'data/2024'
source = {
         'flat':[data_root_folder+'/raw/flat/cian',data_root_folder+'/raw/flat/avito'],
        'house':[data_root_folder+'/raw/house/cian',data_root_folder+'/raw/house/avito'],
         'land':[data_root_folder+'/raw/land/cian',data_root_folder+'/raw/land/avito'],
    }

# %% [markdown]
# ---

# %%
obj_type = 'flat'
files = [ f'{d}/{f}' for d in source[obj_type] for f in listdir(d) if f[-4:]=='.pkl' ]
display( len(files) )

cols = ['url','place','title','subtitle','price','address','description','ts',]

df_flat = pd.concat([
        pd.read_pickle(f).drop_duplicates(['url'])
        for f in files
    ]).reset_index(drop=True)[cols]

display( len(df_flat) )
display(df_flat.sample(9))
# Out:
# 32
# 30297
#                                                    url       place  \
# 3962   https://sevastopol.cian.ru/sale/flat/301572889/  sevastopol
# 27259                  https://www.avito.ru/4025335335  sevastopol
# 19821                  https://www.avito.ru/3471591209  sevastopol
# 9629   https://sevastopol.cian.ru/sale/flat/302213430/  sevastopol
# 14221                  https://www.avito.ru/3614459402       sudak
# 14898                  https://www.avito.ru/3721159342  sevastopol
# 10545  https://sevastopol.cian.ru/sale/flat/282199823/  sevastopol
# 15478                  https://www.avito.ru/3512476770  sevastopol
# 7898   https://sevastopol.cian.ru/sale/flat/303086287/  sevastopol
#
#                                        title  \
# 3962     2-комн. квартира, 57,2 м², 7/9 этаж
# 27259       1-к. квартира, 40,1 м², 7/10 эт.
# 19821        2-к. квартира, 52,6 м², 1/5 эт.
# 9629      2-комн. квартира, 62 м², 2/10 этаж
# 14221        1-к. квартира, 46,3 м², 5/8 эт.
# 14898        3-к. квартира, 71,6 м², 5/5 эт.
# 10545  3-комн. квартира, 55,71 м², 1/11 этаж
# 15478     1-к. апартаменты, 15,7 м², 1/2 эт.
# 7898   3-комн. квартира, 58,14 м², 9/12 этаж
#
#                                   subtitle     price  \
# 3962                                         8300000
# 27259                                  NaN   8000000
# 19821                                  NaN   7000000
# 9629                                        12500000
# 14221                                  NaN  10681664
# 14898                                  NaN  12500000
# 10545                                       14485000
# 15478                                  NaN   2600000
# 7898   Секция 1 • Сдача корпуса 2 кв. 2027  10126999
#
#                                                  address  \
# 3962   Севастополь, р-н Гагаринский, мкр. Летчики, пр...
# 27259                                ул. Колобова, 18/11
# 19821                                ул. Хрусталёва, 153
# 9629   Севастополь, р-н Гагаринский, мкр. 5-й, улица ...
# 14221            ЖК «Долина Роз»\nкв-л Долина роз, 1 оч.
# 14898                        пр-т Героев Сталинграда, 50
# 10545    Севастополь, р-н Гагаринский, улица Парковая, 7
# 15478  Нахимовский муниципальный округ, посёлок Любим...
# 7898          Севастополь, р-н Ленинский, мкр. Острякова
#
#                                              description  \
# 3962   Объект 15604. Продам двухкомнатную квартиру!!!...
# 27259  Вы любите уютные небольшие квартиры в современ...
# 19821  Продам. Собственник. Пристройка Стоит На Учёте...
# 9629   БЕЗ КОМИССИИ ДЛЯ ПОКУПАТЕЛЯ! Продается 2х квар...
# 14221  Продается квартира общей площадью 46,29 м2 в к...
# 14898  Продаётся Просторная и Уютная квартира Чешског...
# 10545
# 15478  Апартаменты в Любоморье 15.7 м2, на 1/ 2 эт. О...
# 7898
#
#                               ts
# 3962  2024-06-14 12:56:14.435965
# 27259 2024-06-13 11:17:37.489999
# 19821 2024-06-14 13:06:45.993553
# 9629  2024-06-13 11:09:09.770094
# 14221 2024-06-19 12:38:04.243540
# 14898 2024-06-17 08:29:48.414678
# 10545 2024-06-18 10:45:27.403294
# 15478 2024-06-17 08:29:48.414678
# 7898  2024-06-10 11:06:41.395615

# %%
from lib.cleaner import CleanerFlat

df_flat = CleanerFlat().transform(df_flat)
display( len(df_flat) )
display(df_flat.sample(9))
# Out:
# 30297
#                                                    url       place  \
# 8727   https://sevastopol.cian.ru/sale/flat/300780128/  sevastopol
# 25489                  https://www.avito.ru/3720659006  sevastopol
# 7533   https://sevastopol.cian.ru/sale/flat/290159437/  sevastopol
# 2947   https://sevastopol.cian.ru/sale/flat/301572583/  sevastopol
# 26610                  https://www.avito.ru/4183800349  sevastopol
# 17835                  https://www.avito.ru/3510159688  sevastopol
# 22590                  https://www.avito.ru/3851276376  sevastopol
# 7673   https://sevastopol.cian.ru/sale/flat/299736305/  sevastopol
# 57           https://krym.cian.ru/sale/flat/300737943/       sudak
#
#                                       title subtitle     price  \
# 8727    1-комн. квартира, 32,4 м², 5/5 этаж            5800000
# 25489       2-к. квартира, 49,6 м², 9/9 эт.      NaN  10990000
# 7533    2-комн. квартира, 57,2 м², 3/5 этаж            8700000
# 2947   1-комн. апартаменты, 52 м², 5/6 этаж            5000000
# 26610       2-к. квартира, 29,4 м², 1/1 эт.      NaN   3500000
# 17835         1-к. квартира, 32 м², 1/1 эт.      NaN   4300000
# 22590      1-к. квартира, 37,9 м², 5/10 эт.      NaN   7700000
# 7673   1-комн. апартаменты, 42 м², 1/9 этаж           14000000
# 57      апартаменты-студия, 18 м², 1/8 этаж            1980000
#
#                                                  address  \
# 8727      Севастополь, р-н Ленинский, улица Мечникова, 5
# 25489              проспект Октябрьской Революции, 23 к3
# 7533   Севастополь, р-н Гагаринский, мкр. Летчики, пр...
# 2947   Севастополь, р-н Гагаринский, улица Адмирала Ф...
# 26610                               улица Богданова, 167
# 17835  Нахимовский муниципальный округ, посёлок Любим...
# 22590                                 улица Косарева, 25
# 7673   Севастополь, р-н Балаклавский, Севастопольская...
# 57          Республика Крым, Судак, переулок Серный, 12А
#
#                                              description  \
# 8727   Квартира ждёт своих Счастливых владельцев! Про...
# 25489  В продаже Видовая двухкомнатная квартира с сов...
# 7533   Продаю отличную 2-хкомнатную квартиру по адрес...
# 2947
# 26610  Продается квартира(по документам квартира в од...
# 17835  Продаётся уютная и современная квартира в лучш...
# 22590  Объект №1580. Продаётся уютная 1-комнатная ква...
# 7673   Продаются отличные апартаменты в Бухте Мечты! ...
# 57     Объект 125. ПРОДАЮТСЯ АПАРТАМЕНТЫ В ЦЕНТРЕ СУД...
#
#                               ts  nrooms  floor  ...  area  is_studio  \
# 8727  2024-06-10 11:06:41.395615       0      5  ...  32.4      False
# 25489 2024-06-11 10:25:30.856703       2      9  ...  49.6      False
# 7533  2024-06-10 11:06:41.395615       0      3  ...  57.2      False
# 2947  2024-06-07 11:33:12.800097       0      5  ...  52.0      False
# 26610 2024-06-13 11:17:37.489999       2      1  ...  29.4      False
# 17835 2024-06-19 12:22:29.452737       1      1  ...  32.0      False
# 22590 2024-06-07 11:27:07.236636       1      5  ...  37.9      False
# 7673  2024-06-10 11:06:41.395615       0      1  ...  42.0      False
# 57    2024-06-18 10:56:35.757139       0      1  ...  18.0       True
#
#        is_apartment  is_part  is_auction  is_openspace  is_roof  is_SNT  \
# 8727          False    False       False         False    False   False
# 25489         False    False       False         False    False   False
# 7533          False    False       False         False    False   False
# 2947           True    False       False         False    False   False
# 26610         False    False       False         False    False   False
# 17835         False    False       False         False    False   False
# 22590         False    False       False         False    False   False
# 7673           True    False       False         False    False   False
# 57             True    False       False         False    False   False
#
#        priceM  is_last_floor
# 8727     5.80           True
# 25489   10.99           True
# 7533     8.70          False
# 2947     5.00          False
# 26610    3.50           True
# 17835    4.30           True
# 22590    7.70          False
# 7673    14.00          False
# 57       1.98          False
#
# [9 rows x 21 columns]

# %% [markdown]
# ---

# %%
obj_type = 'land'
files = [ f'{d}/{f}' for d in source[obj_type] for f in listdir(d) if f[-4:]=='.pkl' ]
display( len(files) )

cols = ['url','place','title','subtitle','price','address','description','ts',]

df_land = pd.concat([
        pd.read_pickle(f).drop_duplicates(['url'])
        for f in files
    ]).reset_index(drop=True)[cols]

display( len(df_land) )
display(df_land.sample(9))
# Out:
# 40
# 27339
#                                                      url       place  \
# 24624                    https://www.avito.ru/3861019238  sevastopol
# 6116   https://sevastopol.cian.ru/sale/suburban/30279...  sevastopol
# 22418                    https://www.avito.ru/2352802924  sevastopol
# 12797                    https://www.avito.ru/3693298543  sevastopol
# 23095                    https://www.avito.ru/4369735095       sudak
# 2364   https://sevastopol.cian.ru/sale/suburban/29813...  sevastopol
# 3988   https://sevastopol.cian.ru/sale/suburban/29497...  sevastopol
# 12401                    https://www.avito.ru/2917619319  sevastopol
# 12673                    https://www.avito.ru/3322834954  sevastopol
#
#                                 title subtitle    price  \
# 24624       Участок 8 сот. (СНТ, ДНП)      NaN  4000000
# 6116             Участок, 8 сот., ИЖС           3100000
# 22418       Участок 4 сот. (СНТ, ДНП)      NaN  2700000
# 12797     Участок 4,5 сот. (СНТ, ДНП)      NaN  4000000
# 23095       Участок 6 сот. (СНТ, ДНП)      NaN  4600000
# 2364   Участок, 6.5 сот., Садоводство           2800000
# 3988             Участок, 8 сот., ИЖС           3000000
# 12401          Участок 7,2 сот. (ИЖС)      NaN  6400000
# 12673       Участок 1,3 га (СНТ, ДНП)      NaN  2150000
#
#                                                  address  \
# 24624            садоводческое товарищество Декоративное
# 6116   Севастополь, р-н Нахимовский, с. Вишневое, ули...
# 22418  садоводческое некоммерческое товарищество Клер...
# 12797              садоводческое товарищество Планер, 2А
# 23095                       садовое товарищество Ветеран
# 2364   Севастополь, р-н Балаклавский, с. Орлиное, Нив...
# 3988      Севастополь, р-н Нахимовский, улица Мореходная
# 12401                                ул. Мельникова, 12А
# 12673                                           СТ Берег
#
#                                              description  \
# 24624            Продам свой участок 8 соток, гпзу есть.
# 6116   Продается ровный участок в экологичном месте с...
# 22418  Арт. 19591716 Данный участок можно приобрести ...
# 12797  Продаётся земельный участок 4,5 сот. В Тсн Пла...
# 23095  Продам земельный участок. Ровной формы находит...
# 2364   Объект 12112. Продается участок от собственник...
# 3988   Продам участок 8 соток,ИЖС, ул. Мореходная, пр...
# 12401  Предлагается к продаже земельный участок Ижс, ...
# 12673  Предлагается к продаже участок 130 соток в СТ ...
#
#                               ts
# 24624 2024-06-11 10:32:52.971878
# 6116  2024-06-19 12:23:33.870565
# 22418 2024-06-13 11:24:39.283050
# 12797 2024-06-17 08:36:13.464806
# 23095 2024-06-14 13:22:43.186566
# 2364  2024-06-07 11:37:10.690720
# 3988  2024-06-17 08:22:17.440170
# 12401 2024-06-17 08:36:13.464806
# 12673 2024-06-17 08:36:13.464806

# %%
from lib.cleaner import CleanerLand

df_land = CleanerLand().transform(df_land)

display( len(df_land) )
display(df_land.sample(9))
# Out:
# 27339
#                                                      url       place  \
# 24954                    https://www.avito.ru/4001272478  sevastopol
# 25036                    https://www.avito.ru/3690897419  sevastopol
# 3815   https://sevastopol.cian.ru/sale/suburban/30190...  sevastopol
# 15781                    https://www.avito.ru/3322829667  sevastopol
# 13763                    https://www.avito.ru/3548612865  sevastopol
# 24517                    https://www.avito.ru/3769280393  sevastopol
# 11178  https://sevastopol.cian.ru/sale/suburban/26736...  sevastopol
# 13740                    https://www.avito.ru/3970698288  sevastopol
# 1227   https://sevastopol.cian.ru/sale/suburban/30017...  sevastopol
#
#                                  title subtitle    price  \
# 24954        участок 4 сот. (снт, днп)      NaN  3600000
# 25036             участок 2 сот. (ижс)      NaN  7500000
# 3815   участок, 4.08 сот., садоводство           2500000
# 15781      участок 5,1 сот. (снт, днп)      NaN  1150000
# 13763            участок 10 сот. (ижс)      NaN  2750000
# 24517      участок 4,5 сот. (снт, днп)      NaN  4800000
# 11178            участок, 10 сот., днп           4200000
# 13740            участок 18 сот. (ижс)      NaN  6200000
# 1227      участок, 4 сот., садоводство           3900000
#
#                                                  address  \
# 24954                    садовое товарищество Поиск, 112
# 25036                                      ул. Киянченко
# 3815   Севастополь, р-н Нахимовский, Качинский муници...
# 15781                   садоводческое товарищество Алмаз
# 13763                    с. Фронтовое, Сары-Синапная ул.
# 24517   садоводческое товарищество Виктория-Балаклава, 3
# 11178  Севастополь, р-н Балаклавский, улица Нагорная, 20
# 13740                                         с. Орлиное
# 1227             Севастополь, р-н Балаклавский, Союз ТСН
#
#                                              description  \
# 24954  Продаётся участок 4 сотки. Ровный, Коммуникаци...
# 25036  Продам видовой участок в центре города с видом...
# 3815   Срочно продам земельный участок 4,08 сотки на ...
# 15781  Продается ровный участок 5,1 соток. Расположен...
# 13763  Продам участок 10 соток, по фасаду очень широк...
# 24517  Продажа от собственника. Земельный участок в С...
# 11178  Продается живописный земельный участок площадь...
# 13740  Большой живописный учaсток 18 соток под стpоит...
# 1227   Продаю земельный участок в ТСН Союз! Характери...
#
#                               ts  area  is_IJS  priceM   priceMU  \
# 24954 2024-06-11 10:32:52.971878   4.0   False    3.60  0.900000
# 25036 2024-06-11 10:32:52.971878   2.0    True    7.50  3.750000
# 3815  2024-06-17 08:22:17.440170   8.0   False    2.50  0.312500
# 15781 2024-06-19 12:29:14.234421   5.1   False    1.15  0.225490
# 13763 2024-06-10 11:25:16.532576  10.0    True    2.75  0.275000
# 24517 2024-06-11 10:32:52.971878   4.5   False    4.80  1.066667
# 11178 2024-06-10 11:18:48.884876  10.0   False    4.20  0.420000
# 13740 2024-06-10 11:25:16.532576  18.0    True    6.20  0.344444
# 1227  2024-06-11 10:17:41.455159   4.0   False    3.90  0.975000
#
#       area_size_category
# 24954                2-4
# 25036                1-2
# 3815                 4-8
# 15781                4-8
# 13763               8-12
# 24517                4-8
# 11178               8-12
# 13740              12-20
# 1227                 2-4

# %% [markdown]
# ---

# %%
obj_type = 'house'
files = [ f'{d}/{f}' for d in source[obj_type] for f in listdir(d) if f[-4:]=='.pkl' ]
display( len(files) )

cols = ['url','place','title','subtitle','price','address','description','ts',]

df_house = pd.concat([
        pd.read_pickle(f).drop_duplicates(['url'])
        for f in files
    ]).reset_index(drop=True)[cols]

display( len(df_house) )
display(df_house.sample(9))
# Out:
# 40
# 26021
#                                                      url       place  \
# 7117   https://sevastopol.cian.ru/sale/suburban/30317...  sevastopol
# 6309   https://sevastopol.cian.ru/sale/suburban/28370...  sevastopol
# 5379   https://sevastopol.cian.ru/sale/suburban/29991...  sevastopol
# 18989                    https://www.avito.ru/3821232103  sevastopol
# 25273                    https://www.avito.ru/4069704499  sevastopol
# 11562  https://sevastopol.cian.ru/sale/suburban/30289...  sevastopol
# 21626                    https://www.avito.ru/3817480495  sevastopol
# 7786       https://krym.cian.ru/sale/suburban/295404903/       sudak
# 22441                    https://www.avito.ru/3687830921  sevastopol
#
#                                    title subtitle     price  \
# 7117           Дом, 70 м², 4.5 сот., ИЖС            7200000
# 6309                 Дом, 111 м², 8 сот.           10500000
# 5379   Дом, 85 м², 9.3 сот., Садоводство            5300000
# 18989   Дом 483,3 м² на участке 6,9 сот.      NaN  14000000
# 25273   Дом 195,1 м² на участке 4,9 сот.      NaN  27000000
# 11562       Дом, 87,3 м², 0.63 сот., ИЖС            5100000
# 21626   Дом 119,9 м² на участке 4,1 сот.      NaN  13900000
# 7786            Дом, 180 м², 6 сот., ИЖС           13800000
# 22441     Дом 119 м² на участке 4,3 сот.      NaN  10000000
#
#                                                  address  \
# 7117   Севастополь, р-н Балаклавский, Автомобилист са...
# 6309   Севастополь, р-н Балаклавский, мкр. Балаклава,...
# 5379   Севастополь, р-н Гагаринский, мкр. Фиолент, Те...
# 18989                                 Ромашковая ул., 37
# 25273                                      Хомутовая ул.
# 11562  Севастополь, р-н Нахимовский, с. Фронтовое, ул...
# 21626  товарищества собственников недвижимости Карава...
# 7786                  Республика Крым, Судак, Асрет кв-л
# 22441       садоводческое товарищество Первомайское, 129
#
#                                              description  \
# 7117   Дом новой постройки 70 квм на участке 4,5 сот....
# 6309   Дом 111 м² на участке 8 сотки Дом 111 м² на уч...
# 5379   Объект 681. Продаетсядом 85кв. м на участке 9,...
# 18989  Арт. 63476407. Продается двухэтажный коттедж 4...
# 25273  Продам новый дом 2024 года постройки полностью...
# 11562  Продаётся уютный дом в стиле хай-тек с потряса...
# 21626  Продам новый тёплый дом на высоком ленточном ф...
# 7786   Продам шиксрный дом в самом претижном районе С...
# 22441  Продам новый каменный дом 119 м2 в Севастополе...
#
#                               ts
# 7117  2024-06-19 12:37:23.275933
# 6309  2024-06-19 12:37:23.275933
# 5379  2024-06-10 11:23:47.056251
# 18989 2024-06-11 10:41:08.345000
# 25273 2024-06-07 11:52:05.094685
# 11562 2024-06-07 11:42:40.789431
# 21626 2024-06-14 13:20:44.492111
# 7786  2024-06-17 08:28:56.608317
# 22441 2024-06-19 12:36:50.932990

# %%
# cols = ['title','address','place','url']
# df_house[ (df_house['place']=='sevastopol') & (df_house['address'].str.match(r'.*Судак.*')) ][cols]

# %%
from lib.cleaner import CleanerHouse

df_house = CleanerHouse().transform(df_house)

display( len(df_house) )
display(df_house.sample(9))
# Out:
# 26021
#                                                      url       place  \
# 18075                    https://www.avito.ru/3629350767  sevastopol
# 7640   https://sevastopol.cian.ru/sale/suburban/30335...  sevastopol
# 633    https://sevastopol.cian.ru/sale/suburban/30113...  sevastopol
# 11168  https://sevastopol.cian.ru/sale/suburban/28370...  sevastopol
# 3760   https://sevastopol.cian.ru/sale/suburban/30289...  sevastopol
# 17870                    https://www.avito.ru/3072264084  sevastopol
# 7292   https://sevastopol.cian.ru/sale/suburban/30280...  sevastopol
# 7991   https://sevastopol.cian.ru/sale/suburban/27040...  sevastopol
# 3562   https://sevastopol.cian.ru/sale/suburban/29506...  sevastopol
#
#                                       title subtitle     price  \
# 18075          дом 105 м² на участке 4 сот.      NaN   8199000
# 7640        дом, 70 м², 4 сот., садоводство           11000000
# 633       дом, 32 м², 4.5 сот., садоводство            4750000
# 11168                дом, 150 м², 2.53 сот.            9900000
# 3760   дом, 66,5 м², 3.64 сот., садоводство            6500000
# 17870      дом 52,9 м² на участке 14,6 сот.      NaN  10000000
# 7292      дом, 73,6 м², 4 сот., садоводство            8500000
# 7991        дом, 95 м², 4 сот., садоводство            7500999
# 3562        дом, 65 м², 2 сот., садоводство            4350000
#
#                                                  address  \
# 18075             садовое товарищество Автомобилист, 284
# 7640   Севастополь, р-н Гагаринский, Строитель садово...
# 633    Севастополь, р-н Гагаринский, Таврия садоводче...
# 11168  Севастополь, р-н Нахимовский, улица Героев Сев...
# 3760     Севастополь, р-н Балаклавский, Родник ТСН, 38/3
# 17870                  с. Хмельницкое, Изобильная ул., 3
# 7292   Севастополь, р-н Гагаринский, мкр. Фиолент, Ав...
# 7991   Севастополь, р-н Балаклавский, Надежда-1 садов...
# 3562   Севастополь, р-н Нахимовский, мкр. Любимовка, ...
#
#                                              description  \
# 18075  Продается действующая гостиница на Фиоленте, 1...
# 7640   Предлагаю к продаже компактный дом с возможнос...
# 633    Арт. 64083214 Продаётся жилой дом и земельный ...
# 11168  Дом 150 м² на участке 2,53 сотки Дом 150 м² на...
# 3760   Дом 66.5 м2 в 7 минутах езды от 5-го километра...
# 17870  Дом 52,9 м² на участке 14,57 соток, одноэтажны...
# 7292   Вы давно мечтаете жить у моря? Тогда это предл...
# 7991   Продается новый жилой дом в ТСН СНТ "Надежда -...
# 3562   Предлагается к продаже дом 65 кв.м. на участке...
#
#                               ts  house_area  is_part  is_townhouse  is_SNT  \
# 18075 2024-06-10 11:33:36.811644       105.0    False         False    True
# 7640  2024-06-19 12:37:23.275933        70.0    False         False    True
# 633   2024-06-11 10:23:05.308675        32.0    False         False    True
# 11168 2024-06-07 11:42:40.789431       150.0    False         False   False
# 3760  2024-06-13 11:22:19.008525        66.5    False         False    True
# 17870 2024-06-10 11:33:36.811644        52.9    False         False   False
# 7292  2024-06-19 12:37:23.275933        73.6    False         False    True
# 7991  2024-06-18 10:55:44.416781        95.0    False         False    True
# 3562  2024-06-13 11:22:19.008525        65.0    False         False    True
#
#        land_area     priceM land_size_category house_size_category
# 18075        4.0   8.199000                2-4              70-110
# 7640         4.0  11.000000                2-4               50-70
# 633          5.0   4.750000                4-8               30-50
# 11168       53.0   9.900000                20+             110-180
# 3760        64.0   6.500000                20+               50-70
# 17870       14.6  10.000000              12-20               50-70
# 7292         4.0   8.500000                2-4              70-110
# 7991         4.0   7.500999                2-4              70-110
# 3562         2.0   4.350000                1-2               50-70

# %% [markdown]
# ---

# %% [markdown]
# ## обновляем таблицу адресов

# %%
# !pip install geopy

# %%
from lib.locator import AddressTransformer

atr = AddressTransformer()

places = { 
# поле 'place' и название города
'bahchisaray': 'Бахчисарай,',
      'sudak': 'Судак,',
  'sevastopol': 'Севастополь,',
}

def address_norm(df,atr=atr):
    df['address_orig'] =  df['address']
    df['address'] =  df['address'].apply(atr.transform)
    df['place_'] =  df['place'].map(places)
    df['address'] = df[['address','place_']].apply(lambda d: d[0] if d[1] in d[0] else d[1]+','+d[0],axis=1) 
    df['address'] = (
        df['address']
        .str.replace(', ',',')
        .str.replace(',,',',')
        .str.replace('. ','.')
        .str.replace('\n',' ')
        .str.replace('  ',' ')
        .str.lower()
    )
    return df

# %%
df_flat = address_norm(df_flat)
df_land = address_norm(df_land)
df_house = address_norm(df_house)
# Out:
# /tmp/ipykernel_79191/776805188.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['address'] = df[['address','place_']].apply(lambda d: d[0] if d[1] in d[0] else d[1]+','+d[0],axis=1)
# /tmp/ipykernel_79191/776805188.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['address'] = df[['address','place_']].apply(lambda d: d[0] if d[1] in d[0] else d[1]+','+d[0],axis=1)
# /tmp/ipykernel_79191/776805188.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['address'] = df[['address','place_']].apply(lambda d: d[0] if d[1] in d[0] else d[1]+','+d[0],axis=1)

# %%
# df_flat[['address','address_orig']]

# %%
address = pd.concat([
        df_flat[['address','address_orig']],
        df_land[['address','address_orig']],
        df_house[['address','address_orig']],
    ]).drop_duplicates(['address']).reset_index(drop=True)

display(len(address))
display(address.sample(5))
# Out:
# 9133
#                                                 address  \
# 1189                       севастополь,улица гоголя,26а
# 580   севастополь,р-н гагаринский,переулок 1-й папор...
# 60        севастополь,р-н гагаринский,улица летчиков,10
# 6957  севастополь,р-н гагаринский,мкр.фиолент,орбита...
# 3858   севастополь,р-н гагаринский,улица 1-я дорическая
#
#                                            address_orig
# 1189                                  улица Гоголя, 26А
# 580   Севастополь, р-н Гагаринский, переулок 1-й Пап...
# 60     Севастополь, р-н Гагаринский, улица Летчиков, 10
# 6957  Севастополь, р-н Гагаринский, мкр. Фиолент, Ор...
# 3858  Севастополь, р-н Гагаринский, улица 1-я Дориче...

# %%
from os.path import exists as path_exists
loc_file_path = 'data/location.pkl' # таблица адресов

location = pd.DataFrame([],columns=['address','latitude','longitude',])
if path_exists( loc_file_path ):
    location = pd.read_pickle(loc_file_path).drop_duplicates(['address']).reset_index(drop=True)
    
display(len(location))
display(location.sample(5))
# Out:
# 16254
#                                                  address   latitude  longitude
# 4070   севастополь,р-н балаклавский,водолаз садовое т...  44.518403  33.496982
# 5002   севастополь,р-н балаклавский,эллада садовое то...  44.526603  33.500881
# 8345   севастополь,район ленинский,матюшенко,улица си...  44.592916  33.509972
# 11065  севастополь,садоводческое товарищество собстве...  44.524001  33.542895
# 2149     севастополь,жк «доброгород» улица токарева,д.18  44.580353  33.506019

# %% [markdown]
# ---

# %%
# def address_norm_(df):
#     df['address_orig'] =  df['address']
#     # df['address'] =  df['address'].apply(atr.transform)
#     df['address'] = (
#         df['address']
#         .str.replace(', ',',')
#         .str.replace(',,',',')
#         .str.replace('. ','.')
#         .str.replace('\n',' ')
#         .str.replace('  ',' ')
#         .str.lower()
#     )
#     return df

# %%
# location = address_norm_(location)

# %%
# location = location[['address','latitude','longitude']]

# %% [markdown]
# ---

# %%
# собираем все адреса в один список
location = location.merge(
        address[['address']].drop_duplicates(),
        how='outer',
        on='address',
    ).drop_duplicates(['address']).reset_index(drop=True)

display(len(location))
display(location.sample(5))
# Out:
# 16383
#                                                  address   latitude  longitude
# 701                        бахчисарай,ул.македонского,6б  44.757473  33.849903
# 15808               севастополь,ш.генерала моргунова,127  44.556677  33.560655
# 4739   севастополь,р-н балаклавский,с.широкое,улица б...  44.479345  33.777796
# 12353                       севастополь,ст металлист,270  44.530292  33.528666
# 9791                               севастополь,с.ушаково   44.54787  33.540577

# %%
display(len(location))
display(location['latitude'].isnull().sum())
# Out:
# 16383
# 129

# %%
# собираем все адреса с геопозицией
location_def = location[~location['latitude'].isna()].reset_index(drop=True)
display(len(location_def))

# собираем все адреса без геопозиции
location_undef = location[location['latitude'].isna()][['address']].reset_index(drop=True)
display(len(location_undef))
# Out:
# 16254
# 129

# %%
display(location_undef)
# Out:
#                                                address
# 0               бахчисарай,с.дачное,ул.гаспринского,13
# 1                бахчисарай,с.фурмановка,ул.крым герай
# 2                                    севастополь,67к-5
# 3                севастополь,английский бульвар ,21б/1
# 4                     севастополь,бакинская улица ,8/1
# ..                                                 ...
# 124  судак,республика крым,судак городской округ,с....
# 125  судак,республика крым,феодосия городской округ...
# 126  судак,республика крым,ялта городской округ,лив...
# 127      судак,республика крым,ялта,проезд парковый,6б
# 128   судак,республика крым,ялта,улица свердлова,48ак6
#
# [129 rows x 1 columns]

# %%
from tqdm.auto import tqdm
tqdm.pandas()

# %%
# from lib.locator import GeocoderSimpleOSM
from lib.locator import GeocoderYandex
from yandex_keys import keys

atr = AddressTransformer()
locator = GeocoderYandex(keys[0])
# locator = GeocoderSimpleOSM()

if len(location_undef)>0:
    # определяем координаты по строке адреса
    location_undef = location_undef.join( 
            location_undef['address'].progress_apply(locator.transform).apply(pd.Series) 
        ).dropna()     
    display(f'LocationUpdater: {len(location_undef)} new addresses found')
    location = pd.concat([location_def,location_undef]).reset_index(drop=True) 
    assert len(location)>0
    # location.to_pickle(loc_file_path)
# Out:
#   0%|          | 0/129 [00:00<?, ?it/s]
# 'LocationUpdater: 129 new addresses found'

# %%
display( len(location) )
display( location.sample(3) )
# Out:
# 16383
#                                                 address   latitude  longitude
# 8050  севастополь,район гагаринский,проезд стрелецки...  44.579968  33.474255
# 7063  севастополь,р-н нахимовский,с.орловка,шоссе ка...  44.731929  33.547081
# 2558                       севастополь,крепостное ш.,10   44.54805  33.438322

# %%
assert len(location)>0
location.to_pickle(loc_file_path)

# %% [markdown]
# ## дополняем данные геометкой

# %%
display( len(df_flat) )
df_flat  = df_flat.merge(location,on='address').reset_index(drop=True) 
display( len(df_flat) )
display( df_flat.sample(3) )
# Out:
# 30297
# 30297
#                                                    url       place  \
# 27345                  https://www.avito.ru/3829802513  sevastopol
# 6815         https://krym.cian.ru/sale/flat/293880638/       sudak
# 6089   https://sevastopol.cian.ru/sale/flat/299334069/  sevastopol
#
#                                        title subtitle    price  \
# 27345        3-к. квартира, 61,5 м², 5/5 эт.      NaN  6900000
# 6815   апартаменты-студия, 33,2 м², 4/8 этаж           4918040
# 6089    2-комн. апартаменты, 42 м², 5/5 этаж           6150000
#
#                                                  address  \
# 27345                    севастополь,улица хрусталёва,53
# 6815        республика крым,судак,улица айвазовского,4/2
# 6089   севастополь,р-н нахимовский,мкр.учкуевка,улица...
#
#                                              description  \
# 27345  Продается просторная 3-х комнатная квартира по...
# 6815   Старт Продаж Квартир У Моря! Мы предлагаем Вам...
# 6089   Продаю просторные двухкомнатные апартаменты пл...
#
#                               ts  nrooms  floor  ...  is_auction  \
# 27345 2024-06-13 11:17:37.489999       3      5  ...       False
# 6815  2024-06-14 13:07:08.419041       0      4  ...       False
# 6089  2024-06-11 10:13:23.305322       0      5  ...       False
#
#        is_openspace  is_roof  is_SNT   priceM  is_last_floor  \
# 27345         False    False   False  6.90000           True
# 6815          False    False   False  4.91804          False
# 6089          False    False   False  6.15000           True
#
#                                             address_orig        place_  \
# 27345                               улица Хрусталёва, 53  Севастополь,
# 6815     Республика Крым, Судак, улица Айвазовского, 4/2        Судак,
# 6089   Севастополь, р-н Нахимовский, мкр. Учкуевка, у...  Севастополь,
#
#         latitude  longitude
# 27345  44.575474  33.515128
# 6815   44.851171  34.969626
# 6089   44.638716  33.540371
#
# [3 rows x 25 columns]

# %%
display( len(df_land) )
df_land  = df_land.merge(location,on='address').reset_index(drop=True) 
display( len(df_land) )
display( df_land.sample(3) )
# Out:
# 27339
# 27339
#                                                      url       place  \
# 20327                    https://www.avito.ru/2469393911  sevastopol
# 1509   https://sevastopol.cian.ru/sale/suburban/30164...  sevastopol
# 16127                    https://www.avito.ru/4089672496       sudak
#
#                         title subtitle    price  \
# 20327   участок 12 сот. (ижс)      NaN  5700000
# 1509          участок, 4 сот.           2700000
# 16127  участок 7,3 сот. (ижс)      NaN  3900000
#
#                                                  address  \
# 20327  севастополь,садоводческое товарищество геракле...
# 1509   севастополь,р-н гагаринский,мкр.фиолент,гранат...
# 16127                  судак,с.солнечная долина,ул.авдет
#
#                                              description  \
# 20327  Доброго времени суток! Представляем Вам земель...
# 1509   Предлагаем вашему вниманию участок земли площа...
# 16127  Объект №34. Продается участок — Ижс. Участок 7...
#
#                               ts  area  is_IJS  priceM   priceMU  \
# 20327 2024-06-14 13:13:27.377070  12.0    True     5.7  0.475000
# 1509  2024-06-07 11:37:10.690720   4.0   False     2.7  0.675000
# 16127 2024-06-13 11:34:07.730864   7.3    True     3.9  0.534247
#
#       area_size_category                                       address_orig  \
# 20327               8-12            садоводческое товарищество Гераклея, 13
# 1509                 2-4  Севастополь, р-н Гагаринский, мкр. Фиолент, Гр...
# 16127                4-8                     с. Солнечная Долина, ул. Авдет
#
#              place_   latitude  longitude
# 20327  Севастополь,  44.514386  33.547054
# 1509   Севастополь,  44.544613  33.455732
# 16127        Судак,  44.864614  35.115153

# %%
display( len(df_house) )
df_house = df_house.merge(location,on='address').reset_index(drop=True) 
display( len(df_house) )
display( df_house.sample(3) )
# Out:
# 26021
# 26021
#                                                      url       place  \
# 2690   https://sevastopol.cian.ru/sale/suburban/30284...  sevastopol
# 15153                    https://www.avito.ru/3421309809  sevastopol
# 4730       https://krym.cian.ru/sale/suburban/299586063/       sudak
#
#                                   title subtitle     price  \
# 2690   дом, 102 м², 2 сот., садоводство           10000000
# 15153      дом 253 м² на участке 5 сот.      NaN   9250000
# 4730           дом, 274 м², 5 сот., ижс           39000000
#
#                                                  address  \
# 2690   севастополь,р-н гагаринский,мкр.фиолент,шоссе ...
# 15153  севастополь,гагаринский район ,мкр-н казачья б...
# 4730       республика крым,судак,улица имени вернадского
#
#                                              description  \
# 2690   Объект 1844. Продам дом. Расположенный в СТ Аф...
# 15153  Дом Казачья. Снт. Есть прописка. Жилой район. ...
# 4730
#
#                               ts  house_area  is_part  is_townhouse  is_SNT  \
# 2690  2024-06-17 08:27:31.304082       102.0    False         False   False
# 15153 2024-06-13 11:32:06.964835       253.0    False         False   False
# 4730  2024-06-10 11:25:21.743717       274.0    False         False   False
#
#        land_area  priceM land_size_category house_size_category  \
# 2690         2.0   10.00                1-2              70-110
# 15153        5.0    9.25                4-8             180-300
# 4730         5.0   39.00                4-8             180-300
#
#                                             address_orig        place_  \
# 2690   Севастополь, р-н Гагаринский, мкр. Фиолент, шо...  Севастополь,
# 15153  Гагаринский муниципальный округ, мкр-н Казачья...  Севастополь,
# 4730     Республика Крым, Судак, улица Имени Вернадского        Судак,
#
#         latitude  longitude
# 2690   44.527529  33.466682
# 15153  44.567608  33.419395
# 4730   44.849574  34.983326

# %%
def address_filter(df):
    #           46.319437, 33.911048
    #
    # 45.402617, 32.455625 |  45.545301, 36.684702
    #
    #          44.320887, 33.917013

    df['latitude'] = pd.to_numeric( df['latitude'], errors='coerce' )
    df['longitude'] = pd.to_numeric( df['longitude'], errors='coerce' )

    df = df.query('(32.4<longitude<36.7) & (44.3<latitude<46.4)') 

    df.loc[ df['url']=='https://avito.ru/2322251740', ['latitude','longitude']] = None

    df.loc[ df['address']=='Севастополь,Чёрное море', ['latitude','longitude'] ] = None
    df.loc[ df['address'].str.lower().str.match('чёрное море'), ['latitude','longitude'] ] = None 

    df.loc[ df['address']=='квартал Старый Город', 'place'] = 'turkie'
    df.loc[ df['address'].str.lower().str.match('анталья'), 'place' ] = 'turkie' 

    df.loc[ df['address'].str.lower().str.match(r'.*бахчисарай.*'), 'place' ] = 'bahchisaray'
    df.loc[ df['address'].str.lower().str.match(r'.*севастополь,.*'), 'place' ] = 'sevastopol'

    df.loc[ df['address'].str.lower().str.match(r'.*мысовское.*'), 'place' ] = 'kerch'
    df.loc[ df['address'].str.lower().str.match(r'.*алушта.*'), 'place' ] = 'alushta'
    df.loc[ df['address'].str.lower().str.match(r'.*гурзуф.*'), 'place' ] = 'gurzuf'

    df.loc[ df['address'].str.lower().str.match(r'.*с.лучистое.*'), 'place' ] = 'alushta'
    df.loc[ df['address'].str.lower().str.match(r'.*снт солнечная долина.*'), 'place' ] = 'sudak'
    df.loc[ df['address'].str.lower().str.match(r'.*пгт.новоозёрное.*'), 'place' ] = 'evpatoria'

    df.loc[ df['address'].str.lower().str.match(r'.*с.мирное.*'), 'place' ] = 'simferopol'
    df.loc[ df['address'].str.lower().str.match(r'.*тсн аэрофлот.*'), 'place' ] = 'simferopol'

    df.loc[ df['address'].str.lower().str.match(r'.*семисот.*'), 'place' ] = 'kerch'

    df.loc[ df['address'].str.lower().str.match(r'.*ялта.*') , 'place' ] = 'yalta'
    df.loc[ df['address'].str.lower().str.match(r'.*феодосия.*') , 'place' ] = 'feodosia'
    df.loc[ df['address'].str.lower().str.match(r'.*окуневка.*') , 'place' ] = 'tarkhankut'
    df.loc[ df['address'].str.lower().str.match(r'.*заветное.*') , 'place' ] = 'kerch'
    df.loc[ df['address'].str.lower().str.match(r'.*евпатория.*') , 'place' ] = 'evpatoria'
    df.loc[ df['address'].str.lower().str.match(r'.*симферопольский район.*'), 'place' ] = 'simferopol'

    df = df.dropna(subset=['latitude','longitude'])
    
    return df

# %%
display(len(df_flat))
df_flat = address_filter(df_flat)
display(len(df_flat))

display(len(df_land))
df_land = address_filter(df_land)
display(len(df_land))

display(len(df_house))
df_house = address_filter(df_house)
display(len(df_house))
# Out:
# 30297
# 29948
# 27339
# 27326
# 26021
# 26020

# %%
assert len(df_flat)>0
df_flat.to_pickle(f'{data_root_folder}/df_flat.pkl')

assert len(df_land)>0
df_land.to_pickle(f'{data_root_folder}/df_land.pkl')

assert len(df_house)>0
df_house.to_pickle(f'{data_root_folder}/df_house.pkl')

# %%
# !date
# Out:
# Ср 19 июн 2024 12:57:56 MSK
